# %% [markdown]
# ## Variational Autoencoder

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAE

DATASET_SIZE = 25084
INPUT_SHAPE = (40, 40, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    raise Exception("Cannot initialize GPU")

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training'
)

val_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation'
)
# Out:
# Found 17559 images belonging to 1 classes.
# Found 7524 images belonging to 1 classes.

# %%
vae = VAE(
    layers=5,
    latent_size=16,
    kernel_size=3,
    filters=16,
    input_shape=INPUT_SHAPE,
    name="VAE"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 40, 40, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 40, 40, 8)    80          input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 20, 20, 8)    0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 20, 20, 16)   1168        maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 10, 10, 16)   0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 10, 10, 32)   4640        maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 5, 5, 32)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 5, 5, 64)     18496       maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 3, 3, 64)     0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# conv5_enc (Conv2D)              (None, 3, 3, 128)    73856       maxpool4[0][0]
# __________________________________________________________________________________________________
# maxpool5 (MaxPooling2D)         (None, 2, 2, 128)    0           conv5_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           maxpool5[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 16)           8208        flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 16)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 106,992
# Trainable params: 106,992
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 16)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 512)               8704
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 2, 128)         0
# _________________________________________________________________
# conv5_dec (Conv2D)           (None, 2, 2, 128)         147584
# _________________________________________________________________
# upsamp5 (UpSampling2D)       (None, 4, 4, 128)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 4, 4, 64)          73792
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 8, 8, 64)          0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 8, 8, 32)          18464
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 16, 16, 16)        4624
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 32, 32, 16)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 32, 32, 8)         1160
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 64, 64, 8)         0
# _________________________________________________________________
# output (Conv2D)              (None, 40, 40, 1)         5001
# =================================================================
# Total params: 259,329
# Trainable params: 259,329
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 16), (None, 16),  106992
# _________________________________________________________________
# Decoder (Functional)         (None, 40, 40, 1)         259329
# =================================================================
# Total params: 366,327
# Trainable params: 366,321
# Non-trainable params: 6
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15),
    TensorBoard(
        log_dir='./logs',
        histogram_freq=1
    )
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=100, 
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 549/549 [==============================] - 191s 325ms/step - loss: 108.4745 - reconstruction_loss: 76.8227 - kl_loss: 1.0168 - val_loss: 53.7547 - val_reconstruction_loss: 43.6788 - val_kl_loss: 10.0759
# Epoch 2/100
# 549/549 [==============================] - 6s 11ms/step - loss: 42.0271 - reconstruction_loss: 26.2480 - kl_loss: 10.4333 - val_loss: 30.5794 - val_reconstruction_loss: 18.8654 - val_kl_loss: 11.7141
# Epoch 3/100
# 549/549 [==============================] - 6s 12ms/step - loss: 29.3997 - reconstruction_loss: 17.7687 - kl_loss: 11.0367 - val_loss: 29.8823 - val_reconstruction_loss: 18.9305 - val_kl_loss: 10.9518
# Epoch 4/100
# 549/549 [==============================] - 7s 12ms/step - loss: 27.8092 - reconstruction_loss: 16.3268 - kl_loss: 11.1721 - val_loss: 21.0539 - val_reconstruction_loss: 10.2910 - val_kl_loss: 10.7629
# Epoch 5/100
# 549/549 [==============================] - 6s 11ms/step - loss: 26.4398 - reconstruction_loss: 15.2078 - kl_loss: 10.8945 - val_loss: 25.2433 - val_reconstruction_loss: 14.0580 - val_kl_loss: 11.1853
# Epoch 6/100
# 549/549 [==============================] - 6s 12ms/step - loss: 24.3907 - reconstruction_loss: 13.8416 - kl_loss: 10.4782 - val_loss: 19.5375 - val_reconstruction_loss: 9.2887 - val_kl_loss: 10.2488
# Epoch 7/100
# 549/549 [==============================] - 6s 12ms/step - loss: 23.8746 - reconstruction_loss: 13.2872 - kl_loss: 10.5232 - val_loss: 22.4283 - val_reconstruction_loss: 11.7385 - val_kl_loss: 10.6897
# Epoch 8/100
# 549/549 [==============================] - 6s 11ms/step - loss: 23.4995 - reconstruction_loss: 13.0207 - kl_loss: 10.5314 - val_loss: 21.0307 - val_reconstruction_loss: 11.5112 - val_kl_loss: 9.5195
# Epoch 9/100
# 549/549 [==============================] - 6s 11ms/step - loss: 23.3496 - reconstruction_loss: 12.5442 - kl_loss: 10.6258 - val_loss: 16.0958 - val_reconstruction_loss: 5.9925 - val_kl_loss: 10.1033
# Epoch 10/100
# 549/549 [==============================] - 6s 11ms/step - loss: 23.2053 - reconstruction_loss: 12.3965 - kl_loss: 10.5702 - val_loss: 21.9904 - val_reconstruction_loss: 11.2604 - val_kl_loss: 10.7300
# Epoch 11/100
# 549/549 [==============================] - 6s 11ms/step - loss: 22.8063 - reconstruction_loss: 12.1875 - kl_loss: 10.6427 - val_loss: 24.1863 - val_reconstruction_loss: 13.5777 - val_kl_loss: 10.6086
# Epoch 12/100
# 549/549 [==============================] - 7s 12ms/step - loss: 22.4856 - reconstruction_loss: 11.9510 - kl_loss: 10.5887 - val_loss: 21.0630 - val_reconstruction_loss: 10.9201 - val_kl_loss: 10.1429
# Epoch 13/100
# 549/549 [==============================] - 6s 11ms/step - loss: 22.4633 - reconstruction_loss: 11.8027 - kl_loss: 10.6452 - val_loss: 20.8880 - val_reconstruction_loss: 10.8739 - val_kl_loss: 10.0141
# Epoch 14/100
# 549/549 [==============================] - 6s 11ms/step - loss: 22.0882 - reconstruction_loss: 11.5466 - kl_loss: 10.5842 - val_loss: 14.0882 - val_reconstruction_loss: 4.0713 - val_kl_loss: 10.0169
# Epoch 15/100
# 549/549 [==============================] - 6s 11ms/step - loss: 22.0527 - reconstruction_loss: 11.4007 - kl_loss: 10.5784 - val_loss: 24.3355 - val_reconstruction_loss: 13.8466 - val_kl_loss: 10.4889
# Epoch 16/100
# 549/549 [==============================] - 6s 11ms/step - loss: 22.0280 - reconstruction_loss: 11.2972 - kl_loss: 10.6388 - val_loss: 16.8856 - val_reconstruction_loss: 6.8328 - val_kl_loss: 10.0528
# Epoch 17/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.9189 - reconstruction_loss: 11.2770 - kl_loss: 10.6148 - val_loss: 18.9540 - val_reconstruction_loss: 8.2747 - val_kl_loss: 10.6792
# Epoch 18/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.8851 - reconstruction_loss: 11.1097 - kl_loss: 10.6262 - val_loss: 16.3721 - val_reconstruction_loss: 6.0998 - val_kl_loss: 10.2724
# Epoch 19/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.6964 - reconstruction_loss: 10.9253 - kl_loss: 10.6293 - val_loss: 16.3309 - val_reconstruction_loss: 6.5124 - val_kl_loss: 9.8185
# Epoch 20/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.4325 - reconstruction_loss: 10.9915 - kl_loss: 10.5839 - val_loss: 21.3719 - val_reconstruction_loss: 10.1937 - val_kl_loss: 11.1782
# Epoch 21/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.6263 - reconstruction_loss: 10.9186 - kl_loss: 10.6087 - val_loss: 21.7940 - val_reconstruction_loss: 11.6017 - val_kl_loss: 10.1923
# Epoch 22/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.3781 - reconstruction_loss: 10.7406 - kl_loss: 10.6306 - val_loss: 25.4458 - val_reconstruction_loss: 14.8359 - val_kl_loss: 10.6100
# Epoch 23/100
# 549/549 [==============================] - 6s 12ms/step - loss: 21.2867 - reconstruction_loss: 10.6369 - kl_loss: 10.6341 - val_loss: 26.0966 - val_reconstruction_loss: 16.2524 - val_kl_loss: 9.8442
# Epoch 24/100
# 549/549 [==============================] - 7s 12ms/step - loss: 21.1587 - reconstruction_loss: 10.4735 - kl_loss: 10.6790 - val_loss: 17.9654 - val_reconstruction_loss: 6.8715 - val_kl_loss: 11.0940
# Epoch 25/100
# 549/549 [==============================] - 7s 12ms/step - loss: 20.9714 - reconstruction_loss: 10.4236 - kl_loss: 10.5982 - val_loss: 27.8665 - val_reconstruction_loss: 16.9570 - val_kl_loss: 10.9095
# Epoch 26/100
# 549/549 [==============================] - 7s 12ms/step - loss: 20.9875 - reconstruction_loss: 10.3751 - kl_loss: 10.6204 - val_loss: 19.3459 - val_reconstruction_loss: 9.3978 - val_kl_loss: 9.9482
# Epoch 27/100
# 549/549 [==============================] - 7s 12ms/step - loss: 20.8667 - reconstruction_loss: 10.2390 - kl_loss: 10.6362 - val_loss: 14.8945 - val_reconstruction_loss: 3.8005 - val_kl_loss: 11.0940
# Epoch 28/100
# 549/549 [==============================] - 7s 12ms/step - loss: 21.0790 - reconstruction_loss: 10.2329 - kl_loss: 10.6455 - val_loss: 17.0351 - val_reconstruction_loss: 6.9321 - val_kl_loss: 10.1031
# Epoch 29/100
# 549/549 [==============================] - 7s 13ms/step - loss: 20.8362 - reconstruction_loss: 10.1112 - kl_loss: 10.6552 - val_loss: 18.5821 - val_reconstruction_loss: 8.5953 - val_kl_loss: 9.9868

# %%
val_rec_loss = history.history['val_reconstruction_loss']
rec_loss = history.history['reconstruction_loss']

epochs = range(1, len(val_rec_loss) + 1)    

plt.plot(epochs, val_rec_loss, 'b', label='Val Reconstruction loss')
plt.plot(epochs, rec_loss, 'bo', label='Reconstruction loss')
plt.title('Reconstruction and KL loss')
plt.legend()

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

'''
for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE)
    img = img_to_array(load_img(f"images_trans/pong_trans_{rand_img}.png", color_mode='grayscale'))
    images[i] = img
    '''

rand_img = random.randint(0, DATASET_SIZE-10)
for i in range(n):
    img = img_to_array(load_img(f"images_trans/pong_trans_{rand_img+i}.png", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 100.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [i*10 for i in range(-7, 7)]
            # missing =  -2.9679005e+00, -1.7151514e+01    
            z_sample = np.array([[xi, yi] + rest])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)

# %%
vae.model.save("models/vae")
# Out:
# INFO:tensorflow:Assets written to: models/vae/assets
