# %% [markdown]
# ## Variational Autoencoder

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAE

DATASET_SIZE = 25084
INPUT_SHAPE = (40, 40, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    raise Exception("Cannot initialize GPU")

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training'
)

val_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation'
)
# Out:
# Found 17559 images belonging to 1 classes.
# Found 7524 images belonging to 1 classes.

# %%
vae = VAE(
    layers=4,
    latent_size=16,
    kernel_size=3,
    filters=16,
    input_shape=INPUT_SHAPE,
    name="VAE"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 40, 40, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 40, 40, 16)   160         input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 20, 20, 16)   0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 20, 20, 32)   4640        maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 10, 10, 32)   0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 10, 10, 64)   18496       maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 5, 5, 64)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 5, 5, 128)    73856       maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 3, 3, 128)    0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1152)         0           maxpool4[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 16)           18448       flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling_5 (Sampling)           (None, 16)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 116,144
# Trainable params: 116,144
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 16)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 1152)              19584
# _________________________________________________________________
# reshape (Reshape)            (None, 3, 3, 128)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 6, 6, 128)         0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 6, 6, 64)          73792
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 12, 12, 32)        18464
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 24, 24, 32)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 24, 24, 16)        4624
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 48, 48, 16)        0
# _________________________________________________________________
# output (Conv2D)              (None, 40, 40, 1)         1297
# =================================================================
# Total params: 265,345
# Trainable params: 265,345
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 16), (None, 16),  116144
# _________________________________________________________________
# Decoder (Functional)         (None, 40, 40, 1)         265345
# =================================================================
# Total params: 381,495
# Trainable params: 381,489
# Non-trainable params: 6
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=30),
    TensorBoard(
        log_dir='./logs',
        histogram_freq=1
    )
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=100, 
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 549/549 [==============================] - 24s 30ms/step - loss: 112.7423 - reconstruction_loss: 62.9463 - kl_loss: 5.4085 - val_loss: 34.7437 - val_reconstruction_loss: 24.0038 - val_kl_loss: 10.7399
# Epoch 2/100
# 549/549 [==============================] - 6s 11ms/step - loss: 31.9709 - reconstruction_loss: 19.4395 - kl_loss: 10.1571 - val_loss: 28.8878 - val_reconstruction_loss: 17.8606 - val_kl_loss: 11.0272
# Epoch 3/100
# 549/549 [==============================] - 6s 11ms/step - loss: 25.8268 - reconstruction_loss: 14.9609 - kl_loss: 10.4620 - val_loss: 26.5463 - val_reconstruction_loss: 16.1991 - val_kl_loss: 10.3472
# Epoch 4/100
# 549/549 [==============================] - 6s 11ms/step - loss: 24.5347 - reconstruction_loss: 13.6867 - kl_loss: 10.6497 - val_loss: 18.9473 - val_reconstruction_loss: 8.3019 - val_kl_loss: 10.6454
# Epoch 5/100
# 549/549 [==============================] - 6s 11ms/step - loss: 23.9260 - reconstruction_loss: 13.0800 - kl_loss: 10.7322 - val_loss: 25.0343 - val_reconstruction_loss: 13.2901 - val_kl_loss: 11.7442
# Epoch 6/100
# 549/549 [==============================] - 6s 11ms/step - loss: 23.3793 - reconstruction_loss: 12.5437 - kl_loss: 10.7485 - val_loss: 21.3330 - val_reconstruction_loss: 10.0122 - val_kl_loss: 11.3207
# Epoch 7/100
# 549/549 [==============================] - 6s 11ms/step - loss: 23.0219 - reconstruction_loss: 12.1400 - kl_loss: 10.7602 - val_loss: 31.0497 - val_reconstruction_loss: 20.1514 - val_kl_loss: 10.8982
# Epoch 8/100
# 549/549 [==============================] - 6s 11ms/step - loss: 22.7184 - reconstruction_loss: 11.9109 - kl_loss: 10.7584 - val_loss: 27.9217 - val_reconstruction_loss: 16.3184 - val_kl_loss: 11.6033
# Epoch 9/100
# 549/549 [==============================] - 6s 11ms/step - loss: 22.2513 - reconstruction_loss: 11.6328 - kl_loss: 10.7360 - val_loss: 22.4636 - val_reconstruction_loss: 12.1928 - val_kl_loss: 10.2708
# Epoch 10/100
# 549/549 [==============================] - 6s 11ms/step - loss: 22.1254 - reconstruction_loss: 11.2896 - kl_loss: 10.7342 - val_loss: 19.7971 - val_reconstruction_loss: 8.8220 - val_kl_loss: 10.9750
# Epoch 11/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.8796 - reconstruction_loss: 11.1243 - kl_loss: 10.7084 - val_loss: 18.8489 - val_reconstruction_loss: 8.5459 - val_kl_loss: 10.3031
# Epoch 12/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.5287 - reconstruction_loss: 10.9331 - kl_loss: 10.7265 - val_loss: 19.9825 - val_reconstruction_loss: 9.0089 - val_kl_loss: 10.9736
# Epoch 13/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.3886 - reconstruction_loss: 10.6939 - kl_loss: 10.6785 - val_loss: 18.2525 - val_reconstruction_loss: 7.7864 - val_kl_loss: 10.4661
# Epoch 14/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.1333 - reconstruction_loss: 10.4526 - kl_loss: 10.6801 - val_loss: 23.7568 - val_reconstruction_loss: 12.6168 - val_kl_loss: 11.1400
# Epoch 15/100
# 549/549 [==============================] - 6s 11ms/step - loss: 21.0499 - reconstruction_loss: 10.4064 - kl_loss: 10.6405 - val_loss: 19.3286 - val_reconstruction_loss: 9.3174 - val_kl_loss: 10.0112
# Epoch 16/100
# 549/549 [==============================] - 6s 11ms/step - loss: 20.8683 - reconstruction_loss: 10.2739 - kl_loss: 10.6342 - val_loss: 25.6174 - val_reconstruction_loss: 14.0384 - val_kl_loss: 11.5790
# Epoch 17/100
# 549/549 [==============================] - 6s 11ms/step - loss: 20.7233 - reconstruction_loss: 10.1496 - kl_loss: 10.6304 - val_loss: 22.8728 - val_reconstruction_loss: 11.3791 - val_kl_loss: 11.4937
# Epoch 18/100
# 549/549 [==============================] - 6s 11ms/step - loss: 20.5867 - reconstruction_loss: 10.0010 - kl_loss: 10.6045 - val_loss: 24.0607 - val_reconstruction_loss: 12.1942 - val_kl_loss: 11.8665
# Epoch 19/100
# 549/549 [==============================] - 6s 11ms/step - loss: 20.3060 - reconstruction_loss: 9.7560 - kl_loss: 10.6878 - val_loss: 18.0330 - val_reconstruction_loss: 6.6568 - val_kl_loss: 11.3763
# Epoch 20/100
# 549/549 [==============================] - 6s 11ms/step - loss: 20.2694 - reconstruction_loss: 9.7292 - kl_loss: 10.6105 - val_loss: 24.2247 - val_reconstruction_loss: 13.0145 - val_kl_loss: 11.2102
# Epoch 21/100
# 549/549 [==============================] - 6s 11ms/step - loss: 20.2524 - reconstruction_loss: 9.6302 - kl_loss: 10.6682 - val_loss: 19.0220 - val_reconstruction_loss: 7.8311 - val_kl_loss: 11.1908
# Epoch 22/100
# 549/549 [==============================] - 6s 11ms/step - loss: 20.3464 - reconstruction_loss: 9.5191 - kl_loss: 10.6724 - val_loss: 22.1580 - val_reconstruction_loss: 11.1851 - val_kl_loss: 10.9729
# Epoch 23/100
# 549/549 [==============================] - 6s 11ms/step - loss: 20.1293 - reconstruction_loss: 9.5774 - kl_loss: 10.6858 - val_loss: 19.3346 - val_reconstruction_loss: 9.6935 - val_kl_loss: 9.6411
# Epoch 24/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.9757 - reconstruction_loss: 9.3953 - kl_loss: 10.6642 - val_loss: 20.1649 - val_reconstruction_loss: 10.0894 - val_kl_loss: 10.0755
# Epoch 25/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.9191 - reconstruction_loss: 9.2176 - kl_loss: 10.6955 - val_loss: 17.7736 - val_reconstruction_loss: 7.3992 - val_kl_loss: 10.3743
# Epoch 26/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.9095 - reconstruction_loss: 9.2234 - kl_loss: 10.6647 - val_loss: 11.8644 - val_reconstruction_loss: 2.0098 - val_kl_loss: 9.8546
# Epoch 27/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.8099 - reconstruction_loss: 9.1343 - kl_loss: 10.6635 - val_loss: 12.7778 - val_reconstruction_loss: 3.0891 - val_kl_loss: 9.6886
# Epoch 28/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.6929 - reconstruction_loss: 8.9617 - kl_loss: 10.6968 - val_loss: 18.5620 - val_reconstruction_loss: 7.9300 - val_kl_loss: 10.6319
# Epoch 29/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.7865 - reconstruction_loss: 9.0694 - kl_loss: 10.7117 - val_loss: 13.3552 - val_reconstruction_loss: 3.3238 - val_kl_loss: 10.0313
# Epoch 30/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.6788 - reconstruction_loss: 8.9709 - kl_loss: 10.7324 - val_loss: 17.7485 - val_reconstruction_loss: 7.5592 - val_kl_loss: 10.1893
# Epoch 31/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.6938 - reconstruction_loss: 8.9011 - kl_loss: 10.7029 - val_loss: 18.4032 - val_reconstruction_loss: 8.2035 - val_kl_loss: 10.1997
# Epoch 32/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.4672 - reconstruction_loss: 8.7530 - kl_loss: 10.7517 - val_loss: 20.2863 - val_reconstruction_loss: 8.8490 - val_kl_loss: 11.4373
# Epoch 33/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.3137 - reconstruction_loss: 8.7067 - kl_loss: 10.7247 - val_loss: 16.9579 - val_reconstruction_loss: 6.6612 - val_kl_loss: 10.2967
# Epoch 34/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.4250 - reconstruction_loss: 8.6979 - kl_loss: 10.7217 - val_loss: 19.0768 - val_reconstruction_loss: 8.0553 - val_kl_loss: 11.0215
# Epoch 35/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.3080 - reconstruction_loss: 8.6214 - kl_loss: 10.7728 - val_loss: 23.5183 - val_reconstruction_loss: 12.4527 - val_kl_loss: 11.0656
# Epoch 36/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.2485 - reconstruction_loss: 8.5678 - kl_loss: 10.7360 - val_loss: 16.6057 - val_reconstruction_loss: 6.3273 - val_kl_loss: 10.2783
# Epoch 37/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.2029 - reconstruction_loss: 8.4195 - kl_loss: 10.7611 - val_loss: 17.5822 - val_reconstruction_loss: 5.5714 - val_kl_loss: 12.0108
# Epoch 38/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.2539 - reconstruction_loss: 8.3818 - kl_loss: 10.7873 - val_loss: 13.3952 - val_reconstruction_loss: 3.4509 - val_kl_loss: 9.9443
# Epoch 39/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.1102 - reconstruction_loss: 8.3652 - kl_loss: 10.8210 - val_loss: 18.7481 - val_reconstruction_loss: 7.7519 - val_kl_loss: 10.9963
# Epoch 40/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.1566 - reconstruction_loss: 8.2974 - kl_loss: 10.7773 - val_loss: 14.5597 - val_reconstruction_loss: 3.6283 - val_kl_loss: 10.9314
# Epoch 41/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.8900 - reconstruction_loss: 8.2350 - kl_loss: 10.7811 - val_loss: 22.0035 - val_reconstruction_loss: 11.4617 - val_kl_loss: 10.5418
# Epoch 42/100
# 549/549 [==============================] - 6s 11ms/step - loss: 19.0816 - reconstruction_loss: 8.2092 - kl_loss: 10.7916 - val_loss: 19.4955 - val_reconstruction_loss: 8.9264 - val_kl_loss: 10.5691
# Epoch 43/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.9570 - reconstruction_loss: 8.0568 - kl_loss: 10.7997 - val_loss: 17.3184 - val_reconstruction_loss: 6.8202 - val_kl_loss: 10.4982
# Epoch 44/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.7944 - reconstruction_loss: 8.0488 - kl_loss: 10.8028 - val_loss: 16.8556 - val_reconstruction_loss: 6.1890 - val_kl_loss: 10.6666
# Epoch 45/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.9451 - reconstruction_loss: 8.1091 - kl_loss: 10.8599 - val_loss: 19.2865 - val_reconstruction_loss: 8.9115 - val_kl_loss: 10.3750
# Epoch 46/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.8849 - reconstruction_loss: 8.0504 - kl_loss: 10.8206 - val_loss: 12.5022 - val_reconstruction_loss: 2.9025 - val_kl_loss: 9.5996
# Epoch 47/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.7960 - reconstruction_loss: 8.0307 - kl_loss: 10.8251 - val_loss: 13.3895 - val_reconstruction_loss: 2.6400 - val_kl_loss: 10.7495
# Epoch 48/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.5191 - reconstruction_loss: 7.8962 - kl_loss: 10.7813 - val_loss: 15.8740 - val_reconstruction_loss: 4.7674 - val_kl_loss: 11.1066
# Epoch 49/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.7663 - reconstruction_loss: 7.8555 - kl_loss: 10.8479 - val_loss: 19.5579 - val_reconstruction_loss: 8.7872 - val_kl_loss: 10.7707
# Epoch 50/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.7254 - reconstruction_loss: 7.8777 - kl_loss: 10.8368 - val_loss: 16.4459 - val_reconstruction_loss: 4.7743 - val_kl_loss: 11.6716
# Epoch 51/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.7712 - reconstruction_loss: 7.8265 - kl_loss: 10.8903 - val_loss: 19.7660 - val_reconstruction_loss: 8.7751 - val_kl_loss: 10.9909
# Epoch 52/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.7207 - reconstruction_loss: 7.7495 - kl_loss: 10.8852 - val_loss: 22.5553 - val_reconstruction_loss: 10.6694 - val_kl_loss: 11.8858
# Epoch 53/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.5280 - reconstruction_loss: 7.7581 - kl_loss: 10.9001 - val_loss: 16.4388 - val_reconstruction_loss: 4.5856 - val_kl_loss: 11.8532
# Epoch 54/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.5090 - reconstruction_loss: 7.5688 - kl_loss: 10.8862 - val_loss: 13.4945 - val_reconstruction_loss: 2.7627 - val_kl_loss: 10.7319
# Epoch 55/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.4944 - reconstruction_loss: 7.6533 - kl_loss: 10.8576 - val_loss: 17.5062 - val_reconstruction_loss: 7.0714 - val_kl_loss: 10.4348
# Epoch 56/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.4650 - reconstruction_loss: 7.5929 - kl_loss: 10.8319 - val_loss: 11.1377 - val_reconstruction_loss: 1.7469 - val_kl_loss: 9.3908
# Epoch 57/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.4103 - reconstruction_loss: 7.6386 - kl_loss: 10.8790 - val_loss: 15.6949 - val_reconstruction_loss: 5.4401 - val_kl_loss: 10.2548
# Epoch 58/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.4348 - reconstruction_loss: 7.5654 - kl_loss: 10.8496 - val_loss: 18.1332 - val_reconstruction_loss: 8.4260 - val_kl_loss: 9.7072
# Epoch 59/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.4068 - reconstruction_loss: 7.5965 - kl_loss: 10.8579 - val_loss: 20.5345 - val_reconstruction_loss: 8.7122 - val_kl_loss: 11.8223
# Epoch 60/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.2878 - reconstruction_loss: 7.4681 - kl_loss: 10.8705 - val_loss: 18.3904 - val_reconstruction_loss: 6.6932 - val_kl_loss: 11.6971
# Epoch 61/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.3977 - reconstruction_loss: 7.4125 - kl_loss: 10.8970 - val_loss: 13.5180 - val_reconstruction_loss: 2.2977 - val_kl_loss: 11.2203
# Epoch 62/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.5012 - reconstruction_loss: 7.5267 - kl_loss: 10.9609 - val_loss: 14.7456 - val_reconstruction_loss: 3.1281 - val_kl_loss: 11.6176
# Epoch 63/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.4593 - reconstruction_loss: 7.4306 - kl_loss: 10.9232 - val_loss: 26.0221 - val_reconstruction_loss: 14.5299 - val_kl_loss: 11.4921
# Epoch 64/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.4189 - reconstruction_loss: 7.5067 - kl_loss: 10.9110 - val_loss: 16.8580 - val_reconstruction_loss: 6.0784 - val_kl_loss: 10.7796
# Epoch 65/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.1732 - reconstruction_loss: 7.2770 - kl_loss: 10.9162 - val_loss: 17.2714 - val_reconstruction_loss: 5.5481 - val_kl_loss: 11.7233
# Epoch 66/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.3334 - reconstruction_loss: 7.3406 - kl_loss: 10.8965 - val_loss: 13.4608 - val_reconstruction_loss: 3.7928 - val_kl_loss: 9.6680
# Epoch 67/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.1127 - reconstruction_loss: 7.2145 - kl_loss: 10.9292 - val_loss: 15.4651 - val_reconstruction_loss: 3.8577 - val_kl_loss: 11.6074
# Epoch 68/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.3683 - reconstruction_loss: 7.3674 - kl_loss: 10.8998 - val_loss: 14.5614 - val_reconstruction_loss: 3.4564 - val_kl_loss: 11.1050
# Epoch 69/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.2316 - reconstruction_loss: 7.3913 - kl_loss: 10.8874 - val_loss: 21.1693 - val_reconstruction_loss: 9.9206 - val_kl_loss: 11.2488
# Epoch 70/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.1492 - reconstruction_loss: 7.1939 - kl_loss: 10.9199 - val_loss: 17.0520 - val_reconstruction_loss: 6.5459 - val_kl_loss: 10.5061
# Epoch 71/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.1965 - reconstruction_loss: 7.2506 - kl_loss: 10.9146 - val_loss: 19.6304 - val_reconstruction_loss: 9.2753 - val_kl_loss: 10.3551
# Epoch 72/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.1880 - reconstruction_loss: 7.2394 - kl_loss: 10.9699 - val_loss: 13.5609 - val_reconstruction_loss: 3.1332 - val_kl_loss: 10.4277
# Epoch 73/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.0427 - reconstruction_loss: 7.1271 - kl_loss: 10.9414 - val_loss: 11.4903 - val_reconstruction_loss: 2.2954 - val_kl_loss: 9.1949
# Epoch 74/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.1041 - reconstruction_loss: 7.1203 - kl_loss: 10.9427 - val_loss: 21.2603 - val_reconstruction_loss: 9.3529 - val_kl_loss: 11.9074
# Epoch 75/100
# 549/549 [==============================] - 6s 11ms/step - loss: 17.9961 - reconstruction_loss: 7.1567 - kl_loss: 10.9322 - val_loss: 15.7223 - val_reconstruction_loss: 4.9626 - val_kl_loss: 10.7597
# Epoch 76/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.0090 - reconstruction_loss: 7.0649 - kl_loss: 10.9231 - val_loss: 13.6731 - val_reconstruction_loss: 2.2557 - val_kl_loss: 11.4173
# Epoch 77/100
# 549/549 [==============================] - 6s 11ms/step - loss: 17.9246 - reconstruction_loss: 7.0851 - kl_loss: 10.9517 - val_loss: 21.1962 - val_reconstruction_loss: 10.2140 - val_kl_loss: 10.9822
# Epoch 78/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.1543 - reconstruction_loss: 7.1480 - kl_loss: 10.9412 - val_loss: 14.7176 - val_reconstruction_loss: 4.6424 - val_kl_loss: 10.0752
# Epoch 79/100
# 549/549 [==============================] - 6s 11ms/step - loss: 17.8562 - reconstruction_loss: 7.0483 - kl_loss: 10.9125 - val_loss: 17.5543 - val_reconstruction_loss: 6.1712 - val_kl_loss: 11.3831
# Epoch 80/100
# 549/549 [==============================] - 6s 11ms/step - loss: 17.9627 - reconstruction_loss: 7.0569 - kl_loss: 10.9829 - val_loss: 18.2591 - val_reconstruction_loss: 6.0355 - val_kl_loss: 12.2236
# Epoch 81/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.0881 - reconstruction_loss: 7.0704 - kl_loss: 10.9530 - val_loss: 15.7219 - val_reconstruction_loss: 6.4274 - val_kl_loss: 9.2945
# Epoch 82/100
# 549/549 [==============================] - 6s 11ms/step - loss: 17.9190 - reconstruction_loss: 6.9804 - kl_loss: 10.9421 - val_loss: 19.9676 - val_reconstruction_loss: 8.9096 - val_kl_loss: 11.0580
# Epoch 83/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.0116 - reconstruction_loss: 6.9471 - kl_loss: 10.9637 - val_loss: 12.1578 - val_reconstruction_loss: 2.0511 - val_kl_loss: 10.1067
# Epoch 84/100
# 549/549 [==============================] - 6s 11ms/step - loss: 18.0328 - reconstruction_loss: 6.9962 - kl_loss: 10.9910 - val_loss: 18.7500 - val_reconstruction_loss: 7.6380 - val_kl_loss: 11.1120
# Epoch 85/100
# 549/549 [==============================] - 6s 11ms/step - loss: 17.8129 - reconstruction_loss: 6.9143 - kl_loss: 10.9507 - val_loss: 15.4473 - val_reconstruction_loss: 3.7885 - val_kl_loss: 11.6588
# Epoch 86/100
# 549/549 [==============================] - 6s 11ms/step - loss: 17.8749 - reconstruction_loss: 6.9672 - kl_loss: 10.9234 - val_loss: 21.2429 - val_reconstruction_loss: 8.9541 - val_kl_loss: 12.2888

# %%
val_rec_loss = history.history['val_reconstruction_loss']
rec_loss = history.history['reconstruction_loss']

epochs = range(1, len(val_rec_loss) + 1)    

plt.plot(epochs, val_rec_loss, 'b', label='Val Reconstruction loss')
plt.plot(epochs, rec_loss, 'bo', label='Reconstruction loss')
plt.title('Reconstruction and KL loss')
plt.legend()

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

'''
for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE)
    img = img_to_array(load_img(f"images_trans/pong_trans_{rand_img}.png", color_mode='grayscale'))
    images[i] = img
    '''

for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE-10)
    img = img_to_array(load_img(f"images_trans/pong_trans_{rand_img}.png", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# /home/loptt/.local/lib/python3.8/site-packages/matplotlib/image.py:446: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /home/loptt/.local/lib/python3.8/site-packages/matplotlib/image.py:453: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /home/loptt/.local/lib/python3.8/site-packages/matplotlib/image.py:458: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 100.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [i*10 for i in range(-7, 7)]
            # missing =  -2.9679005e+00, -1.7151514e+01    
            z_sample = np.array([[xi, yi] + rest])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)

# %%
vae.model.save("models/vae")
# Out:
# INFO:tensorflow:Assets written to: models/vae/assets
