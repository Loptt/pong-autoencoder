# %% [markdown]
# ## Variational Autoencoder

# %%
# Windows config
import os
os.add_dll_directory("C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA/v11.4/bin")
# Out:
# <AddedDllDirectory('C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA/v11.4/bin')>

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAE

DATASET_SIZE = 25084
INPUT_SHAPE = (40, 40, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    raise Exception("Cannot initialize GPU")

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training'
)

val_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation'
)
# Out:
# Found 17559 images belonging to 1 classes.
# Found 7524 images belonging to 1 classes.

# %%
vae = VAE(
    layers=4,
    latent_size=16,
    kernel_size=3,
    filters=16,
    input_shape=INPUT_SHAPE,
    name="VAE"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 40, 40, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 40, 40, 16)   160         input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 20, 20, 16)   0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 20, 20, 32)   4640        maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 10, 10, 32)   0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 10, 10, 64)   18496       maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 5, 5, 64)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 5, 5, 128)    73856       maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 3, 3, 128)    0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1152)         0           maxpool4[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 16)           18448       flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling_1 (Sampling)           (None, 16)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 116,144
# Trainable params: 116,144
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 16)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 1152)              19584
# _________________________________________________________________
# reshape (Reshape)            (None, 3, 3, 128)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 6, 6, 128)         0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 6, 6, 64)          73792
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 12, 12, 32)        18464
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 24, 24, 32)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 24, 24, 16)        4624
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 48, 48, 16)        0
# _________________________________________________________________
# output (Conv2D)              (None, 40, 40, 1)         1297
# =================================================================
# Total params: 265,345
# Trainable params: 265,345
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 16), (None, 16),  116144
# _________________________________________________________________
# Decoder (Functional)         (None, 40, 40, 1)         265345
# =================================================================
# Total params: 381,495
# Trainable params: 381,489
# Non-trainable params: 6
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=20),
    TensorBoard(
        log_dir='./logs',
        histogram_freq=1
    )
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=100, 
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 549/549 [==============================] - 7s 11ms/step - loss: 111.8699 - reconstruction_loss: 65.2833 - kl_loss: 4.1414 - val_loss: 28.3838 - val_reconstruction_loss: 17.7833 - val_kl_loss: 10.6005
# Epoch 2/100
# 549/549 [==============================] - 6s 10ms/step - loss: 32.8682 - reconstruction_loss: 19.8813 - kl_loss: 10.6999 - val_loss: 26.6221 - val_reconstruction_loss: 16.9298 - val_kl_loss: 9.6923
# Epoch 3/100
# 549/549 [==============================] - 6s 10ms/step - loss: 26.3905 - reconstruction_loss: 15.2999 - kl_loss: 10.5484 - val_loss: 20.1421 - val_reconstruction_loss: 9.2622 - val_kl_loss: 10.8800
# Epoch 4/100
# 549/549 [==============================] - 6s 10ms/step - loss: 24.7806 - reconstruction_loss: 13.9761 - kl_loss: 10.5992 - val_loss: 27.3251 - val_reconstruction_loss: 16.7593 - val_kl_loss: 10.5658
# Epoch 5/100
# 549/549 [==============================] - 6s 10ms/step - loss: 23.8334 - reconstruction_loss: 12.9327 - kl_loss: 10.7069 - val_loss: 28.2178 - val_reconstruction_loss: 16.3865 - val_kl_loss: 11.8314
# Epoch 6/100
# 549/549 [==============================] - 6s 10ms/step - loss: 23.3184 - reconstruction_loss: 12.4715 - kl_loss: 10.7635 - val_loss: 24.2414 - val_reconstruction_loss: 12.7662 - val_kl_loss: 11.4752
# Epoch 7/100
# 549/549 [==============================] - 6s 10ms/step - loss: 22.8935 - reconstruction_loss: 12.0180 - kl_loss: 10.7955 - val_loss: 30.9279 - val_reconstruction_loss: 19.5989 - val_kl_loss: 11.3290
# Epoch 8/100
# 549/549 [==============================] - 6s 10ms/step - loss: 22.4821 - reconstruction_loss: 11.6438 - kl_loss: 10.7785 - val_loss: 17.9669 - val_reconstruction_loss: 6.9043 - val_kl_loss: 11.0626
# Epoch 9/100
# 549/549 [==============================] - 6s 10ms/step - loss: 22.1509 - reconstruction_loss: 11.3621 - kl_loss: 10.7878 - val_loss: 21.3841 - val_reconstruction_loss: 9.9379 - val_kl_loss: 11.4462
# Epoch 10/100
# 549/549 [==============================] - 6s 10ms/step - loss: 21.8223 - reconstruction_loss: 11.0937 - kl_loss: 10.7686 - val_loss: 25.9150 - val_reconstruction_loss: 14.0061 - val_kl_loss: 11.9089
# Epoch 11/100
# 549/549 [==============================] - 6s 10ms/step - loss: 21.8475 - reconstruction_loss: 10.9101 - kl_loss: 10.7787 - val_loss: 20.7213 - val_reconstruction_loss: 9.8085 - val_kl_loss: 10.9127
# Epoch 12/100
# 549/549 [==============================] - 6s 10ms/step - loss: 21.6727 - reconstruction_loss: 10.7537 - kl_loss: 10.7908 - val_loss: 17.9746 - val_reconstruction_loss: 7.0118 - val_kl_loss: 10.9628
# Epoch 13/100
# 549/549 [==============================] - 6s 10ms/step - loss: 21.4184 - reconstruction_loss: 10.6044 - kl_loss: 10.8015 - val_loss: 24.0879 - val_reconstruction_loss: 12.8418 - val_kl_loss: 11.2461
# Epoch 14/100
# 549/549 [==============================] - 5s 10ms/step - loss: 21.1793 - reconstruction_loss: 10.4444 - kl_loss: 10.7670 - val_loss: 20.6022 - val_reconstruction_loss: 9.0785 - val_kl_loss: 11.5237
# Epoch 15/100
# 549/549 [==============================] - 6s 10ms/step - loss: 20.9728 - reconstruction_loss: 10.1473 - kl_loss: 10.8064 - val_loss: 18.4120 - val_reconstruction_loss: 8.1315 - val_kl_loss: 10.2805
# Epoch 16/100
# 549/549 [==============================] - 6s 10ms/step - loss: 20.9960 - reconstruction_loss: 10.1595 - kl_loss: 10.8031 - val_loss: 19.6770 - val_reconstruction_loss: 8.0044 - val_kl_loss: 11.6727
# Epoch 17/100
# 549/549 [==============================] - 6s 10ms/step - loss: 20.7439 - reconstruction_loss: 9.9491 - kl_loss: 10.8185 - val_loss: 14.3186 - val_reconstruction_loss: 3.8832 - val_kl_loss: 10.4354
# Epoch 18/100
# 549/549 [==============================] - 6s 10ms/step - loss: 20.7775 - reconstruction_loss: 9.8881 - kl_loss: 10.7829 - val_loss: 21.7380 - val_reconstruction_loss: 11.4590 - val_kl_loss: 10.2790
# Epoch 19/100
# 549/549 [==============================] - 6s 10ms/step - loss: 20.5465 - reconstruction_loss: 9.7065 - kl_loss: 10.7959 - val_loss: 22.7337 - val_reconstruction_loss: 11.6540 - val_kl_loss: 11.0797
# Epoch 20/100
# 549/549 [==============================] - 6s 10ms/step - loss: 20.3774 - reconstruction_loss: 9.6552 - kl_loss: 10.7884 - val_loss: 23.8877 - val_reconstruction_loss: 12.7875 - val_kl_loss: 11.1002
# Epoch 21/100
# 549/549 [==============================] - 6s 10ms/step - loss: 20.3704 - reconstruction_loss: 9.5598 - kl_loss: 10.7912 - val_loss: 20.1792 - val_reconstruction_loss: 9.6848 - val_kl_loss: 10.4944
# Epoch 22/100
# 549/549 [==============================] - 6s 10ms/step - loss: 20.1521 - reconstruction_loss: 9.4630 - kl_loss: 10.8120 - val_loss: 23.1222 - val_reconstruction_loss: 13.0618 - val_kl_loss: 10.0604
# Epoch 23/100
# 549/549 [==============================] - 6s 10ms/step - loss: 20.2417 - reconstruction_loss: 9.4179 - kl_loss: 10.8191 - val_loss: 21.4978 - val_reconstruction_loss: 10.7338 - val_kl_loss: 10.7640
# Epoch 24/100
# 549/549 [==============================] - 6s 10ms/step - loss: 20.0643 - reconstruction_loss: 9.2698 - kl_loss: 10.8188 - val_loss: 17.9505 - val_reconstruction_loss: 6.5567 - val_kl_loss: 11.3938
# Epoch 25/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.9310 - reconstruction_loss: 9.1897 - kl_loss: 10.8842 - val_loss: 17.0638 - val_reconstruction_loss: 6.3551 - val_kl_loss: 10.7087
# Epoch 26/100
# 549/549 [==============================] - 5s 10ms/step - loss: 19.9793 - reconstruction_loss: 9.1662 - kl_loss: 10.7903 - val_loss: 14.2787 - val_reconstruction_loss: 4.3118 - val_kl_loss: 9.9668
# Epoch 27/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.8852 - reconstruction_loss: 9.0130 - kl_loss: 10.8331 - val_loss: 22.4257 - val_reconstruction_loss: 11.5108 - val_kl_loss: 10.9150
# Epoch 28/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.7868 - reconstruction_loss: 8.9273 - kl_loss: 10.8604 - val_loss: 24.6374 - val_reconstruction_loss: 13.4718 - val_kl_loss: 11.1656
# Epoch 29/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.8955 - reconstruction_loss: 8.9060 - kl_loss: 10.8683 - val_loss: 18.1000 - val_reconstruction_loss: 7.6066 - val_kl_loss: 10.4935
# Epoch 30/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.7811 - reconstruction_loss: 8.8855 - kl_loss: 10.8384 - val_loss: 23.8549 - val_reconstruction_loss: 12.1076 - val_kl_loss: 11.7474
# Epoch 31/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.7641 - reconstruction_loss: 8.8327 - kl_loss: 10.8095 - val_loss: 34.6864 - val_reconstruction_loss: 23.3214 - val_kl_loss: 11.3650
# Epoch 32/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.5143 - reconstruction_loss: 8.6544 - kl_loss: 10.8422 - val_loss: 17.3239 - val_reconstruction_loss: 6.2525 - val_kl_loss: 11.0714
# Epoch 33/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.4537 - reconstruction_loss: 8.6617 - kl_loss: 10.8226 - val_loss: 19.0182 - val_reconstruction_loss: 7.7422 - val_kl_loss: 11.2760
# Epoch 34/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.5171 - reconstruction_loss: 8.5403 - kl_loss: 10.8917 - val_loss: 15.6723 - val_reconstruction_loss: 4.9039 - val_kl_loss: 10.7685
# Epoch 35/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.3864 - reconstruction_loss: 8.5625 - kl_loss: 10.8343 - val_loss: 20.0808 - val_reconstruction_loss: 9.3632 - val_kl_loss: 10.7176
# Epoch 36/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.4246 - reconstruction_loss: 8.5193 - kl_loss: 10.8678 - val_loss: 14.3655 - val_reconstruction_loss: 3.6087 - val_kl_loss: 10.7568
# Epoch 37/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.1748 - reconstruction_loss: 8.3913 - kl_loss: 10.8831 - val_loss: 18.9464 - val_reconstruction_loss: 8.1158 - val_kl_loss: 10.8306
# Epoch 38/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.1675 - reconstruction_loss: 8.3805 - kl_loss: 10.9080 - val_loss: 22.2086 - val_reconstruction_loss: 10.6136 - val_kl_loss: 11.5950
# Epoch 39/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.1253 - reconstruction_loss: 8.2216 - kl_loss: 10.8849 - val_loss: 17.9607 - val_reconstruction_loss: 6.8886 - val_kl_loss: 11.0721
# Epoch 40/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.8697 - reconstruction_loss: 8.1679 - kl_loss: 10.8584 - val_loss: 16.5260 - val_reconstruction_loss: 4.9420 - val_kl_loss: 11.5840
# Epoch 41/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.0776 - reconstruction_loss: 8.1635 - kl_loss: 10.9027 - val_loss: 12.9964 - val_reconstruction_loss: 3.0368 - val_kl_loss: 9.9596
# Epoch 42/100
# 549/549 [==============================] - 6s 10ms/step - loss: 19.0585 - reconstruction_loss: 8.1114 - kl_loss: 10.9252 - val_loss: 12.7100 - val_reconstruction_loss: 2.3117 - val_kl_loss: 10.3983
# Epoch 43/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.9382 - reconstruction_loss: 8.1777 - kl_loss: 10.8515 - val_loss: 18.7627 - val_reconstruction_loss: 7.8752 - val_kl_loss: 10.8875
# Epoch 44/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.8878 - reconstruction_loss: 8.0269 - kl_loss: 10.9065 - val_loss: 15.1984 - val_reconstruction_loss: 3.6601 - val_kl_loss: 11.5383
# Epoch 45/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.7970 - reconstruction_loss: 7.9266 - kl_loss: 10.9123 - val_loss: 15.2987 - val_reconstruction_loss: 5.0640 - val_kl_loss: 10.2347
# Epoch 46/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.8163 - reconstruction_loss: 7.9465 - kl_loss: 10.9399 - val_loss: 16.7954 - val_reconstruction_loss: 5.6435 - val_kl_loss: 11.1519
# Epoch 47/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.7557 - reconstruction_loss: 7.8953 - kl_loss: 10.9083 - val_loss: 13.1286 - val_reconstruction_loss: 2.8249 - val_kl_loss: 10.3037
# Epoch 48/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.8956 - reconstruction_loss: 7.9271 - kl_loss: 10.9866 - val_loss: 13.0478 - val_reconstruction_loss: 2.8167 - val_kl_loss: 10.2311
# Epoch 49/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.7581 - reconstruction_loss: 7.8246 - kl_loss: 10.9768 - val_loss: 20.5803 - val_reconstruction_loss: 9.6437 - val_kl_loss: 10.9366
# Epoch 50/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.7505 - reconstruction_loss: 7.7850 - kl_loss: 10.9041 - val_loss: 18.2241 - val_reconstruction_loss: 7.6008 - val_kl_loss: 10.6233
# Epoch 51/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.5315 - reconstruction_loss: 7.7090 - kl_loss: 10.9337 - val_loss: 17.3177 - val_reconstruction_loss: 6.7662 - val_kl_loss: 10.5514
# Epoch 52/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.5511 - reconstruction_loss: 7.6557 - kl_loss: 10.9606 - val_loss: 20.5515 - val_reconstruction_loss: 9.3634 - val_kl_loss: 11.1881
# Epoch 53/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.7066 - reconstruction_loss: 7.7159 - kl_loss: 10.9554 - val_loss: 15.4552 - val_reconstruction_loss: 6.1753 - val_kl_loss: 9.2799
# Epoch 54/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.4721 - reconstruction_loss: 7.5907 - kl_loss: 10.9134 - val_loss: 15.6402 - val_reconstruction_loss: 4.7293 - val_kl_loss: 10.9109
# Epoch 55/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.6309 - reconstruction_loss: 7.5870 - kl_loss: 10.9805 - val_loss: 13.9101 - val_reconstruction_loss: 3.0764 - val_kl_loss: 10.8337
# Epoch 56/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.4411 - reconstruction_loss: 7.5550 - kl_loss: 10.9473 - val_loss: 16.4565 - val_reconstruction_loss: 5.2690 - val_kl_loss: 11.1875
# Epoch 57/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.4738 - reconstruction_loss: 7.5191 - kl_loss: 10.9459 - val_loss: 13.7129 - val_reconstruction_loss: 2.5384 - val_kl_loss: 11.1745
# Epoch 58/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.4163 - reconstruction_loss: 7.4587 - kl_loss: 10.9712 - val_loss: 22.1209 - val_reconstruction_loss: 11.7218 - val_kl_loss: 10.3990
# Epoch 59/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.2708 - reconstruction_loss: 7.4399 - kl_loss: 10.9748 - val_loss: 14.1558 - val_reconstruction_loss: 4.2278 - val_kl_loss: 9.9281
# Epoch 60/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.3956 - reconstruction_loss: 7.4262 - kl_loss: 10.9610 - val_loss: 12.7106 - val_reconstruction_loss: 2.6841 - val_kl_loss: 10.0265
# Epoch 61/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.4674 - reconstruction_loss: 7.4569 - kl_loss: 10.9961 - val_loss: 27.1888 - val_reconstruction_loss: 15.7275 - val_kl_loss: 11.4614
# Epoch 62/100
# 549/549 [==============================] - 5s 10ms/step - loss: 18.3327 - reconstruction_loss: 7.4290 - kl_loss: 10.9620 - val_loss: 20.0316 - val_reconstruction_loss: 7.9082 - val_kl_loss: 12.1234
# Epoch 63/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.3003 - reconstruction_loss: 7.3297 - kl_loss: 10.9996 - val_loss: 21.9092 - val_reconstruction_loss: 9.8971 - val_kl_loss: 12.0121
# Epoch 64/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.3258 - reconstruction_loss: 7.3257 - kl_loss: 10.9682 - val_loss: 23.6387 - val_reconstruction_loss: 13.7968 - val_kl_loss: 9.8419
# Epoch 65/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.3540 - reconstruction_loss: 7.2347 - kl_loss: 10.9889 - val_loss: 16.1190 - val_reconstruction_loss: 5.6339 - val_kl_loss: 10.4852
# Epoch 66/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.3112 - reconstruction_loss: 7.3122 - kl_loss: 11.0416 - val_loss: 14.7546 - val_reconstruction_loss: 3.7693 - val_kl_loss: 10.9853
# Epoch 67/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.1850 - reconstruction_loss: 7.2387 - kl_loss: 10.9585 - val_loss: 16.4578 - val_reconstruction_loss: 5.9412 - val_kl_loss: 10.5166
# Epoch 68/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.3862 - reconstruction_loss: 7.2778 - kl_loss: 11.0054 - val_loss: 18.1843 - val_reconstruction_loss: 8.0387 - val_kl_loss: 10.1456
# Epoch 69/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.3458 - reconstruction_loss: 7.2387 - kl_loss: 11.0432 - val_loss: 17.3290 - val_reconstruction_loss: 6.6348 - val_kl_loss: 10.6942
# Epoch 70/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.2683 - reconstruction_loss: 7.2829 - kl_loss: 11.0433 - val_loss: 19.1227 - val_reconstruction_loss: 7.0779 - val_kl_loss: 12.0448
# Epoch 71/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.1400 - reconstruction_loss: 7.1633 - kl_loss: 10.9964 - val_loss: 20.4744 - val_reconstruction_loss: 8.4074 - val_kl_loss: 12.0670
# Epoch 72/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.2151 - reconstruction_loss: 7.1518 - kl_loss: 11.0138 - val_loss: 17.9010 - val_reconstruction_loss: 7.6124 - val_kl_loss: 10.2886
# Epoch 73/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.2988 - reconstruction_loss: 7.1458 - kl_loss: 10.9995 - val_loss: 14.0051 - val_reconstruction_loss: 3.2040 - val_kl_loss: 10.8010
# Epoch 74/100
# 549/549 [==============================] - 5s 10ms/step - loss: 18.0932 - reconstruction_loss: 7.1205 - kl_loss: 10.9367 - val_loss: 17.5527 - val_reconstruction_loss: 6.4873 - val_kl_loss: 11.0654
# Epoch 75/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.0418 - reconstruction_loss: 7.0672 - kl_loss: 10.9838 - val_loss: 20.2495 - val_reconstruction_loss: 8.9872 - val_kl_loss: 11.2623
# Epoch 76/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.1390 - reconstruction_loss: 7.1177 - kl_loss: 11.0595 - val_loss: 23.2470 - val_reconstruction_loss: 11.5605 - val_kl_loss: 11.6865
# Epoch 77/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.1195 - reconstruction_loss: 7.1053 - kl_loss: 10.9689 - val_loss: 17.8709 - val_reconstruction_loss: 6.7497 - val_kl_loss: 11.1212
# Epoch 78/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.0152 - reconstruction_loss: 7.0491 - kl_loss: 10.9477 - val_loss: 19.8835 - val_reconstruction_loss: 8.0014 - val_kl_loss: 11.8821
# Epoch 79/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.0141 - reconstruction_loss: 7.0415 - kl_loss: 10.9971 - val_loss: 16.6172 - val_reconstruction_loss: 6.0212 - val_kl_loss: 10.5960
# Epoch 80/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.9468 - reconstruction_loss: 6.9942 - kl_loss: 11.0438 - val_loss: 20.9852 - val_reconstruction_loss: 9.5999 - val_kl_loss: 11.3853
# Epoch 81/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.0498 - reconstruction_loss: 7.0364 - kl_loss: 11.0310 - val_loss: 16.7925 - val_reconstruction_loss: 5.4897 - val_kl_loss: 11.3027
# Epoch 82/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.9884 - reconstruction_loss: 7.0107 - kl_loss: 11.0508 - val_loss: 17.4023 - val_reconstruction_loss: 7.1671 - val_kl_loss: 10.2352
# Epoch 83/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.9818 - reconstruction_loss: 6.9593 - kl_loss: 11.0249 - val_loss: 16.5035 - val_reconstruction_loss: 4.4659 - val_kl_loss: 12.0375
# Epoch 84/100
# 549/549 [==============================] - 5s 10ms/step - loss: 17.9883 - reconstruction_loss: 6.9769 - kl_loss: 11.0232 - val_loss: 22.4362 - val_reconstruction_loss: 11.1439 - val_kl_loss: 11.2922
# Epoch 85/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.0596 - reconstruction_loss: 7.0035 - kl_loss: 11.0456 - val_loss: 18.8274 - val_reconstruction_loss: 6.2958 - val_kl_loss: 12.5316
# Epoch 86/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.9449 - reconstruction_loss: 6.9732 - kl_loss: 10.9814 - val_loss: 15.9733 - val_reconstruction_loss: 4.1707 - val_kl_loss: 11.8025
# Epoch 87/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.9161 - reconstruction_loss: 6.9001 - kl_loss: 11.0072 - val_loss: 15.3616 - val_reconstruction_loss: 5.5191 - val_kl_loss: 9.8425
# Epoch 88/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.8611 - reconstruction_loss: 6.9422 - kl_loss: 11.0301 - val_loss: 18.2476 - val_reconstruction_loss: 6.7043 - val_kl_loss: 11.5434
# Epoch 89/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.0931 - reconstruction_loss: 6.9211 - kl_loss: 11.0139 - val_loss: 14.9135 - val_reconstruction_loss: 3.8939 - val_kl_loss: 11.0197
# Epoch 90/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.9866 - reconstruction_loss: 6.9361 - kl_loss: 11.0594 - val_loss: 15.7529 - val_reconstruction_loss: 5.2510 - val_kl_loss: 10.5020
# Epoch 91/100
# 549/549 [==============================] - 5s 10ms/step - loss: 17.9486 - reconstruction_loss: 6.9307 - kl_loss: 11.0707 - val_loss: 11.7566 - val_reconstruction_loss: 2.0623 - val_kl_loss: 9.6943
# Epoch 92/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.9586 - reconstruction_loss: 6.8352 - kl_loss: 11.0177 - val_loss: 15.8663 - val_reconstruction_loss: 4.6744 - val_kl_loss: 11.1919
# Epoch 93/100
# 549/549 [==============================] - 6s 10ms/step - loss: 18.1059 - reconstruction_loss: 6.8974 - kl_loss: 11.0697 - val_loss: 16.8681 - val_reconstruction_loss: 4.5049 - val_kl_loss: 12.3632
# Epoch 94/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.8783 - reconstruction_loss: 6.8242 - kl_loss: 11.0685 - val_loss: 21.8954 - val_reconstruction_loss: 9.2764 - val_kl_loss: 12.6190
# Epoch 95/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.8467 - reconstruction_loss: 6.8888 - kl_loss: 10.9775 - val_loss: 18.2711 - val_reconstruction_loss: 6.1442 - val_kl_loss: 12.1269
# Epoch 96/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.7355 - reconstruction_loss: 6.8785 - kl_loss: 10.9719 - val_loss: 11.0800 - val_reconstruction_loss: 2.0719 - val_kl_loss: 9.0081
# Epoch 97/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.7106 - reconstruction_loss: 6.8332 - kl_loss: 11.0020 - val_loss: 15.6416 - val_reconstruction_loss: 5.5947 - val_kl_loss: 10.0469
# Epoch 98/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.8028 - reconstruction_loss: 6.8142 - kl_loss: 10.9877 - val_loss: 22.8365 - val_reconstruction_loss: 12.0355 - val_kl_loss: 10.8009
# Epoch 99/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.9099 - reconstruction_loss: 6.8307 - kl_loss: 11.0246 - val_loss: 19.8006 - val_reconstruction_loss: 7.9003 - val_kl_loss: 11.9003
# Epoch 100/100
# 549/549 [==============================] - 6s 10ms/step - loss: 17.7659 - reconstruction_loss: 6.8103 - kl_loss: 11.0377 - val_loss: 15.3340 - val_reconstruction_loss: 4.7763 - val_kl_loss: 10.5576

# %%
val_rec_loss = history.history['val_reconstruction_loss']
rec_loss = history.history['reconstruction_loss']

epochs = range(1, len(val_rec_loss) + 1)    

plt.figure(figsize=(8,6), dpi=80)

plt.plot(epochs, val_rec_loss, 'r', label='Val Reconstruction loss')
plt.plot(epochs, rec_loss, 'b', label='Reconstruction loss')
plt.title('VAE Training')
plt.legend()

plt.title('Reconstruction loss')
plt.ylabel('Loss')
plt.xlabel("Epochs")
plt.gca().set_ylim([0,60])
#plt.gca().set_ylim([0, 20])
plt.legend()

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

'''
for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE)
    img = img_to_array(load_img(f"images_trans/pong_trans_{rand_img}.png", color_mode='grayscale'))
    images[i] = img
    '''

for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE-10)
    img = img_to_array(load_img(f"images_trans/pong_trans_{rand_img}.png", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 100.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [i*10 for i in range(-7, 7)]
            # missing =  -2.9679005e+00, -1.7151514e+01    
            z_sample = np.array([[xi, yi] + rest])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)

# %%
#vae.model.save("models/vae")
