# %% [markdown]
# ## Variational Autoencoder

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAE

DATASET_SIZE = 25084
INPUT_SHAPE = (20, 20, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    raise Exception("Cannot initialize GPU")

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_ballless/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training'
)

val_datagen = datagen.flow_from_directory(
    'images_ballless/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation'
)
# Out:
# Found 17559 images belonging to 1 classes.
# Found 7524 images belonging to 1 classes.

# %%
vae = VAE(
    layers=4,
    latent_size=16,
    kernel_size=5,
    filters=16,
    input_shape=INPUT_SHAPE,
    name="VAE"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 20, 20, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 20, 20, 16)   416         input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 10, 10, 16)   0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 10, 10, 32)   12832       maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 5, 5, 32)     0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 5, 5, 64)     51264       maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 3, 3, 64)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 3, 3, 128)    204928      maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 2, 2, 128)    0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           maxpool4[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 16)           8208        flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling_3 (Sampling)           (None, 16)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 278,192
# Trainable params: 278,192
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 16)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 512)               8704
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 2, 128)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 2, 2, 128)         409728
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 4, 4, 128)         0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 4, 4, 64)          204864
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 8, 8, 32)          51232
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 16, 16, 32)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 16, 16, 16)        12816
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 32, 32, 16)        0
# _________________________________________________________________
# output (Conv2D)              (None, 20, 20, 1)         2705
# =================================================================
# Total params: 690,049
# Trainable params: 690,049
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 16), (None, 16),  278192
# _________________________________________________________________
# Decoder (Functional)         (None, 20, 20, 1)         690049
# =================================================================
# Total params: 968,247
# Trainable params: 968,241
# Non-trainable params: 6
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=
50
# 549/549 [==============================] - 6s 11ms/step - loss: 10.8795 - reconstruction_loss: 1.9480 - kl_loss: 8.8462 - val_loss: 13.0277 - val_reconstruction_loss: 4.5602 - val_kl_loss: 8.4675
# Epoch 32/50
# 549/549 [==============================] - 6s 11ms/step - loss: 10.7926 - reconstruction_loss: 1.8910 - kl_loss: 8.8356 - val_loss: 10.6573 - val_reconstruction_loss: 1.8027 - val_kl_loss: 8.8546
# Epoch 33/50
# 549/549 [==============================] - 6s 11ms/step - loss: 10.8543 - reconstruction_loss: 1.8995 - kl_loss: 8.8829 - val_loss: 10.4924 - val_reconstruction_loss: 2.3649 - val_kl_loss: 8.1275
# Epoch 34/50
# 549/549 [==============================] - 6s 11ms/step - loss: 10.7435 - reconstruction_loss: 1.8443 - kl_loss: 8.8581 - val_loss: 13.2578 - val_reconstruction_loss: 4.0891 - val_kl_loss: 9.1687
# Epoch 35/50
# 549/549 [==============================] - 6s 11ms/step - loss: 10.6735 - reconstruction_loss: 1.8447 - kl_loss: 8.8184 - val_loss: 12.2612 - val_reconstruction_loss: 3.3835 - val_kl_loss: 8.8777

# %%
val_rec_loss = history.history['val_reconstruction_loss']
rec_loss = history.history['reconstruction_loss']

epochs = range(1, len(val_rec_loss) + 1)    

plt.plot(epochs, val_rec_loss, 'b', label='Val Reconstruction loss')
plt.plot(epochs, rec_loss, 'bo', label='Reconstruction loss')
plt.title('Reconstruction and KL loss')
plt.legend()

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

'''
for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE)
    img = img_to_array(load_img(f"images_ballless/pong_ballless_{rand_img}.png", color_mode='grayscale'))
    images[i] = img
    '''

for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE-10)
    img = img_to_array(load_img(f"images_ballless/pong_ballless_{rand_img}.png", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 100.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [i*10 for i in range(-7, 7)]
            # missing =  -2.9679005e+00, -1.7151514e+01    
            z_sample = np.array([[xi, yi] + rest])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)

# %%
vae.model.save("models/vae_ballless")
# Out:
# INFO:tensorflow:Assets written to: models/vae_ballless/assets
