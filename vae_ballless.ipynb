# %% [markdown]
# ## Variational Autoencoder

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAE

DATASET_SIZE = 25084
INPUT_SHAPE = (20, 20, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    #raise Exception("Cannot initialize GPU")
    pass

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_ballless/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training'
)

val_datagen = datagen.flow_from_directory(
    'images_ballless/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation'
)
# Out:
# Found 17559 images belonging to 1 classes.
# Found 7524 images belonging to 1 classes.

# %%
vae = VAE(
    layers=4,
    latent_size=16,
    kernel_size=5,
    filters=16,
    input_shape=INPUT_SHAPE,
    name="VAE"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 20, 20, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 20, 20, 16)   416         input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 10, 10, 16)   0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 10, 10, 32)   12832       maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 5, 5, 32)     0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 5, 5, 64)     51264       maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 3, 3, 64)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 3, 3, 128)    204928      maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 2, 2, 128)    0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           maxpool4[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 16)           8208        flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling_1 (Sampling)           (None, 16)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 278,192
# Trainable params: 278,192
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 16)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 512)               8704
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 2, 128)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 2, 2, 128)         409728
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 4, 4, 128)         0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 4, 4, 64)          204864
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 8, 8, 32)          51232
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 16, 16, 32)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 16, 16, 16)        12816
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 32, 32, 16)        0
# _________________________________________________________________
# output (Conv2D)              (None, 20, 20, 1)         2705
# =================================================================
# Total params: 690,049
# Trainable params: 690,049
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 16), (None, 16),  278192
# _________________________________________________________________
# Decoder (Functional)         (None, 20, 20, 1)         690049
# =================================================================
# Total params: 968,247
# Trainable params: 968,241
# Non-trainable params: 6
# _________________________________________________________________

# %%
callbacks = [
    #EarlyStopping(monitor='val_loss', patience=20),
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=100, 
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 549/549 [==============================] - 8s 12ms/step - loss: 53.0214 - reconstruction_loss: 43.7683 - kl_loss: 0.0039 - val_loss: 42.0115 - val_reconstruction_loss: 42.0107 - val_kl_loss: 7.9157e-04
# Epoch 2/100
# 549/549 [==============================] - 7s 12ms/step - loss: 39.0975 - reconstruction_loss: 32.7547 - kl_loss: 2.4499 - val_loss: 21.4154 - val_reconstruction_loss: 14.7078 - val_kl_loss: 6.7075
# Epoch 3/100
# 549/549 [==============================] - 7s 12ms/step - loss: 20.0956 - reconstruction_loss: 9.2732 - kl_loss: 7.9909 - val_loss: 12.0525 - val_reconstruction_loss: 3.5502 - val_kl_loss: 8.5023
# Epoch 4/100
# 549/549 [==============================] - 7s 12ms/step - loss: 13.8487 - reconstruction_loss: 4.7083 - kl_loss: 8.7563 - val_loss: 10.3577 - val_reconstruction_loss: 2.1846 - val_kl_loss: 8.1731
# Epoch 5/100
# 549/549 [==============================] - 6s 12ms/step - loss: 13.0043 - reconstruction_loss: 4.1567 - kl_loss: 8.8153 - val_loss: 12.3692 - val_reconstruction_loss: 3.1324 - val_kl_loss: 9.2368
# Epoch 6/100
# 549/549 [==============================] - 6s 12ms/step - loss: 12.6765 - reconstruction_loss: 3.8641 - kl_loss: 8.7659 - val_loss: 11.4030 - val_reconstruction_loss: 2.7428 - val_kl_loss: 8.6602
# Epoch 7/100
# 549/549 [==============================] - 6s 11ms/step - loss: 12.3649 - reconstruction_loss: 3.5860 - kl_loss: 8.7662 - val_loss: 12.3357 - val_reconstruction_loss: 3.2664 - val_kl_loss: 9.0692
# Epoch 8/100
# 549/549 [==============================] - 6s 11ms/step - loss: 12.0552 - reconstruction_loss: 3.3451 - kl_loss: 8.7381 - val_loss: 11.0978 - val_reconstruction_loss: 2.9443 - val_kl_loss: 8.1534
# Epoch 9/100
# 549/549 [==============================] - 6s 11ms/step - loss: 12.0195 - reconstruction_loss: 3.3481 - kl_loss: 8.6729 - val_loss: 17.2539 - val_reconstruction_loss: 8.8563 - val_kl_loss: 8.3976
# Epoch 10/100
# 549/549 [==============================] - 6s 11ms/step - loss: 11.9701 - reconstruction_loss: 3.2882 - kl_loss: 8.6656 - val_loss: 12.3007 - val_reconstruction_loss: 4.1227 - val_kl_loss: 8.1780
# Epoch 11/100
# 549/549 [==============================] - 6s 11ms/step - loss: 12.0026 - reconstruction_loss: 3.1810 - kl_loss: 8.6424 - val_loss: 11.8516 - val_reconstruction_loss: 2.7446 - val_kl_loss: 9.1070
# Epoch 12/100
# 549/549 [==============================] - 6s 11ms/step - loss: 11.7221 - reconstruction_loss: 3.0863 - kl_loss: 8.6201 - val_loss: 8.8733 - val_reconstruction_loss: 0.8938 - val_kl_loss: 7.9795
# Epoch 13/100
# 549/549 [==============================] - 6s 11ms/step - loss: 11.7287 - reconstruction_loss: 3.0088 - kl_loss: 8.6073 - val_loss: 9.1210 - val_reconstruction_loss: 1.2951 - val_kl_loss: 7.8258
# Epoch 14/100
# 549/549 [==============================] - 6s 11ms/step - loss: 11.4091 - reconstruction_loss: 2.9119 - kl_loss: 8.5372 - val_loss: 9.6480 - val_reconstruction_loss: 2.0438 - val_kl_loss: 7.6042
# Epoch 15/100
# 549/549 [==============================] - 6s 11ms/step - loss: 11.3472 - reconstruction_loss: 2.8042 - kl_loss: 8.5264 - val_loss: 11.0462 - val_reconstruction_loss: 2.4760 - val_kl_loss: 8.5701
# Epoch 16/100
# 549/549 [==============================] - 6s 11ms/step - loss: 11.3224 - reconstruction_loss: 2.7496 - kl_loss: 8.4599 - val_loss: 10.5095 - val_reconstruction_loss: 1.6874 - val_kl_loss: 8.8220
# Epoch 17/100
# 549/549 [==============================] - 6s 11ms/step - loss: 11.2391 - reconstruction_loss: 2.6824 - kl_loss: 8.5172 - val_loss: 11.7950 - val_reconstruction_loss: 2.7553 - val_kl_loss: 9.0396
# Epoch 18/100
# 549/549 [==============================] - 6s 11ms/step - loss: 11.3195 - reconstruction_loss: 2.6621 - kl_loss: 8.5500 - val_loss: 13.5850 - val_reconstruction_loss: 4.8970 - val_kl_loss: 8.6880
# Epoch 19/100
# 549/549 [==============================] - 6s 11ms/step - loss: 11.1332 - reconstruction_loss: 2.5455 - kl_loss: 8.4982 - val_loss: 10.2203 - val_reconstruction_loss: 2.7813 - val_kl_loss: 7.4390
# Epoch 20/100
# 549/549 [==============================] - 6s 11ms/step - loss: 11.0091 - reconstruction_loss: 2.4972 - kl_loss: 8.4963 - val_loss: 10.6750 - val_reconstruction_loss: 2.4301 - val_kl_loss: 8.2449
# Epoch 21/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.8641 - reconstruction_loss: 2.5029 - kl_loss: 8.4779 - val_loss: 10.7974 - val_reconstruction_loss: 2.7717 - val_kl_loss: 8.0257
# Epoch 22/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.8430 - reconstruction_loss: 2.3714 - kl_loss: 8.5395 - val_loss: 8.1257 - val_reconstruction_loss: 0.4710 - val_kl_loss: 7.6547
# Epoch 23/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.8734 - reconstruction_loss: 2.2886 - kl_loss: 8.5170 - val_loss: 10.0402 - val_reconstruction_loss: 1.0419 - val_kl_loss: 8.9982
# Epoch 24/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.8010 - reconstruction_loss: 2.2294 - kl_loss: 8.4842 - val_loss: 9.3797 - val_reconstruction_loss: 0.8219 - val_kl_loss: 8.5578
# Epoch 25/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.7507 - reconstruction_loss: 2.2345 - kl_loss: 8.5156 - val_loss: 12.0371 - val_reconstruction_loss: 2.4520 - val_kl_loss: 9.5851
# Epoch 26/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.7633 - reconstruction_loss: 2.1520 - kl_loss: 8.5109 - val_loss: 10.6242 - val_reconstruction_loss: 2.0328 - val_kl_loss: 8.5914
# Epoch 27/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.6234 - reconstruction_loss: 2.1987 - kl_loss: 8.4475 - val_loss: 11.4924 - val_reconstruction_loss: 3.1401 - val_kl_loss: 8.3523
# Epoch 28/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.7717 - reconstruction_loss: 2.3089 - kl_loss: 8.5347 - val_loss: 8.8763 - val_reconstruction_loss: 0.4127 - val_kl_loss: 8.4635
# Epoch 29/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.5486 - reconstruction_loss: 2.0681 - kl_loss: 8.5134 - val_loss: 9.9958 - val_reconstruction_loss: 1.7820 - val_kl_loss: 8.2138
# Epoch 30/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.5244 - reconstruction_loss: 2.0511 - kl_loss: 8.4976 - val_loss: 9.6324 - val_reconstruction_loss: 1.1191 - val_kl_loss: 8.5133
# Epoch 31/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.5383 - reconstruction_loss: 2.0007 - kl_loss: 8.5964 - val_loss: 12.1777 - val_reconstruction_loss: 3.4929 - val_kl_loss: 8.6848
# Epoch 32/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.6054 - reconstruction_loss: 2.0522 - kl_loss: 8.4985 - val_loss: 10.4378 - val_reconstruction_loss: 2.4318 - val_kl_loss: 8.0059
# Epoch 33/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.5673 - reconstruction_loss: 2.0424 - kl_loss: 8.4913 - val_loss: 10.7998 - val_reconstruction_loss: 2.1704 - val_kl_loss: 8.6293
# Epoch 34/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.4814 - reconstruction_loss: 1.9319 - kl_loss: 8.4883 - val_loss: 10.6064 - val_reconstruction_loss: 2.1477 - val_kl_loss: 8.4587
# Epoch 35/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.5508 - reconstruction_loss: 1.9793 - kl_loss: 8.5612 - val_loss: 10.5162 - val_reconstruction_loss: 2.1436 - val_kl_loss: 8.3726
# Epoch 36/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.2915 - reconstruction_loss: 1.8702 - kl_loss: 8.5120 - val_loss: 13.4386 - val_reconstruction_loss: 5.0778 - val_kl_loss: 8.3608
# Epoch 37/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.4243 - reconstruction_loss: 1.8588 - kl_loss: 8.4993 - val_loss: 9.8033 - val_reconstruction_loss: 0.5979 - val_kl_loss: 9.2053
# Epoch 38/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.3926 - reconstruction_loss: 1.8314 - kl_loss: 8.5892 - val_loss: 9.3984 - val_reconstruction_loss: 0.2333 - val_kl_loss: 9.1650
# Epoch 39/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.3466 - reconstruction_loss: 1.7906 - kl_loss: 8.5539 - val_loss: 10.2351 - val_reconstruction_loss: 0.8506 - val_kl_loss: 9.3845
# Epoch 40/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.4406 - reconstruction_loss: 1.8380 - kl_loss: 8.5350 - val_loss: 10.5081 - val_reconstruction_loss: 1.8474 - val_kl_loss: 8.6607
# Epoch 41/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.3564 - reconstruction_loss: 1.7385 - kl_loss: 8.5947 - val_loss: 12.0337 - val_reconstruction_loss: 3.2066 - val_kl_loss: 8.8271
# Epoch 42/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.2768 - reconstruction_loss: 1.8356 - kl_loss: 8.5458 - val_loss: 9.8445 - val_reconstruction_loss: 1.4325 - val_kl_loss: 8.4120
# Epoch 43/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.4082 - reconstruction_loss: 1.7377 - kl_loss: 8.5860 - val_loss: 7.8182 - val_reconstruction_loss: 0.5018 - val_kl_loss: 7.3164
# Epoch 44/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.3259 - reconstruction_loss: 1.7402 - kl_loss: 8.5760 - val_loss: 11.3957 - val_reconstruction_loss: 2.4297 - val_kl_loss: 8.9660
# Epoch 45/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1940 - reconstruction_loss: 1.7149 - kl_loss: 8.5636 - val_loss: 11.1963 - val_reconstruction_loss: 2.5660 - val_kl_loss: 8.6304
# Epoch 46/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.2138 - reconstruction_loss: 1.6734 - kl_loss: 8.5577 - val_loss: 9.4065 - val_reconstruction_loss: 1.1526 - val_kl_loss: 8.2539
# Epoch 47/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.2366 - reconstruction_loss: 1.6965 - kl_loss: 8.5501 - val_loss: 8.7589 - val_reconstruction_loss: 0.2159 - val_kl_loss: 8.5429
# Epoch 48/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.3190 - reconstruction_loss: 1.6611 - kl_loss: 8.6145 - val_loss: 8.1288 - val_reconstruction_loss: 0.0799 - val_kl_loss: 8.0489
# Epoch 49/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.3127 - reconstruction_loss: 1.6439 - kl_loss: 8.6484 - val_loss: 11.3851 - val_reconstruction_loss: 2.2129 - val_kl_loss: 9.1723
# Epoch 50/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1666 - reconstruction_loss: 1.6040 - kl_loss: 8.5597 - val_loss: 9.5366 - val_reconstruction_loss: 0.9755 - val_kl_loss: 8.5612
# Epoch 51/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1798 - reconstruction_loss: 1.5634 - kl_loss: 8.5925 - val_loss: 9.1111 - val_reconstruction_loss: 1.1087 - val_kl_loss: 8.0024
# Epoch 52/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1649 - reconstruction_loss: 1.5601 - kl_loss: 8.6257 - val_loss: 11.1188 - val_reconstruction_loss: 2.6135 - val_kl_loss: 8.5053
# Epoch 53/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1257 - reconstruction_loss: 1.5624 - kl_loss: 8.6800 - val_loss: 11.3758 - val_reconstruction_loss: 2.6622 - val_kl_loss: 8.7137
# Epoch 54/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1158 - reconstruction_loss: 1.6150 - kl_loss: 8.5789 - val_loss: 9.9440 - val_reconstruction_loss: 0.9178 - val_kl_loss: 9.0262
# Epoch 55/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1014 - reconstruction_loss: 1.5805 - kl_loss: 8.6369 - val_loss: 9.5608 - val_reconstruction_loss: 0.8355 - val_kl_loss: 8.7253
# Epoch 56/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1404 - reconstruction_loss: 1.5537 - kl_loss: 8.5790 - val_loss: 14.0320 - val_reconstruction_loss: 5.5081 - val_kl_loss: 8.5239
# Epoch 57/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1508 - reconstruction_loss: 1.5032 - kl_loss: 8.5897 - val_loss: 8.4753 - val_reconstruction_loss: 0.2475 - val_kl_loss: 8.2277
# Epoch 58/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1483 - reconstruction_loss: 1.5883 - kl_loss: 8.6367 - val_loss: 10.1394 - val_reconstruction_loss: 0.8131 - val_kl_loss: 9.3264
# Epoch 59/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.0565 - reconstruction_loss: 1.4113 - kl_loss: 8.5589 - val_loss: 9.8481 - val_reconstruction_loss: 1.5655 - val_kl_loss: 8.2826
# Epoch 60/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.2558 - reconstruction_loss: 1.5537 - kl_loss: 8.5845 - val_loss: 8.7591 - val_reconstruction_loss: 0.3281 - val_kl_loss: 8.4310
# Epoch 61/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.2800 - reconstruction_loss: 1.5594 - kl_loss: 8.6049 - val_loss: 8.2040 - val_reconstruction_loss: 0.6129 - val_kl_loss: 7.5911
# Epoch 62/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1278 - reconstruction_loss: 1.4411 - kl_loss: 8.6589 - val_loss: 8.9662 - val_reconstruction_loss: 0.9794 - val_kl_loss: 7.9868
# Epoch 63/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.0344 - reconstruction_loss: 1.4902 - kl_loss: 8.5378 - val_loss: 33.8542 - val_reconstruction_loss: 25.0440 - val_kl_loss: 8.8102
# Epoch 64/100
# 549/549 [==============================] - 6s 11ms/step - loss: 10.1903 - reconstruction_loss: 1.5284 - kl_loss: 8.5649 - val_loss: 8.2417 - val_reconstruction_loss: 0.5876 - val_kl_loss: 7.6541
# Epoch 65/100
# 549/549 [==============================] - 7s 13ms/step - loss: 10.3073 - reconstruction_loss: 1.4876 - kl_loss: 8.6784 - val_loss: 9.9753 - val_reconstruction_loss: 2.0907 - val_kl_loss: 7.8846
# Epoch 66/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9892 - reconstruction_loss: 1.4607 - kl_loss: 8.5857 - val_loss: 9.4024 - val_reconstruction_loss: 0.6319 - val_kl_loss: 8.7705
# Epoch 67/100
# 549/549 [==============================] - 7s 12ms/step - loss: 10.0272 - reconstruction_loss: 1.4778 - kl_loss: 8.5698 - val_loss: 9.5678 - val_reconstruction_loss: 0.8751 - val_kl_loss: 8.6928
# Epoch 68/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9897 - reconstruction_loss: 1.4197 - kl_loss: 8.6123 - val_loss: 12.1631 - val_reconstruction_loss: 3.8563 - val_kl_loss: 8.3068
# Epoch 69/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.8669 - reconstruction_loss: 1.4087 - kl_loss: 8.5669 - val_loss: 11.7232 - val_reconstruction_loss: 2.2712 - val_kl_loss: 9.4520
# Epoch 70/100
# 549/549 [==============================] - 6s 12ms/step - loss: 10.0202 - reconstruction_loss: 1.3921 - kl_loss: 8.6401 - val_loss: 9.9474 - val_reconstruction_loss: 1.1174 - val_kl_loss: 8.8299
# Epoch 71/100
# 549/549 [==============================] - 7s 13ms/step - loss: 9.9106 - reconstruction_loss: 1.3553 - kl_loss: 8.6454 - val_loss: 14.4250 - val_reconstruction_loss: 7.3733 - val_kl_loss: 7.0517
# Epoch 72/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9400 - reconstruction_loss: 1.3983 - kl_loss: 8.5965 - val_loss: 17.0263 - val_reconstruction_loss: 7.6444 - val_kl_loss: 9.3819
# Epoch 73/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.8730 - reconstruction_loss: 1.3455 - kl_loss: 8.5568 - val_loss: 11.0751 - val_reconstruction_loss: 2.1028 - val_kl_loss: 8.9723
# Epoch 74/100
# 549/549 [==============================] - 7s 12ms/step - loss: 10.0182 - reconstruction_loss: 1.4243 - kl_loss: 8.6175 - val_loss: 10.8285 - val_reconstruction_loss: 2.0559 - val_kl_loss: 8.7726
# Epoch 75/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.8482 - reconstruction_loss: 1.3881 - kl_loss: 8.5800 - val_loss: 9.6427 - val_reconstruction_loss: 0.7299 - val_kl_loss: 8.9128
# Epoch 76/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9972 - reconstruction_loss: 1.3635 - kl_loss: 8.5970 - val_loss: 10.2981 - val_reconstruction_loss: 1.2637 - val_kl_loss: 9.0344
# Epoch 77/100
# 549/549 [==============================] - 7s 12ms/step - loss: 10.0412 - reconstruction_loss: 1.3709 - kl_loss: 8.6235 - val_loss: 9.6332 - val_reconstruction_loss: 1.2091 - val_kl_loss: 8.4241
# Epoch 78/100
# 549/549 [==============================] - 7s 12ms/step - loss: 10.0004 - reconstruction_loss: 1.4066 - kl_loss: 8.6377 - val_loss: 11.9774 - val_reconstruction_loss: 2.9189 - val_kl_loss: 9.0585
# Epoch 79/100
# 549/549 [==============================] - 7s 12ms/step - loss: 10.0288 - reconstruction_loss: 1.4137 - kl_loss: 8.6200 - val_loss: 12.4191 - val_reconstruction_loss: 3.3291 - val_kl_loss: 9.0900
# Epoch 80/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9449 - reconstruction_loss: 1.3688 - kl_loss: 8.6391 - val_loss: 8.8293 - val_reconstruction_loss: 0.4263 - val_kl_loss: 8.4030
# Epoch 81/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.8790 - reconstruction_loss: 1.3418 - kl_loss: 8.5213 - val_loss: 9.7413 - val_reconstruction_loss: 1.2378 - val_kl_loss: 8.5036
# Epoch 82/100
# 549/549 [==============================] - 7s 12ms/step - loss: 10.1545 - reconstruction_loss: 1.5065 - kl_loss: 8.6086 - val_loss: 9.7036 - val_reconstruction_loss: 0.9209 - val_kl_loss: 8.7827
# Epoch 83/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9431 - reconstruction_loss: 1.3650 - kl_loss: 8.5848 - val_loss: 9.4053 - val_reconstruction_loss: 0.6182 - val_kl_loss: 8.7871
# Epoch 84/100
# 549/549 [==============================] - 7s 12ms/step - loss: 10.0648 - reconstruction_loss: 1.4045 - kl_loss: 8.6567 - val_loss: 10.0831 - val_reconstruction_loss: 1.1707 - val_kl_loss: 8.9124
# Epoch 85/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9614 - reconstruction_loss: 1.3357 - kl_loss: 8.6732 - val_loss: 10.5470 - val_reconstruction_loss: 1.4879 - val_kl_loss: 9.0591
# Epoch 86/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.8970 - reconstruction_loss: 1.3495 - kl_loss: 8.5894 - val_loss: 7.6628 - val_reconstruction_loss: 0.1872 - val_kl_loss: 7.4756
# Epoch 87/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.8959 - reconstruction_loss: 1.3474 - kl_loss: 8.5958 - val_loss: 10.0029 - val_reconstruction_loss: 0.7178 - val_kl_loss: 9.2851
# Epoch 88/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.8049 - reconstruction_loss: 1.2452 - kl_loss: 8.6395 - val_loss: 10.0565 - val_reconstruction_loss: 0.9076 - val_kl_loss: 9.1489
# Epoch 89/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9395 - reconstruction_loss: 1.3288 - kl_loss: 8.6295 - val_loss: 8.6896 - val_reconstruction_loss: 0.0998 - val_kl_loss: 8.5898
# Epoch 90/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.8994 - reconstruction_loss: 1.3306 - kl_loss: 8.6083 - val_loss: 10.8054 - val_reconstruction_loss: 1.8405 - val_kl_loss: 8.9650
# Epoch 91/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9358 - reconstruction_loss: 1.2828 - kl_loss: 8.6399 - val_loss: 10.6447 - val_reconstruction_loss: 2.3264 - val_kl_loss: 8.3183
# Epoch 92/100
# 549/549 [==============================] - 7s 12ms/step - loss: 10.2319 - reconstruction_loss: 1.8490 - kl_loss: 8.7987 - val_loss: 9.5667 - val_reconstruction_loss: 1.1481 - val_kl_loss: 8.4186
# Epoch 93/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9951 - reconstruction_loss: 1.3217 - kl_loss: 8.6043 - val_loss: 9.3297 - val_reconstruction_loss: 1.3864 - val_kl_loss: 7.9433
# Epoch 94/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9503 - reconstruction_loss: 1.2482 - kl_loss: 8.6548 - val_loss: 8.8608 - val_reconstruction_loss: 0.0657 - val_kl_loss: 8.7951
# Epoch 95/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.7917 - reconstruction_loss: 1.2343 - kl_loss: 8.5574 - val_loss: 9.4014 - val_reconstruction_loss: 0.7441 - val_kl_loss: 8.6574
# Epoch 96/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9221 - reconstruction_loss: 1.3198 - kl_loss: 8.6312 - val_loss: 9.0314 - val_reconstruction_loss: 0.6665 - val_kl_loss: 8.3649
# Epoch 97/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.7973 - reconstruction_loss: 1.2178 - kl_loss: 8.6178 - val_loss: 9.6631 - val_reconstruction_loss: 0.2902 - val_kl_loss: 9.3729
# Epoch 98/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.8530 - reconstruction_loss: 1.2111 - kl_loss: 8.6202 - val_loss: 10.2084 - val_reconstruction_loss: 2.1552 - val_kl_loss: 8.0532
# Epoch 99/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.7628 - reconstruction_loss: 1.3058 - kl_loss: 8.5377 - val_loss: 9.2138 - val_reconstruction_loss: 0.5813 - val_kl_loss: 8.6326
# Epoch 100/100
# 549/549 [==============================] - 7s 12ms/step - loss: 9.9359 - reconstruction_loss: 1.3144 - kl_loss: 8.6225 - val_loss: 8.7679 - val_reconstruction_loss: 1.0432 - val_kl_loss: 7.7247

# %%
rec_loss = history.history['reconstruction_loss']
val_rec_loss = history.history['val_reconstruction_loss']


epochs = range(1, len(val_rec_loss) + 1)    

plt.figure(figsize=(8,6), dpi=80)
plt.plot(epochs, val_rec_loss, 'r', label='Val Reconstruction loss')
plt.plot(epochs, rec_loss, 'b', label='Train Reconstruction loss')
plt.title('Reconstruction loss')
plt.ylabel('Loss')
plt.xlabel("Epochs")
plt.gca().set_ylim([0,15])
#plt.gca().set_ylim([0, 20])
plt.legend()

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

'''
for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE)
    img = img_to_array(load_img(f"images_ballless/pong_ballless_{rand_img}.png", color_mode='grayscale'))
    images[i] = img
    '''

for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE-10)
    img = img_to_array(load_img(f"images_ballless/pong_ballless_{rand_img}.png", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 100.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [i*10 for i in range(-7, 7)]
            # missing =  -2.9679005e+00, -1.7151514e+01    
            z_sample = np.array([[xi, yi] + rest])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)

# %%
vae.model.save("models/vae_ballless")
# Out:
# INFO:tensorflow:Assets written to: models/vae_ballless/assets
