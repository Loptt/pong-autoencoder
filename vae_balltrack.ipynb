# %% [markdown]
# ## Variational Autoencoder Ball Track

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAEBallTrack

DATASET_SIZE = 25084
INPUT_SHAPE = (40, 40, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    raise Exception("Cannot initialize GPU")

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training',
    batch_size=32
)

val_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation',
    batch_size=32
)
# Out:
# Found 17559 images belonging to 1 classes.
# Found 7524 images belonging to 1 classes.

# %%
vae = VAEBallTrack(
    layers=5,
    latent_size=16,
    kernel_size=3,
    input_shape=INPUT_SHAPE,
    name="VAEBall"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 40, 40, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 40, 40, 16)   160         input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 20, 20, 16)   0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 20, 20, 32)   4640        maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 10, 10, 32)   0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 10, 10, 64)   18496       maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 5, 5, 64)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 5, 5, 128)    73856       maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 3, 3, 128)    0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# conv5_enc (Conv2D)              (None, 3, 3, 256)    295168      maxpool4[0][0]
# __________________________________________________________________________________________________
# maxpool5 (MaxPooling2D)         (None, 2, 2, 256)    0           conv5_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           maxpool5[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 16)           16400       flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 16)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 409,264
# Trainable params: 409,264
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 16)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 1024)              17408
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 2, 256)         0
# _________________________________________________________________
# conv5_dec (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# upsamp5 (UpSampling2D)       (None, 4, 4, 256)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 4, 4, 128)         295040
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 8, 8, 128)         0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 8, 8, 64)          73792
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 16, 16, 32)        18464
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 32, 32, 32)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 32, 32, 16)        4624
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 64, 64, 16)        0
# _________________________________________________________________
# output (Conv2D)              (None, 40, 40, 1)         10001
# =================================================================
# Total params: 1,009,409
# Trainable params: 1,009,409
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAEBall"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 16), (None, 16),  409264
# _________________________________________________________________
# Decoder (Functional)         (None, 40, 40, 1)         1009409
# =================================================================
# Total params: 1,418,681
# Trainable params: 1,418,673
# Non-trainable params: 8
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10),
    TensorBoard(
        log_dir='./logs',
        histogram_freq=1
    )
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=100, 
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 549/549 [==============================] - 206s 353ms/step - loss: 132.0451 - reconstruction_loss: 81.6208 - kl_loss: 0.0025 - ball_loss: 18.4032 - val_loss: 66.1516 - val_reconstruction_loss: 50.3758 - val_kl_loss: 5.7041e-04 - val_ball_loss: 15.7752
# Epoch 2/100
# 549/549 [==============================] - 39s 70ms/step - loss: 87.0170 - reconstruction_loss: 69.8027 - kl_loss: 5.3725e-04 - ball_loss: 17.2681 - val_loss: 71.2767 - val_reconstruction_loss: 55.0492 - val_kl_loss: 5.6060e-04 - val_ball_loss: 16.2269
# Epoch 3/100
# 549/549 [==============================] - 37s 68ms/step - loss: 84.2221 - reconstruction_loss: 57.9731 - kl_loss: 3.4109 - ball_loss: 14.5684 - val_loss: 55.7137 - val_reconstruction_loss: 34.0874 - val_kl_loss: 8.8658 - val_ball_loss: 12.7605
# Epoch 4/100
# 549/549 [==============================] - 38s 70ms/step - loss: 44.4237 - reconstruction_loss: 21.4888 - kl_loss: 10.1167 - ball_loss: 9.0688 - val_loss: 31.5377 - val_reconstruction_loss: 11.8722 - val_kl_loss: 10.3201 - val_ball_loss: 9.3453
# Epoch 5/100
# 549/549 [==============================] - 36s 66ms/step - loss: 34.8949 - reconstruction_loss: 16.2056 - kl_loss: 10.6354 - ball_loss: 7.3164 - val_loss: 33.3367 - val_reconstruction_loss: 11.4582 - val_kl_loss: 11.1484 - val_ball_loss: 10.7301
# Epoch 6/100
# 549/549 [==============================] - 37s 67ms/step - loss: 32.2967 - reconstruction_loss: 14.4383 - kl_loss: 10.9175 - ball_loss: 6.7642 - val_loss: 26.7659 - val_reconstruction_loss: 12.2784 - val_kl_loss: 11.5050 - val_ball_loss: 2.9825
# Epoch 7/100
# 549/549 [==============================] - 36s 65ms/step - loss: 31.4679 - reconstruction_loss: 14.0276 - kl_loss: 11.0537 - ball_loss: 6.1894 - val_loss: 25.5831 - val_reconstruction_loss: 8.3150 - val_kl_loss: 11.9774 - val_ball_loss: 5.2907
# Epoch 8/100
# 549/549 [==============================] - 36s 66ms/step - loss: 30.8845 - reconstruction_loss: 13.9187 - kl_loss: 11.0947 - ball_loss: 5.9348 - val_loss: 34.5496 - val_reconstruction_loss: 17.2297 - val_kl_loss: 10.3395 - val_ball_loss: 6.9805
# Epoch 9/100
# Epoch 29/100
# 549/549 [==============================] - 35s 65ms/step - loss: 25.4076 - reconstruction_loss: 10.0534 - kl_loss: 11.5235 - ball_loss: 3.8416 - val_loss: 31.4987 - val_reconstruction_loss: 16.9689 - val_kl_loss: 11.6136 - val_ball_loss: 2.9162
# Epoch 30/100
# 549/549 [==============================] - 35s 64ms/step - loss: 25.2007 - reconstruction_loss: 9.8537 - kl_loss: 11.4777 - ball_loss: 3.7700 - val_loss: 25.2682 - val_reconstruction_loss: 11.4681 - val_kl_loss: 11.4734 - val_ball_loss: 2.3267

# %%
val_loss = history.history['val_loss']
rec_loss = history.history['reconstruction_loss']
ball_loss = history.history['ball_loss']

epochs = range(1, len(val_loss) + 1)    

plt.plot(epochs, val_loss, 'b', label='Val loss')
plt.plot(epochs, rec_loss, 'bo', label='Reconstruction loss')
plt.plot(epochs, ball_loss, 'r', label='Ball loss')
plt.title('Reconstruction and Ball loss')
plt.legend()

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

rand_img = random.randint(0, DATASET_SIZE-10)
for i in range(n):
    img = img_to_array(load_img(f"images_trans/pong_trans_{rand_img+i}.png", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 100.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [ 1.3800155e+01, -1.6270699e+01,
                    1.5749934e+02, -1.1879397e+01, -1.1234385e+01, -3.0332508e+00,
                    7.1921587e+00,  1.1697321e+01,  2.6710289e+00,  2.8224752e+00,
                    2.0286884e+01,  3.5399105e+01, -2.9679005e+00, -1.7151514e+01]
            # missing =  4.5645156e+00,  1.5707643e+01,   
            z_sample = np.array([[-50] * 6 + [xi, yi] + [-50] * 8])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)
