# %% [markdown]
# ## Variational Autoencoder Ball Track

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAEBallTrack

DATASET_SIZE = 25084
INPUT_SHAPE = (40, 40, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    raise Exception("Cannot initialize GPU")

#tf.config.experimental.set_memory_growth(devices[0], True)

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training',
    batch_size=32
)

val_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation',
    batch_size=32
)
# Out:
# Found 17559 images belonging to 1 classes.
# Found 7524 images belonging to 1 classes.

# %%
vae = VAEBallTrack(
    layers=5,
    latent_size=16,
    kernel_size=3,
    input_shape=INPUT_SHAPE,
    filters=16,
    name="VAEBall"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 40, 40, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 40, 40, 16)   160         input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 20, 20, 16)   0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 20, 20, 32)   4640        maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 10, 10, 32)   0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 10, 10, 64)   18496       maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 5, 5, 64)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 5, 5, 128)    73856       maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 3, 3, 128)    0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# conv5_enc (Conv2D)              (None, 3, 3, 256)    295168      maxpool4[0][0]
# __________________________________________________________________________________________________
# maxpool5 (MaxPooling2D)         (None, 2, 2, 256)    0           conv5_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           maxpool5[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 16)           16400       flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 16)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 409,264
# Trainable params: 409,264
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 16)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 1024)              17408
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 2, 256)         0
# _________________________________________________________________
# conv5_dec (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# upsamp5 (UpSampling2D)       (None, 4, 4, 256)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 4, 4, 128)         295040
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 8, 8, 128)         0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 8, 8, 64)          73792
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 16, 16, 32)        18464
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 32, 32, 32)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 32, 32, 16)        4624
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 64, 64, 16)        0
# _________________________________________________________________
# output (Conv2D)              (None, 40, 40, 1)         10001
# =================================================================
# Total params: 1,009,409
# Trainable params: 1,009,409
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAEBall"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 16), (None, 16),  409264
# _________________________________________________________________
# Decoder (Functional)         (None, 40, 40, 1)         1009409
# =================================================================
# Total params: 1,418,681
# Trainable params: 1,418,673
# Non-trainable params: 8
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=20),
    TensorBoard(
        log_dir='./logs',
        histogram_freq=1
    )
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=100, 
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 549/549 [==============================] - 234s 362ms/step - loss: 138.5222 - reconstruction_loss: 80.5363 - kl_loss: 0.5950 - ball_loss: 21.7616 - val_loss: 84.1254 - val_reconstruction_loss: 62.4403 - val_kl_loss: 4.1399 - val_ball_loss: 17.5451
# Epoch 2/100
# 549/549 [==============================] - 33s 60ms/step - loss: 65.8712 - reconstruction_loss: 31.0646 - kl_loss: 9.5730 - ball_loss: 18.0449 - val_loss: 58.5308 - val_reconstruction_loss: 26.1265 - val_kl_loss: 10.9650 - val_ball_loss: 21.4393
# Epoch 3/100
# 549/549 [==============================] - 34s 61ms/step - loss: 48.5606 - reconstruction_loss: 18.8602 - kl_loss: 10.2937 - ball_loss: 18.3358 - val_loss: 35.5627 - val_reconstruction_loss: 11.5527 - val_kl_loss: 10.5491 - val_ball_loss: 13.4609
# Epoch 4/100
# 549/549 [==============================] - 38s 69ms/step - loss: 45.5673 - reconstruction_loss: 16.8399 - kl_loss: 10.2876 - ball_loss: 18.3288 - val_loss: 36.1592 - val_reconstruction_loss: 13.5113 - val_kl_loss: 10.2326 - val_ball_loss: 12.4153
# Epoch 5/100
# 549/549 [==============================] - 36s 65ms/step - loss: 44.7947 - reconstruction_loss: 16.0181 - kl_loss: 10.3868 - ball_loss: 18.2383 - val_loss: 45.5637 - val_reconstruction_loss: 14.8641 - val_kl_loss: 10.3494 - val_ball_loss: 20.3502
# Epoch 6/100
# 549/549 [==============================] - 36s 65ms/step - loss: 44.2183 - reconstruction_loss: 15.3752 - kl_loss: 10.4558 - ball_loss: 18.1522 - val_loss: 40.4816 - val_reconstruction_loss: 13.2609 - val_kl_loss: 10.5167 - val_ball_loss: 16.7039
# Epoch 7/100
# 549/549 [==============================] - 34s 62ms/step - loss: 43.8786 - reconstruction_loss: 14.9038 - kl_loss: 10.5631 - ball_loss: 18.2770 - val_loss: 44.7941 - val_reconstruction_loss: 17.4369 - val_kl_loss: 10.7762 - val_ball_loss: 16.5810
# Epoch 8/100
# 549/549 [==============================] - 34s 62ms/step - loss: 43.4606 - reconstruction_loss: 14.4730 - kl_loss: 10.6143 - ball_loss: 18.2535 - val_loss: 41.7281 - val_reconstruction_loss: 12.6887 - val_kl_loss: 11.4240 - val_ball_loss: 17.6154
# Epoch 9/100
# 549/549 [==============================] - 33s 60ms/step - loss: 43.1742 - reconstruction_loss: 14.0632 - kl_loss: 10.6822 - ball_loss: 18.1787 - val_loss: 41.1111 - val_reconstruction_loss: 13.9206 - val_kl_loss: 10.9887 - val_ball_loss: 16.2019
# Epoch 10/100
# 549/549 [==============================] - 35s 63ms/step - loss: 39.5908 - reconstruction_loss: 10.7209 - kl_loss: 10.9955 - ball_loss: 17.9272 - val_loss: 39.7530 - val_reconstruction_loss: 13.9016 - val_kl_loss: 10.8071 - val_ball_loss: 15.0443
# Epoch 43/100
# 549/549 [==============================] - 35s 63ms/step - loss: 39.6450 - reconstruction_loss: 10.7685 - kl_loss: 11.0025 - ball_loss: 17.9015 - val_loss: 35.4239 - val_reconstruction_loss: 11.4552 - val_kl_loss: 10.2954 - val_ball_loss: 13.6733
# Epoch 44/100
# 549/549 [==============================] - 35s 64ms/step - loss: 39.3487 - reconstruction_loss: 10.8104 - kl_loss: 11.0049 - ball_loss: 17.7189 - val_loss: 37.9490 - val_reconstruction_loss: 9.0790 - val_kl_loss: 11.5102 - val_ball_loss: 17.3599

# %%
val_loss = history.history['val_reconstruction_loss']
rec_loss = history.history['val_ball_loss']
ball_loss = history.history['ball_loss']

epochs = range(1, len(val_loss) + 1)  

plt.figure(figsize=(8,6), dpi=80)

plt.plot(epochs, val_loss, 'r', label='Val reconstruction loss')
plt.plot(epochs, rec_loss, 'b', label='Val ball distance loss')
plt.plot(epochs, ball_loss, 'g', label='Ball distance loss')
plt.title('Reconstruction and Ball loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE-10)
    img = img_to_array(load_img(f"images_trans/pong_trans_{rand_img}.png", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 100.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [ 1.3800155e+01, -1.6270699e+01,
                    1.5749934e+02, -1.1879397e+01, -1.1234385e+01, -3.0332508e+00,
                    7.1921587e+00,  1.1697321e+01,  2.6710289e+00,  2.8224752e+00,
                    2.0286884e+01,  3.5399105e+01, -2.9679005e+00, -1.7151514e+01]
            # missing =  4.5645156e+00,  1.5707643e+01,   
            z_sample = np.array([[-50] * 6 + [xi, yi] + [-50] * 8])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)
