# %% [markdown]
# ## Variational Autoencoder Ball Track No Paddles

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAEBallTrackNoPaddle

DATASET_SIZE = 25084
INPUT_SHAPE = (40, 30, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    raise Exception("Cannot initialize GPU")

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_paddleless/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training',
    batch_size=32
)

val_datagen = datagen.flow_from_directory(
    'images_paddleless/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation',
    batch_size=32
)
# Out:
# Found 9706 images belonging to 1 classes.
# Found 4159 images belonging to 1 classes.

# %%
vae = VAEBallTrackNoPaddle(
    layers=5,
    latent_size=16,
    kernel_size=3,
    input_shape=INPUT_SHAPE,
    name="VAEBall"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 40, 30, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 40, 30, 16)   160         input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 20, 15, 16)   0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 20, 15, 32)   4640        maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 10, 8, 32)    0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 10, 8, 64)    18496       maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 5, 4, 64)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 5, 4, 128)    73856       maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 3, 2, 128)    0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# conv5_enc (Conv2D)              (None, 3, 2, 256)    295168      maxpool4[0][0]
# __________________________________________________________________________________________________
# maxpool5 (MaxPooling2D)         (None, 2, 1, 256)    0           conv5_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           maxpool5[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 16)           8208        flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 16)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 401,072
# Trainable params: 401,072
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 16)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 512)               8704
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 1, 256)         0
# _________________________________________________________________
# conv5_dec (Conv2D)           (None, 2, 1, 256)         590080
# _________________________________________________________________
# upsamp5 (UpSampling2D)       (None, 4, 2, 256)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 4, 2, 128)         295040
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 8, 4, 128)         0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 8, 4, 64)          73792
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 16, 8, 64)         0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 16, 8, 32)         18464
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 32, 16, 32)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 32, 16, 16)        4624
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 64, 32, 16)        0
# _________________________________________________________________
# output (Conv2D)              (None, 40, 30, 1)         1201
# =================================================================
# Total params: 991,905
# Trainable params: 991,905
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAEBall"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 16), (None, 16),  401072
# _________________________________________________________________
# Decoder (Functional)         (None, 40, 30, 1)         991905
# =================================================================
# Total params: 1,392,983
# Trainable params: 1,392,977
# Non-trainable params: 6
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10),
    TensorBoard(
        log_dir='./logs',
        histogram_freq=1
    )
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=100, 
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 304/304 [==============================] - 52s 129ms/step - loss: 12.6472 - kl_loss: 1.2388 - ball_loss: 9.5424 - val_loss: 6.9098 - val_kl_loss: 2.3764 - val_ball_loss: 4.5334
# Epoch 2/100
# 304/304 [==============================] - 19s 61ms/step - loss: 7.9894 - kl_loss: 2.5994 - ball_loss: 5.1575 - val_loss: 6.7406 - val_kl_loss: 2.7763 - val_ball_loss: 3.9643
# Epoch 3/100
# 304/304 [==============================] - 18s 60ms/step - loss: 7.1240 - kl_loss: 2.6703 - ball_loss: 4.3861 - val_loss: 6.2517 - val_kl_loss: 2.5721 - val_ball_loss: 3.6796
# Epoch 4/100
# 304/304 [==============================] - 18s 61ms/step - loss: 6.9124 - kl_loss: 2.7463 - ball_loss: 4.2055 - val_loss: 7.0733 - val_kl_loss: 2.2660 - val_ball_loss: 4.8073
# Epoch 5/100
# 304/304 [==============================] - 18s 60ms/step - loss: 6.8219 - kl_loss: 2.7564 - ball_loss: 4.1359 - val_loss: 5.8358 - val_kl_loss: 2.2639 - val_ball_loss: 3.5719
# Epoch 6/100
# 304/304 [==============================] - 18s 60ms/step - loss: 6.8891 - kl_loss: 2.7761 - ball_loss: 4.0676 - val_loss: 7.0694 - val_kl_loss: 3.2984 - val_ball_loss: 3.7709
# Epoch 7/100
# 304/304 [==============================] - 18s 58ms/step - loss: 7.8814 - kl_loss: 2.5886 - ball_loss: 5.0634 - val_loss: 9.2172 - val_kl_loss: 1.9374 - val_ball_loss: 7.2798
# Epoch 8/100
# 304/304 [==============================] - 18s 59ms/step - loss: 9.3590 - kl_loss: 2.5545 - ball_loss: 6.0037 - val_loss: 9.3396 - val_kl_loss: 2.6265 - val_ball_loss: 6.7131
# Epoch 9/100
# 304/304 [==============================] - 19s 63ms/step - loss: 8.3436 - kl_loss: 2.5554 - ball_loss: 5.7276 - val_loss: 8.1630 - val_kl_loss: 2.4066 - val_ball_loss: 5.7564
# Epoch 10/100
# 304/304 [==============================] - 18s 61ms/step - loss: 11.0482 - kl_loss: 1.7071 - ball_loss: 11.4293 - val_loss: 15.6635 - val_kl_loss: 0.2993 - val_ball_loss: 15.3642
# Epoch 11/100
# 304/304 [==============================] - 18s 59ms/step - loss: 14.5920 - kl_loss: 0.2159 - ball_loss: 15.8093 - val_loss: 18.3143 - val_kl_loss: 0.0142 - val_ball_loss: 18.3001
# Epoch 12/100
# 304/304 [==============================] - 18s 58ms/step - loss: 17.6638 - kl_loss: 0.0077 - ball_loss: 17.6626 - val_loss: 17.0087 - val_kl_loss: 0.0034 - val_ball_loss: 17.0053
# Epoch 13/100
# 304/304 [==============================] - 18s 58ms/step - loss: 17.6839 - kl_loss: 0.0018 - ball_loss: 17.6585 - val_loss: 17.3407 - val_kl_loss: 7.4393e-04 - val_ball_loss: 17.3399
# Epoch 14/100
# 304/304 [==============================] - 17s 57ms/step - loss: 17.7314 - kl_loss: 4.0455e-04 - ball_loss: 17.6612 - val_loss: 17.2930 - val_kl_loss: 1.6685e-04 - val_ball_loss: 17.2929
# Epoch 15/100
# 304/304 [==============================] - 17s 58ms/step - loss: 17.6472 - kl_loss: 1.1937e-04 - ball_loss: 17.6599 - val_loss: 16.7736 - val_kl_loss: 6.8910e-05 - val_ball_loss: 16.7735

# %%
val_loss = history.history['val_loss']
#rec_loss = history.history['reconstruction_loss']
ball_loss = history.history['ball_loss']

epochs = range(1, len(val_loss) + 1)    

plt.plot(epochs, val_loss, 'b', label='Val loss')
#plt.plot(epochs, rec_loss, 'bo', label='Reconstruction loss')
plt.plot(epochs, ball_loss, 'r', label='Ball loss')
plt.title('Reconstruction and Ball loss')
plt.legend()

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 1
images = np.empty((n, *INPUT_SHAPE))

for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE)
    img = img_to_array(load_img(f"images_paddleless/pong_paddleless_{rand_img}.png", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 100.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [ 1.3800155e+01, -1.6270699e+01,
                    1.5749934e+02, -1.1879397e+01, -1.1234385e+01, -3.0332508e+00,
                    7.1921587e+00,  1.1697321e+01,  2.6710289e+00,  2.8224752e+00,
                    2.0286884e+01,  3.5399105e+01, -2.9679005e+00, -1.7151514e+01]
            # missing =  4.5645156e+00,  1.5707643e+01,   
            z_sample = np.array([[-50] * 6 + [xi, yi] + [-50] * 8])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)
