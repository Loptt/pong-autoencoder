# %% [markdown]
# ## Variational Autoencoder CoordConv filters

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAECoordConv as VAE

DATASET_SIZE = 25084
INPUT_SHAPE = (40, 40, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    raise Exception("Cannot initialize GPU")

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training'
)

val_datagen = datagen.flow_from_directory(
    'images_trans/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation'
)
# Out:
# Found 17559 images belonging to 1 classes.
# Found 7524 images belonging to 1 classes.

# %%
vae = VAE(
    layers=5,
    latent_size=16,
    kernel_size=3,
    input_shape=INPUT_SHAPE,
    name="VAE"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 40, 40, 1)]  0
# __________________________________________________________________________________________________
# coordinate_channel2d_2 (Coordin (None, 40, 40, 3)    0           input_encoder[0][0]
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 40, 40, 16)   448         coordinate_channel2d_2[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 20, 20, 16)   0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 20, 20, 32)   4640        maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 10, 10, 32)   0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 10, 10, 64)   18496       maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 5, 5, 64)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 5, 5, 128)    73856       maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 3, 3, 128)    0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# conv5_enc (Conv2D)              (None, 3, 3, 256)    295168      maxpool4[0][0]
# __________________________________________________________________________________________________
# maxpool5 (MaxPooling2D)         (None, 2, 2, 256)    0           conv5_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           maxpool5[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 16)           16400       flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 16)           272         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling_1 (Sampling)           (None, 16)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 409,552
# Trainable params: 409,552
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 16)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 1024)              17408
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 2, 256)         0
# _________________________________________________________________
# conv5_dec (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# upsamp5 (UpSampling2D)       (None, 4, 4, 256)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 4, 4, 128)         295040
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 8, 8, 128)         0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 8, 8, 64)          73792
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 16, 16, 32)        18464
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 32, 32, 32)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 32, 32, 16)        4624
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 64, 64, 16)        0
# _________________________________________________________________
# coordinate_channel2d_3 (Coor (None, 64, 64, 18)        0
# _________________________________________________________________
# output (Conv2D)              (None, 40, 40, 1)         11251
# =================================================================
# Total params: 1,010,659
# Trainable params: 1,010,659
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 16), (None, 16),  409552
# _________________________________________________________________
# Decoder (Functional)         (None, 40, 40, 1)         1010659
# =================================================================
# Total params: 1,420,217
# Trainable params: 1,420,211
# Non-trainable params: 6
# _________________________________________________________________

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=30),
    TensorBoard(
        log_dir='./logs',
        histogram_freq=1
    )
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=75, 
    callbacks=callbacks
)
# Out:
# Epoch 1/75
# 549/549 [==============================] - 12s 20ms/step - loss: 103.3831 - reconstruction_loss: 70.9788 - kl_loss: 2.0015 - val_loss: 46.3730 - val_reconstruction_loss: 40.2481 - val_kl_loss: 6.1248
# Epoch 2/75
# 549/549 [==============================] - 10s 19ms/step - loss: 51.0163 - reconstruction_loss: 43.6810 - kl_loss: 5.0444 - val_loss: 50.8567 - val_reconstruction_loss: 45.2266 - val_kl_loss: 5.6301
# Epoch 3/75
# 549/549 [==============================] - 10s 19ms/step - loss: 45.6179 - reconstruction_loss: 39.9668 - kl_loss: 5.1253 - val_loss: 39.7666 - val_reconstruction_loss: 34.9577 - val_kl_loss: 4.8089
# Epoch 4/75
# 549/549 [==============================] - 10s 19ms/step - loss: 43.3687 - reconstruction_loss: 36.6744 - kl_loss: 5.8325 - val_loss: 39.5079 - val_reconstruction_loss: 33.6429 - val_kl_loss: 5.8649
# Epoch 5/75
# 549/549 [==============================] - 10s 19ms/step - loss: 39.5919 - reconstruction_loss: 30.1230 - kl_loss: 7.3901 - val_loss: 26.9705 - val_reconstruction_loss: 17.0821 - val_kl_loss: 9.8884
# Epoch 6/75
# 549/549 [==============================] - 10s 19ms/step - loss: 28.7177 - reconstruction_loss: 18.8357 - kl_loss: 8.8126 - val_loss: 26.6449 - val_reconstruction_loss: 17.5640 - val_kl_loss: 9.0810
# Epoch 7/75
# 549/549 [==============================] - 10s 19ms/step - loss: 25.3728 - reconstruction_loss: 16.1531 - kl_loss: 8.9438 - val_loss: 18.7079 - val_reconstruction_loss: 9.2719 - val_kl_loss: 9.4359
# Epoch 8/75
# 549/549 [==============================] - 10s 19ms/step - loss: 23.5748 - reconstruction_loss: 15.0665 - kl_loss: 9.0026 - val_loss: 25.0718 - val_reconstruction_loss: 16.2131 - val_kl_loss: 8.8587
# Epoch 9/75
# 549/549 [==============================] - 11s 19ms/step - loss: 23.5980 - reconstruction_loss: 14.3267 - kl_loss: 9.0643 - val_loss: 25.9657 - val_reconstruction_loss: 16.9556 - val_kl_loss: 9.0101
# Epoch 10/75
# 549/549 [==============================] - 10s 19ms/step - loss: 23.1937 - reconstruction_loss: 13.8771 - kl_loss: 9.0732 - val_loss: 21.1885 - val_reconstruction_loss: 11.7523 - val_kl_loss: 9.4362
# Epoch 11/75
# 549/549 [==============================] - 11s 19ms/step - loss: 22.7421 - reconstruction_loss: 13.6249 - kl_loss: 9.1451 - val_loss: 19.0049 - val_reconstruction_loss: 9.4219 - val_kl_loss: 9.5829
# Epoch 12/75
# 549/549 [==============================] - 10s 19ms/step - loss: 22.2056 - reconstruction_loss: 13.0305 - kl_loss: 9.1105 - val_loss: 29.2279 - val_reconstruction_loss: 20.0192 - val_kl_loss: 9.2086
# Epoch 13/75
# 549/549 [==============================] - 10s 19ms/step - loss: 22.3763 - reconstruction_loss: 13.0386 - kl_loss: 9.1788 - val_loss: 22.5533 - val_reconstruction_loss: 13.4750 - val_kl_loss: 9.0783
# Epoch 14/75
# 549/549 [==============================] - 11s 19ms/step - loss: 22.0392 - reconstruction_loss: 12.7890 - kl_loss: 9.1952 - val_loss: 19.4033 - val_reconstruction_loss: 10.6965 - val_kl_loss: 8.7068
# Epoch 15/75
# 549/549 [==============================] - 11s 19ms/step - loss: 21.9262 - reconstruction_loss: 12.8890 - kl_loss: 9.1425 - val_loss: 20.9745 - val_reconstruction_loss: 11.9735 - val_kl_loss: 9.0010
# Epoch 16/75
# 549/549 [==============================] - 10s 19ms/step - loss: 21.2119 - reconstruction_loss: 12.1484 - kl_loss: 9.1563 - val_loss: 20.6023 - val_reconstruction_loss: 11.3256 - val_kl_loss: 9.2767
# Epoch 17/75
# 549/549 [==============================] - 10s 19ms/step - loss: 21.6006 - reconstruction_loss: 12.4417 - kl_loss: 9.1919 - val_loss: 24.1967 - val_reconstruction_loss: 15.2260 - val_kl_loss: 8.9707
# Epoch 18/75
# 549/549 [==============================] - 10s 19ms/step - loss: 21.3432 - reconstruction_loss: 12.0230 - kl_loss: 9.2422 - val_loss: 17.6054 - val_reconstruction_loss: 8.7180 - val_kl_loss: 8.8874
# Epoch 19/75
# 549/549 [==============================] - 10s 19ms/step - loss: 21.5275 - reconstruction_loss: 12.1876 - kl_loss: 9.1871 - val_loss: 22.8097 - val_reconstruction_loss: 13.1256 - val_kl_loss: 9.6841
# Epoch 20/75
# 549/549 [==============================] - 10s 19ms/step - loss: 21.3805 - reconstruction_loss: 11.9958 - kl_loss: 9.2311 - val_loss: 21.0722 - val_reconstruction_loss: 12.0424 - val_kl_loss: 9.0298
# Epoch 21/75
# 549/549 [==============================] - 10s 19ms/step - loss: 20.8082 - reconstruction_loss: 11.7063 - kl_loss: 9.2609 - val_loss: 18.4593 - val_reconstruction_loss: 8.7420 - val_kl_loss: 9.7172
# Epoch 22/75
# 549/549 [==============================] - 10s 19ms/step - loss: 21.0741 - reconstruction_loss: 11.7285 - kl_loss: 9.2652 - val_loss: 21.6218 - val_reconstruction_loss: 12.8339 - val_kl_loss: 8.7879
# Epoch 23/75
# 549/549 [==============================] - 11s 20ms/step - loss: 20.5546 - reconstruction_loss: 11.5850 - kl_loss: 9.2306 - val_loss: 31.1210 - val_reconstruction_loss: 20.4550 - val_kl_loss: 10.6660
# Epoch 24/75
# 549/549 [==============================] - 11s 20ms/step - loss: 20.8600 - reconstruction_loss: 11.6922 - kl_loss: 9.2024 - val_loss: 19.8153 - val_reconstruction_loss: 9.7150 - val_kl_loss: 10.1003
# Epoch 25/75
# 549/549 [==============================] - 10s 19ms/step - loss: 20.4926 - reconstruction_loss: 11.4058 - kl_loss: 9.2855 - val_loss: 19.5892 - val_reconstruction_loss: 10.7415 - val_kl_loss: 8.8477
# Epoch 26/75
# 549/549 [==============================] - 11s 19ms/step - loss: 20.3658 - reconstruction_loss: 11.6323 - kl_loss: 9.2570 - val_loss: 34.8806 - val_reconstruction_loss: 24.5771 - val_kl_loss: 10.3036
# Epoch 27/75
# 549/549 [==============================] - 11s 19ms/step - loss: 21.4628 - reconstruction_loss: 11.6133 - kl_loss: 9.2336 - val_loss: 31.4553 - val_reconstruction_loss: 22.6347 - val_kl_loss: 8.8206
# Epoch 28/75
# 549/549 [==============================] - 11s 19ms/step - loss: 20.6588 - reconstruction_loss: 11.4033 - kl_loss: 9.3184 - val_loss: 16.3251 - val_reconstruction_loss: 7.7477 - val_kl_loss: 8.5774
# Epoch 29/75
# 549/549 [==============================] - 10s 19ms/step - loss: 20.1963 - reconstruction_loss: 11.0745 - kl_loss: 9.2030 - val_loss: 16.5778 - val_reconstruction_loss: 6.4316 - val_kl_loss: 10.1462
# Epoch 30/75
# 549/549 [==============================] - 11s 19ms/step - loss: 20.7750 - reconstruction_loss: 11.3664 - kl_loss: 9.3760 - val_loss: 29.8437 - val_reconstruction_loss: 20.5169 - val_kl_loss: 9.3268
# Epoch 31/75
# 549/549 [==============================] - 10s 17ms/step - loss: 19.7959 - reconstruction_loss: 10.6767 - kl_loss: 9.2492 - val_loss: 22.6481 - val_reconstruction_loss: 13.1930 - val_kl_loss: 9.4551
# Epoch 32/75
# 549/549 [==============================] - 10s 18ms/step - loss: 20.2087 - reconstruction_loss: 10.9867 - kl_loss: 9.2545 - val_loss: 21.8942 - val_reconstruction_loss: 11.6616 - val_kl_loss: 10.2326
# Epoch 33/75
# 549/549 [==============================] - 10s 18ms/step - loss: 19.9566 - reconstruction_loss: 10.9028 - kl_loss: 9.3189 - val_loss: 20.2339 - val_reconstruction_loss: 9.7575 - val_kl_loss: 10.4765
# Epoch 34/75
# 549/549 [==============================] - 10s 19ms/step - loss: 20.2963 - reconstruction_loss: 11.0187 - kl_loss: 9.3125 - val_loss: 17.3274 - val_reconstruction_loss: 8.0157 - val_kl_loss: 9.3116
# Epoch 35/75
# 549/549 [==============================] - 10s 18ms/step - loss: 19.8753 - reconstruction_loss: 10.7607 - kl_loss: 9.2748 - val_loss: 18.5935 - val_reconstruction_loss: 9.3937 - val_kl_loss: 9.1998
# Epoch 36/75
# 549/549 [==============================] - 10s 19ms/step - loss: 19.8600 - reconstruction_loss: 10.5931 - kl_loss: 9.2263 - val_loss: 16.8658 - val_reconstruction_loss: 7.6737 - val_kl_loss: 9.1922
# Epoch 37/75
# 549/549 [==============================] - 10s 18ms/step - loss: 19.8260 - reconstruction_loss: 10.6562 - kl_loss: 9.2858 - val_loss: 17.0287 - val_reconstruction_loss: 7.9710 - val_kl_loss: 9.0577
# Epoch 38/75
# 549/549 [==============================] - 10s 18ms/step - loss: 19.6419 - reconstruction_loss: 10.6502 - kl_loss: 9.2924 - val_loss: 17.9627 - val_reconstruction_loss: 8.0890 - val_kl_loss: 9.8736
# Epoch 39/75
# 549/549 [==============================] - 10s 19ms/step - loss: 19.8687 - reconstruction_loss: 10.4818 - kl_loss: 9.2411 - val_loss: 22.0544 - val_reconstruction_loss: 12.9271 - val_kl_loss: 9.1273
# Epoch 40/75
# 549/549 [==============================] - 10s 18ms/step - loss: 20.2836 - reconstruction_loss: 10.8859 - kl_loss: 9.3118 - val_loss: 15.7787 - val_reconstruction_loss: 7.1937 - val_kl_loss: 8.5850
# Epoch 41/75
# 549/549 [==============================] - 9s 17ms/step - loss: 19.9888 - reconstruction_loss: 10.7749 - kl_loss: 9.3609 - val_loss: 15.6528 - val_reconstruction_loss: 6.3684 - val_kl_loss: 9.2844
# Epoch 42/75
# 549/549 [==============================] - 9s 17ms/step - loss: 19.7636 - reconstruction_loss: 10.2508 - kl_loss: 9.2519 - val_loss: 19.7947 - val_reconstruction_loss: 10.5071 - val_kl_loss: 9.2875
# Epoch 43/75
# 549/549 [==============================] - 9s 17ms/step - loss: 19.7305 - reconstruction_loss: 10.6456 - kl_loss: 9.3437 - val_loss: 23.0775 - val_reconstruction_loss: 13.5562 - val_kl_loss: 9.5214
# Epoch 44/75
# 549/549 [==============================] - 9s 17ms/step - loss: 19.9933 - reconstruction_loss: 10.5846 - kl_loss: 9.3501 - val_loss: 15.3845 - val_reconstruction_loss: 5.7774 - val_kl_loss: 9.6071
# Epoch 45/75
# 549/549 [==============================] - 10s 17ms/step - loss: 19.3801 - reconstruction_loss: 10.1523 - kl_loss: 9.2027 - val_loss: 16.9377 - val_reconstruction_loss: 7.2208 - val_kl_loss: 9.7169
# Epoch 46/75
# 549/549 [==============================] - 9s 17ms/step - loss: 20.4838 - reconstruction_loss: 10.5953 - kl_loss: 9.2889 - val_loss: 15.5004 - val_reconstruction_loss: 6.2135 - val_kl_loss: 9.2869
# Epoch 47/75
# 549/549 [==============================] - 10s 17ms/step - loss: 19.6794 - reconstruction_loss: 10.3903 - kl_loss: 9.2846 - val_loss: 15.7334 - val_reconstruction_loss: 6.3749 - val_kl_loss: 9.3585
# Epoch 48/75
# 549/549 [==============================] - 10s 17ms/step - loss: 19.6819 - reconstruction_loss: 12.6902 - kl_loss: 9.3447 - val_loss: 34.7216 - val_reconstruction_loss: 26.0942 - val_kl_loss: 8.6275
# Epoch 49/75
# 549/549 [==============================] - 9s 17ms/step - loss: 26.0863 - reconstruction_loss: 13.1274 - kl_loss: 9.3247 - val_loss: 17.4350 - val_reconstruction_loss: 8.1546 - val_kl_loss: 9.2804
# Epoch 50/75
# 549/549 [==============================] - 9s 17ms/step - loss: 20.0991 - reconstruction_loss: 10.5385 - kl_loss: 9.3158 - val_loss: 20.7426 - val_reconstruction_loss: 11.2577 - val_kl_loss: 9.4849
# Epoch 51/75
# 549/549 [==============================] - 9s 17ms/step - loss: 19.9185 - reconstruction_loss: 10.5236 - kl_loss: 9.3840 - val_loss: 19.0657 - val_reconstruction_loss: 9.1899 - val_kl_loss: 9.8758
# Epoch 52/75
# 549/549 [==============================] - 10s 18ms/step - loss: 20.0314 - reconstruction_loss: 10.6108 - kl_loss: 9.3884 - val_loss: 20.3021 - val_reconstruction_loss: 10.9819 - val_kl_loss: 9.3202
# Epoch 53/75
# 549/549 [==============================] - 10s 18ms/step - loss: 19.1673 - reconstruction_loss: 10.3808 - kl_loss: 9.3244 - val_loss: 16.9960 - val_reconstruction_loss: 7.5744 - val_kl_loss: 9.4216
# Epoch 54/75
# 549/549 [==============================] - 10s 18ms/step - loss: 19.5402 - reconstruction_loss: 10.1801 - kl_loss: 9.2775 - val_loss: 18.5270 - val_reconstruction_loss: 8.6015 - val_kl_loss: 9.9255
# Epoch 55/75
# 549/549 [==============================] - 10s 19ms/step - loss: 20.1288 - reconstruction_loss: 10.3591 - kl_loss: 9.2856 - val_loss: 19.0323 - val_reconstruction_loss: 9.6387 - val_kl_loss: 9.3936
# Epoch 56/75
# 549/549 [==============================] - 11s 19ms/step - loss: 19.5352 - reconstruction_loss: 10.3594 - kl_loss: 9.3370 - val_loss: 19.6528 - val_reconstruction_loss: 10.4630 - val_kl_loss: 9.1898
# Epoch 57/75
# 549/549 [==============================] - 11s 19ms/step - loss: 19.3170 - reconstruction_loss: 10.1210 - kl_loss: 9.2663 - val_loss: 11.7814 - val_reconstruction_loss: 2.7149 - val_kl_loss: 9.0665
# Epoch 58/75
# 549/549 [==============================] - 11s 19ms/step - loss: 20.0148 - reconstruction_loss: 10.8841 - kl_loss: 9.4136 - val_loss: 19.1453 - val_reconstruction_loss: 9.2442 - val_kl_loss: 9.9011
# Epoch 59/75
# 549/549 [==============================] - 11s 19ms/step - loss: 19.5407 - reconstruction_loss: 9.9973 - kl_loss: 9.2541 - val_loss: 16.4508 - val_reconstruction_loss: 6.9772 - val_kl_loss: 9.4737
# Epoch 60/75
# 549/549 [==============================] - 10s 19ms/step - loss: 20.0422 - reconstruction_loss: 10.5437 - kl_loss: 9.3053 - val_loss: 20.1764 - val_reconstruction_loss: 9.8561 - val_kl_loss: 10.3203
# Epoch 61/75
# 549/549 [==============================] - 10s 18ms/step - loss: 19.1771 - reconstruction_loss: 10.0082 - kl_loss: 9.3532 - val_loss: 12.6036 - val_reconstruction_loss: 3.7232 - val_kl_loss: 8.8804
# Epoch 62/75
# 549/549 [==============================] - 10s 19ms/step - loss: 19.2750 - reconstruction_loss: 10.2247 - kl_loss: 9.2890 - val_loss: 17.1537 - val_reconstruction_loss: 7.0538 - val_kl_loss: 10.0999
# Epoch 63/75
# 549/549 [==============================] - 10s 19ms/step - loss: 19.4253 - reconstruction_loss: 10.0875 - kl_loss: 9.2583 - val_loss: 17.7178 - val_reconstruction_loss: 8.8261 - val_kl_loss: 8.8917
# Epoch 64/75
# 549/549 [==============================] - 10s 19ms/step - loss: 19.4680 - reconstruction_loss: 10.1702 - kl_loss: 9.2477 - val_loss: 17.7123 - val_reconstruction_loss: 8.1520 - val_kl_loss: 9.5603
# Epoch 65/75
# 549/549 [==============================] - 10s 18ms/step - loss: 19.4403 - reconstruction_loss: 10.0297 - kl_loss: 9.3358 - val_loss: 21.7466 - val_reconstruction_loss: 12.3580 - val_kl_loss: 9.3886
# Epoch 66/75
# 549/549 [==============================] - 10s 19ms/step - loss: 19.9011 - reconstruction_loss: 10.6831 - kl_loss: 9.4509 - val_loss: 19.8467 - val_reconstruction_loss: 10.6392 - val_kl_loss: 9.2075
# Epoch 67/75
# 549/549 [==============================] - 10s 19ms/step - loss: 19.1374 - reconstruction_loss: 9.8295 - kl_loss: 9.2730 - val_loss: 19.8886 - val_reconstruction_loss: 10.3936 - val_kl_loss: 9.4950
# Epoch 68/75
# 549/549 [==============================] - 11s 19ms/step - loss: 19.2742 - reconstruction_loss: 9.9555 - kl_loss: 9.2598 - val_loss: 18.9352 - val_reconstruction_loss: 9.2556 - val_kl_loss: 9.6796
# Epoch 69/75
# 549/549 [==============================] - 10s 18ms/step - loss: 19.6190 - reconstruction_loss: 10.0578 - kl_loss: 9.3576 - val_loss: 17.6869 - val_reconstruction_loss: 7.5438 - val_kl_loss: 10.1431
# Epoch 70/75
# 549/549 [==============================] - 11s 19ms/step - loss: 18.9995 - reconstruction_loss: 9.8384 - kl_loss: 9.2926 - val_loss: 18.0143 - val_reconstruction_loss: 9.2361 - val_kl_loss: 8.7783
# Epoch 71/75
# 549/549 [==============================] - 11s 20ms/step - loss: 19.0024 - reconstruction_loss: 9.9664 - kl_loss: 9.2986 - val_loss: 14.2924 - val_reconstruction_loss: 4.6018 - val_kl_loss: 9.6906
# Epoch 72/75
# 549/549 [==============================] - 11s 20ms/step - loss: 19.5908 - reconstruction_loss: 9.8757 - kl_loss: 9.2757 - val_loss: 13.4432 - val_reconstruction_loss: 4.0454 - val_kl_loss: 9.3978
# Epoch 73/75
# 549/549 [==============================] - 10s 19ms/step - loss: 19.2220 - reconstruction_loss: 10.0515 - kl_loss: 9.3799 - val_loss: 16.3344 - val_reconstruction_loss: 7.7219 - val_kl_loss: 8.6125
# Epoch 74/75
# 549/549 [==============================] - 10s 19ms/step - loss: 19.9571 - reconstruction_loss: 11.3358 - kl_loss: 9.3231 - val_loss: 21.9450 - val_reconstruction_loss: 12.9920 - val_kl_loss: 8.9530
# Epoch 75/75
# 549/549 [==============================] - 10s 18ms/step - loss: 19.2626 - reconstruction_loss: 9.8408 - kl_loss: 9.2323 - val_loss: 20.3828 - val_reconstruction_loss: 11.0978 - val_kl_loss: 9.2850

# %%
val_rec_loss = history.history['val_reconstruction_loss']
rec_loss = history.history['reconstruction_loss']

epochs = range(1, len(val_rec_loss) + 1)    

plt.plot(epochs, val_rec_loss, 'b', label='Val Reconstruction loss')
plt.plot(epochs, rec_loss, 'bo', label='Reconstruction loss')
plt.title('Reconstruction and KL loss')
plt.legend()

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

for i in range(n):
    rand_img = random.randint(0, DATASET_SIZE)
    img = img_to_array(load_img(f"images_trans/pong_trans_{rand_img}.png", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# /home/loptt/.local/lib/python3.8/site-packages/matplotlib/image.py:446: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /home/loptt/.local/lib/python3.8/site-packages/matplotlib/image.py:453: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /home/loptt/.local/lib/python3.8/site-packages/matplotlib/image.py:458: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 100.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = rest = [i * 10 for i in range(-7, 7)]
            # missing =  -2.9679005e+00, -1.7151514e+01    
            z_sample = np.array([[xi, yi] + rest])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)
