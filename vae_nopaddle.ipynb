# %% [markdown]
# ## Variational Autoencoder

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAE as VAE

DATASET_SIZE = 25084
INPUT_SHAPE = (40, 30, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    raise Exception("Cannot initialize GPU")

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_paddleless/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training'
)

val_datagen = datagen.flow_from_directory(
    'images_paddleless/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation'
)
# Out:
# Found 9706 images belonging to 1 classes.
# Found 4159 images belonging to 1 classes.

# %%
vae = VAE(
    layers=3,
    latent_size=8,
    kernel_size=3,
    filters=16,
    input_shape=INPUT_SHAPE,
    name="VAE"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 40, 30, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 40, 30, 16)   160         input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 20, 15, 16)   0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 20, 15, 32)   4640        maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 10, 8, 32)    0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 10, 8, 64)    18496       maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 5, 4, 64)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1280)         0           maxpool3[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 8)            10248       flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 8)            72          bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 8)            72          bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling_3 (Sampling)           (None, 8)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 33,688
# Trainable params: 33,688
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 8)]               0
# _________________________________________________________________
# decoding (Dense)             (None, 1280)              11520
# _________________________________________________________________
# reshape (Reshape)            (None, 5, 4, 64)          0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 5, 4, 64)          36928
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 10, 8, 64)         0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 10, 8, 32)         18464
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 20, 16, 32)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 20, 16, 16)        4624
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 40, 32, 16)        0
# _________________________________________________________________
# output (Conv2D)              (None, 40, 30, 1)         49
# =================================================================
# Total params: 71,585
# Trainable params: 71,585
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 8), (None, 8), (N 33688
# _________________________________________________________________
# Decoder (Functional)         (None, 40, 30, 1)         71585
# =================================================================
# Total params: 105,279
# Trainable params: 105,273
# Non-trainable params: 6
# _________________________________________________________________

# %%
callbacks = [
    #EarlyStopping(monitor='val_loss', patience=15),
    #TensorBoard(
    #    log_dir='./logs',
    #    histogram_freq=1
    #)
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=200, 
    callbacks=callbacks
)
# Out:
#  - reconstruction_loss: 4.3280 - kl_loss: 5.3113 - val_loss: 8.3775 - val_reconstruction_loss: 3.3345 - val_kl_loss: 5.0430
# Epoch 105/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6569 - reconstruction_loss: 4.3257 - kl_loss: 5.2877 - val_loss: 8.7216 - val_reconstruction_loss: 3.4371 - val_kl_loss: 5.2846
# Epoch 106/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6042 - reconstruction_loss: 4.3347 - kl_loss: 5.2807 - val_loss: 8.8981 - val_reconstruction_loss: 3.9433 - val_kl_loss: 4.9547
# Epoch 107/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6669 - reconstruction_loss: 4.3242 - kl_loss: 5.2862 - val_loss: 9.9463 - val_reconstruction_loss: 4.8313 - val_kl_loss: 5.1150
# Epoch 108/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6878 - reconstruction_loss: 4.3312 - kl_loss: 5.3137 - val_loss: 8.9708 - val_reconstruction_loss: 3.8715 - val_kl_loss: 5.0993
# Epoch 109/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6269 - reconstruction_loss: 4.3225 - kl_loss: 5.3092 - val_loss: 8.3013 - val_reconstruction_loss: 3.2163 - val_kl_loss: 5.0850
# Epoch 110/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6493 - reconstruction_loss: 4.3148 - kl_loss: 5.3393 - val_loss: 9.2367 - val_reconstruction_loss: 4.1672 - val_kl_loss: 5.0694
# Epoch 111/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5855 - reconstruction_loss: 4.3179 - kl_loss: 5.3248 - val_loss: 9.2925 - val_reconstruction_loss: 4.0022 - val_kl_loss: 5.2903
# Epoch 112/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5982 - reconstruction_loss: 4.2952 - kl_loss: 5.3410 - val_loss: 9.5003 - val_reconstruction_loss: 4.1321 - val_kl_loss: 5.3682
# Epoch 113/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5952 - reconstruction_loss: 4.2949 - kl_loss: 5.3425 - val_loss: 9.4530 - val_reconstruction_loss: 4.5582 - val_kl_loss: 4.8948
# Epoch 114/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5825 - reconstruction_loss: 4.3044 - kl_loss: 5.3064 - val_loss: 9.7207 - val_reconstruction_loss: 4.0736 - val_kl_loss: 5.6471
# Epoch 115/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6022 - reconstruction_loss: 4.2897 - kl_loss: 5.3008 - val_loss: 9.3583 - val_reconstruction_loss: 4.1302 - val_kl_loss: 5.2282
# Epoch 116/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6426 - reconstruction_loss: 4.3001 - kl_loss: 5.3218 - val_loss: 9.0073 - val_reconstruction_loss: 4.0010 - val_kl_loss: 5.0063
# Epoch 117/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6318 - reconstruction_loss: 4.2941 - kl_loss: 5.3257 - val_loss: 9.8600 - val_reconstruction_loss: 4.3002 - val_kl_loss: 5.5597
# Epoch 118/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5749 - reconstruction_loss: 4.2642 - kl_loss: 5.3230 - val_loss: 9.2535 - val_reconstruction_loss: 3.9277 - val_kl_loss: 5.3258
# Epoch 119/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6090 - reconstruction_loss: 4.3113 - kl_loss: 5.2967 - val_loss: 9.1899 - val_reconstruction_loss: 3.8197 - val_kl_loss: 5.3702
# Epoch 120/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6307 - reconstruction_loss: 4.2636 - kl_loss: 5.3626 - val_loss: 9.0159 - val_reconstruction_loss: 3.7838 - val_kl_loss: 5.2321
# Epoch 121/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6272 - reconstruction_loss: 4.2959 - kl_loss: 5.3367 - val_loss: 9.1009 - val_reconstruction_loss: 4.0255 - val_kl_loss: 5.0754
# Epoch 122/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6035 - reconstruction_loss: 4.3049 - kl_loss: 5.2897 - val_loss: 9.9654 - val_reconstruction_loss: 4.7077 - val_kl_loss: 5.2576
# Epoch 123/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5588 - reconstruction_loss: 4.2413 - kl_loss: 5.3373 - val_loss: 8.8519 - val_reconstruction_loss: 3.7582 - val_kl_loss: 5.0937
# Epoch 124/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6375 - reconstruction_loss: 4.2886 - kl_loss: 5.3302 - val_loss: 8.8078 - val_reconstruction_loss: 3.6207 - val_kl_loss: 5.1871
# Epoch 125/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5682 - reconstruction_loss: 4.2702 - kl_loss: 5.2993 - val_loss: 9.3848 - val_reconstruction_loss: 4.0395 - val_kl_loss: 5.3453
# Epoch 126/200
# 304/304 [==============================] - 2s 8ms/step - loss: 9.6337 - reconstruction_loss: 4.2368 - kl_loss: 5.3542 - val_loss: 8.7030 - val_reconstruction_loss: 3.6639 - val_kl_loss: 5.0391
# Epoch 127/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6184 - reconstruction_loss: 4.2606 - kl_loss: 5.3541 - val_loss: 10.6363 - val_reconstruction_loss: 5.3896 - val_kl_loss: 5.2467
# Epoch 128/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6220 - reconstruction_loss: 4.2562 - kl_loss: 5.3518 - val_loss: 8.9409 - val_reconstruction_loss: 3.8689 - val_kl_loss: 5.0720
# Epoch 129/200
# 304/304 [==============================] - 2s 8ms/step - loss: 9.6092 - reconstruction_loss: 4.2514 - kl_loss: 5.3566 - val_loss: 9.4115 - val_reconstruction_loss: 4.2532 - val_kl_loss: 5.1582
# Epoch 130/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5221 - reconstruction_loss: 4.2474 - kl_loss: 5.3550 - val_loss: 9.4574 - val_reconstruction_loss: 4.0566 - val_kl_loss: 5.4008
# Epoch 131/200
# 304/304 [==============================] - 3s 9ms/step - loss: 9.5472 - reconstruction_loss: 4.2365 - kl_loss: 5.3388 - val_loss: 8.7864 - val_reconstruction_loss: 3.9319 - val_kl_loss: 4.8545
# Epoch 132/200
# 304/304 [==============================] - 3s 9ms/step - loss: 9.6315 - reconstruction_loss: 4.2393 - kl_loss: 5.3776 - val_loss: 10.1460 - val_reconstruction_loss: 5.2187 - val_kl_loss: 4.9273
# Epoch 133/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5341 - reconstruction_loss: 4.2234 - kl_loss: 5.3623 - val_loss: 9.4962 - val_reconstruction_loss: 4.2568 - val_kl_loss: 5.2394
# Epoch 134/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6242 - reconstruction_loss: 4.2431 - kl_loss: 5.3544 - val_loss: 9.1992 - val_reconstruction_loss: 4.3047 - val_kl_loss: 4.8945
# Epoch 135/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6504 - reconstruction_loss: 4.2314 - kl_loss: 5.3501 - val_loss: 8.6965 - val_reconstruction_loss: 3.5384 - val_kl_loss: 5.1581
# Epoch 136/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5914 - reconstruction_loss: 4.2405 - kl_loss: 5.3395 - val_loss: 9.0527 - val_reconstruction_loss: 3.7487 - val_kl_loss: 5.3040
# Epoch 137/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5535 - reconstruction_loss: 4.1918 - kl_loss: 5.3518 - val_loss: 7.8832 - val_reconstruction_loss: 3.1028 - val_kl_loss: 4.7804
# Epoch 138/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5522 - reconstruction_loss: 4.1947 - kl_loss: 5.3555 - val_loss: 8.7506 - val_reconstruction_loss: 3.5880 - val_kl_loss: 5.1626
# Epoch 139/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5760 - reconstruction_loss: 4.2223 - kl_loss: 5.3593 - val_loss: 9.7468 - val_reconstruction_loss: 4.8202 - val_kl_loss: 4.9266
# Epoch 140/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6014 - reconstruction_loss: 4.2157 - kl_loss: 5.3549 - val_loss: 9.4776 - val_reconstruction_loss: 4.1431 - val_kl_loss: 5.3345
# Epoch 141/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5192 - reconstruction_loss: 4.2013 - kl_loss: 5.3458 - val_loss: 9.4557 - val_reconstruction_loss: 4.0130 - val_kl_loss: 5.4427
# Epoch 142/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6274 - reconstruction_loss: 4.2063 - kl_loss: 5.3847 - val_loss: 8.3970 - val_reconstruction_loss: 3.1697 - val_kl_loss: 5.2273
# Epoch 143/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5469 - reconstruction_loss: 4.1839 - kl_loss: 5.3761 - val_loss: 8.3386 - val_reconstruction_loss: 3.1950 - val_kl_loss: 5.1436
# Epoch 144/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5378 - reconstruction_loss: 4.2053 - kl_loss: 5.3485 - val_loss: 9.7162 - val_reconstruction_loss: 4.5701 - val_kl_loss: 5.1461
# Epoch 145/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5742 - reconstruction_loss: 4.1811 - kl_loss: 5.3746 - val_loss: 9.3954 - val_reconstruction_loss: 4.0735 - val_kl_loss: 5.3219
# Epoch 146/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5783 - reconstruction_loss: 4.1931 - kl_loss: 5.3553 - val_loss: 8.9622 - val_reconstruction_loss: 3.8037 - val_kl_loss: 5.1586
# Epoch 147/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5599 - reconstruction_loss: 4.1783 - kl_loss: 5.3849 - val_loss: 9.8028 - val_reconstruction_loss: 4.6802 - val_kl_loss: 5.1226
# Epoch 148/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5463 - reconstruction_loss: 4.1883 - kl_loss: 5.3561 - val_loss: 9.6334 - val_reconstruction_loss: 4.1891 - val_kl_loss: 5.4443
# Epoch 149/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.6040 - reconstruction_loss: 4.2004 - kl_loss: 5.3853 - val_loss: 8.8098 - val_reconstruction_loss: 3.7370 - val_kl_loss: 5.0728
# Epoch 150/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5033 - reconstruction_loss: 4.1900 - kl_loss: 5.3538 - val_loss: 9.8135 - val_reconstruction_loss: 4.6155 - val_kl_loss: 5.1979
# Epoch 151/200
# 304/304 [==============================] - 2s 8ms/step - loss: 9.5084 - reconstruction_loss: 4.1729 - kl_loss: 5.3718 - val_loss: 9.1196 - val_reconstruction_loss: 3.9833 - val_kl_loss: 5.1363
# Epoch 152/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5293 - reconstruction_loss: 4.1847 - kl_loss: 5.3718 - val_loss: 8.6389 - val_reconstruction_loss: 3.4657 - val_kl_loss: 5.1732
# Epoch 153/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5906 - reconstruction_loss: 4.1837 - kl_loss: 5.3630 - val_loss: 9.1148 - val_reconstruction_loss: 4.1059 - val_kl_loss: 5.0090
# Epoch 154/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5745 - reconstruction_loss: 4.1838 - kl_loss: 5.3765 - val_loss: 8.7876 - val_reconstruction_loss: 3.8127 - val_kl_loss: 4.9749
# Epoch 155/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5939 - reconstruction_loss: 4.2036 - kl_loss: 5.3848 - val_loss: 8.7339 - val_reconstruction_loss: 3.5118 - val_kl_loss: 5.2222
# Epoch 156/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5762 - reconstruction_loss: 4.1719 - kl_loss: 5.4015 - val_loss: 9.6702 - val_reconstruction_loss: 4.1762 - val_kl_loss: 5.4940
# Epoch 157/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5392 - reconstruction_loss: 4.1669 - kl_loss: 5.3800 - val_loss: 9.2368 - val_reconstruction_loss: 3.8314 - val_kl_loss: 5.4054
# Epoch 158/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5518 - reconstruction_loss: 4.1310 - kl_loss: 5.4152 - val_loss: 8.9628 - val_reconstruction_loss: 3.8050 - val_kl_loss: 5.1578
# Epoch 159/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5260 - reconstruction_loss: 4.1399 - kl_loss: 5.3990 - val_loss: 9.2036 - val_reconstruction_loss: 4.0286 - val_kl_loss: 5.1750
# Epoch 160/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5423 - reconstruction_loss: 4.1584 - kl_loss: 5.3648 - val_loss: 8.8156 - val_reconstruction_loss: 3.6488 - val_kl_loss: 5.1668
# Epoch 161/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5360 - reconstruction_loss: 4.1203 - kl_loss: 5.3980 - val_loss: 9.2191 - val_reconstruction_loss: 3.8702 - val_kl_loss: 5.3489
# Epoch 162/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5363 - reconstruction_loss: 4.1699 - kl_loss: 5.3734 - val_loss: 10.2354 - val_reconstruction_loss: 5.0119 - val_kl_loss: 5.2235
# Epoch 163/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.4922 - reconstruction_loss: 4.1523 - kl_loss: 5.3574 - val_loss: 9.2957 - val_reconstruction_loss: 3.8553 - val_kl_loss: 5.4404
# Epoch 164/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5244 - reconstruction_loss: 4.1597 - kl_loss: 5.3802 - val_loss: 9.3396 - val_reconstruction_loss: 4.1400 - val_kl_loss: 5.1996
# Epoch 165/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5575 - reconstruction_loss: 4.1547 - kl_loss: 5.4170 - val_loss: 8.5319 - val_reconstruction_loss: 3.3465 - val_kl_loss: 5.1854
# Epoch 166/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5210 - reconstruction_loss: 4.1444 - kl_loss: 5.3577 - val_loss: 9.0039 - val_reconstruction_loss: 3.8801 - val_kl_loss: 5.1238
# Epoch 167/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.4956 - reconstruction_loss: 4.1406 - kl_loss: 5.3864 - val_loss: 8.3975 - val_reconstruction_loss: 3.3089 - val_kl_loss: 5.0886
# Epoch 168/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5083 - reconstruction_loss: 4.1368 - kl_loss: 5.3929 - val_loss: 8.4415 - val_reconstruction_loss: 3.2536 - val_kl_loss: 5.1879
# Epoch 169/200
# 304/304 [==============================] - 3s 9ms/step - loss: 9.5298 - reconstruction_loss: 4.1373 - kl_loss: 5.4254 - val_loss: 10.0174 - val_reconstruction_loss: 4.3915 - val_kl_loss: 5.6260
# Epoch 170/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5794 - reconstruction_loss: 4.1226 - kl_loss: 5.4281 - val_loss: 9.0133 - val_reconstruction_loss: 3.6757 - val_kl_loss: 5.3376
# Epoch 171/200
# 304/304 [==============================] - 3s 9ms/step - loss: 9.5463 - reconstruction_loss: 4.1309 - kl_loss: 5.4300 - val_loss: 9.0141 - val_reconstruction_loss: 3.7572 - val_kl_loss: 5.2569
# Epoch 172/200
# 304/304 [==============================] - 3s 9ms/step - loss: 9.4862 - reconstruction_loss: 4.1134 - kl_loss: 5.3852 - val_loss: 8.8444 - val_reconstruction_loss: 3.1683 - val_kl_loss: 5.6761
# Epoch 173/200
# 304/304 [==============================] - 3s 9ms/step - loss: 9.5541 - reconstruction_loss: 4.1068 - kl_loss: 5.4197 - val_loss: 9.4681 - val_reconstruction_loss: 4.5288 - val_kl_loss: 4.9393
# Epoch 174/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5240 - reconstruction_loss: 4.1279 - kl_loss: 5.4231 - val_loss: 9.5108 - val_reconstruction_loss: 4.3281 - val_kl_loss: 5.1828
# Epoch 175/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5825 - reconstruction_loss: 4.1173 - kl_loss: 5.4169 - val_loss: 8.8761 - val_reconstruction_loss: 3.7550 - val_kl_loss: 5.1211
# Epoch 176/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5205 - reconstruction_loss: 4.1075 - kl_loss: 5.4176 - val_loss: 8.9863 - val_reconstruction_loss: 3.8576 - val_kl_loss: 5.1287
# Epoch 177/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5062 - reconstruction_loss: 4.0941 - kl_loss: 5.4236 - val_loss: 9.9578 - val_reconstruction_loss: 4.3944 - val_kl_loss: 5.5634
# Epoch 178/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5532 - reconstruction_loss: 4.1052 - kl_loss: 5.4222 - val_loss: 8.6325 - val_reconstruction_loss: 3.5945 - val_kl_loss: 5.0380
# Epoch 179/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5219 - reconstruction_loss: 4.0910 - kl_loss: 5.4171 - val_loss: 9.1139 - val_reconstruction_loss: 3.8618 - val_kl_loss: 5.2521
# Epoch 180/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.4625 - reconstruction_loss: 4.1116 - kl_loss: 5.4071 - val_loss: 8.1572 - val_reconstruction_loss: 2.7873 - val_kl_loss: 5.3699
# Epoch 181/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.4946 - reconstruction_loss: 4.0968 - kl_loss: 5.4030 - val_loss: 9.0157 - val_reconstruction_loss: 3.6510 - val_kl_loss: 5.3646
# Epoch 182/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5170 - reconstruction_loss: 4.1053 - kl_loss: 5.3869 - val_loss: 8.7316 - val_reconstruction_loss: 3.6088 - val_kl_loss: 5.1229
# Epoch 183/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5356 - reconstruction_loss: 4.0750 - kl_loss: 5.4358 - val_loss: 8.6292 - val_reconstruction_loss: 3.3249 - val_kl_loss: 5.3043
# Epoch 184/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5240 - reconstruction_loss: 4.0842 - kl_loss: 5.4218 - val_loss: 9.2112 - val_reconstruction_loss: 3.9288 - val_kl_loss: 5.2824
# Epoch 185/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5767 - reconstruction_loss: 4.1255 - kl_loss: 5.4510 - val_loss: 8.6889 - val_reconstruction_loss: 3.6166 - val_kl_loss: 5.0724
# Epoch 186/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5179 - reconstruction_loss: 4.1187 - kl_loss: 5.4041 - val_loss: 9.6155 - val_reconstruction_loss: 4.4383 - val_kl_loss: 5.1772
# Epoch 187/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.4829 - reconstruction_loss: 4.0860 - kl_loss: 5.3983 - val_loss: 8.9525 - val_reconstruction_loss: 3.7258 - val_kl_loss: 5.2267
# Epoch 188/200
# 304/304 [==============================] - 2s 8ms/step - loss: 9.5471 - reconstruction_loss: 4.1101 - kl_loss: 5.3965 - val_loss: 8.7929 - val_reconstruction_loss: 3.7297 - val_kl_loss: 5.0632
# Epoch 189/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5004 - reconstruction_loss: 4.1023 - kl_loss: 5.3996 - val_loss: 9.5796 - val_reconstruction_loss: 4.3303 - val_kl_loss: 5.2493
# Epoch 190/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.4831 - reconstruction_loss: 4.0983 - kl_loss: 5.4004 - val_loss: 9.2835 - val_reconstruction_loss: 4.0245 - val_kl_loss: 5.2590
# Epoch 191/200
# 304/304 [==============================] - 2s 8ms/step - loss: 9.4280 - reconstruction_loss: 4.0693 - kl_loss: 5.4163 - val_loss: 8.9499 - val_reconstruction_loss: 3.8955 - val_kl_loss: 5.0543
# Epoch 192/200
# 304/304 [==============================] - 2s 8ms/step - loss: 9.4605 - reconstruction_loss: 4.0728 - kl_loss: 5.3918 - val_loss: 9.6873 - val_reconstruction_loss: 4.2919 - val_kl_loss: 5.3954
# Epoch 193/200
# 304/304 [==============================] - 2s 8ms/step - loss: 9.4849 - reconstruction_loss: 4.0815 - kl_loss: 5.4375 - val_loss: 9.4328 - val_reconstruction_loss: 4.0441 - val_kl_loss: 5.3887
# Epoch 194/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.4758 - reconstruction_loss: 4.0976 - kl_loss: 5.3952 - val_loss: 9.5292 - val_reconstruction_loss: 4.1436 - val_kl_loss: 5.3856
# Epoch 195/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.4920 - reconstruction_loss: 4.0558 - kl_loss: 5.4294 - val_loss: 8.7135 - val_reconstruction_loss: 3.3968 - val_kl_loss: 5.3167
# Epoch 196/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.4905 - reconstruction_loss: 4.0547 - kl_loss: 5.4402 - val_loss: 9.2062 - val_reconstruction_loss: 3.7944 - val_kl_loss: 5.4119
# Epoch 197/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.4815 - reconstruction_loss: 4.0555 - kl_loss: 5.4278 - val_loss: 9.9272 - val_reconstruction_loss: 4.5849 - val_kl_loss: 5.3423
# Epoch 198/200
# 304/304 [==============================] - 2s 8ms/step - loss: 9.4926 - reconstruction_loss: 4.0596 - kl_loss: 5.4511 - val_loss: 8.8362 - val_reconstruction_loss: 3.6770 - val_kl_loss: 5.1592
# Epoch 199/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5405 - reconstruction_loss: 4.0564 - kl_loss: 5.4214 - val_loss: 9.4371 - val_reconstruction_loss: 4.2504 - val_kl_loss: 5.1867
# Epoch 200/200
# 304/304 [==============================] - 3s 8ms/step - loss: 9.5410 - reconstruction_loss: 4.0731 - kl_loss: 5.4379 - val_loss: 9.5038 - val_reconstruction_loss: 4.5469 - val_kl_loss: 4.9569

# %%
val_rec_loss = history.history['val_reconstruction_loss']
rec_loss = history.history['reconstruction_loss']

epochs = range(1, len(val_rec_loss) + 1)    

plt.plot(epochs, val_rec_loss, 'b', label='Val Reconstruction loss')
plt.plot(epochs, rec_loss, 'bo', label='Reconstruction loss')
plt.title('Reconstruction and KL loss')
plt.legend()

# %%
import os
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

files = os.listdir("./images_paddleless/")
files = [f[16:f.find('.')] for f in files]

for i in range(n):
    rand_img = random.randint(0, len(files))
    img = img_to_array(load_img(f"images_paddleless/pong_paddleless_{files[rand_img]}.png", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# WARNING:tensorflow:10 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f109a371670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f109a30d700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f109a2ea550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 100.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [4.5645156e+00,  1.5707643e+01,  1.3800155e+01, -1.6270699e+01,
                    1.5749934e+02, -1.1879397e+01, -1.1234385e+01, -3.0332508e+00,
                    7.1921587e+00,  1.1697321e+01,  2.6710289e+00,  2.8224752e+00,
                    2.0286884e+01,  3.5399105e+01]
            # missing =  -2.9679005e+00, -1.7151514e+01    
            z_sample = np.array([ rest + [xi, yi]])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-75e4d8c51eff> in <module>
#      45
#      46
# ---> 47 plot_latent_space(vae)
#
# <ipython-input-32-75e4d8c51eff> in plot_latent_space(vae, n, figsize)
#      22             z_sample = np.array([ rest + [xi, yi]])
#      23             #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
# ---> 24             x_decoded = vae.decoder.predict(z_sample)
#      25             digit = x_decoded[0].reshape(x_input_size, y_input_size)
#      26             figure[
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     860       # In this case we have not created variables on the first call. So we can
#     861       # run the first trace but we should fail if variables are created.
# --> 862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
#     864         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2939     with self._lock:
#    2940       (graph_function,
# -> 2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3355               self.input_signature is None and
#    3356               call_context_key in self._function_cache.missed):
# -> 3357             return self._define_function_with_shape_relaxation(
#    3358                 args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3359
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _define_function_with_shape_relaxation(self, args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3277           expand_composites=True)
#    3278
# -> 3279     graph_function = self._create_graph_function(
#    3280         args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3281     self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3194     arg_names = base_arg_names + missing_arg_names
#    3195     graph_function = ConcreteFunction(
# -> 3196         func_graph_module.func_graph_from_py_func(
#    3197             self._name,
#    3198             self._python_function,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     /home/loptt/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /home/loptt/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/loptt/.local/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/loptt/.local/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/loptt/.local/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/loptt/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /home/loptt/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /home/loptt/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/loptt/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:271 assert_input_compatibility
#         raise ValueError('Input ' + str(input_index) +
#
#     ValueError: Input 0 is incompatible with layer Decoder: expected shape=(None, 8), found shape=(None, 16)

# %%
vae.model.save("models/vae")
# Out:
# INFO:tensorflow:Assets written to: models/vae/assets
