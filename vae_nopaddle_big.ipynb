# %% [markdown]
# ## Variational Autoencoder Big

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAE as VAE

DATASET_SIZE = 25084
INPUT_SHAPE = (40, 30, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    #raise Exception("Cannot initialize GPU")
    pass

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_paddleless_big/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training'
)

val_datagen = datagen.flow_from_directory(
    'images_paddleless_big/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation'
)
# Out:
# Found 9706 images belonging to 1 classes.
# Found 4159 images belonging to 1 classes.

# %%
vae = VAE(
    layers=5,
    latent_size=12,
    kernel_size=3,
    filters=8,
    beta=1,
    input_shape=INPUT_SHAPE,
    name="VAE"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 40, 30, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 40, 30, 8)    80          input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 20, 15, 8)    0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 20, 15, 16)   1168        maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 10, 8, 16)    0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 10, 8, 32)    4640        maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 5, 4, 32)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 5, 4, 64)     18496       maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 3, 2, 64)     0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# conv5_enc (Conv2D)              (None, 3, 2, 128)    73856       maxpool4[0][0]
# __________________________________________________________________________________________________
# maxpool5 (MaxPooling2D)         (None, 2, 1, 128)    0           conv5_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           maxpool5[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 12)           3084        flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 12)           156         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 12)           156         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 12)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 101,636
# Trainable params: 101,636
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 12)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 256)               3328
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 1, 128)         0
# _________________________________________________________________
# conv5_dec (Conv2D)           (None, 2, 1, 128)         147584
# _________________________________________________________________
# upsamp5 (UpSampling2D)       (None, 4, 2, 128)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 4, 2, 64)          73792
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 8, 4, 64)          0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 8, 4, 32)          18464
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 16, 8, 32)         0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 16, 8, 16)         4624
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 32, 16, 16)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 32, 16, 8)         1160
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 64, 32, 8)         0
# _________________________________________________________________
# output (Conv2D)              (None, 40, 30, 1)         601
# =================================================================
# Total params: 249,553
# Trainable params: 249,553
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 12), (None, 12),  101636
# _________________________________________________________________
# Decoder (Functional)         (None, 40, 30, 1)         249553
# =================================================================
# Total params: 351,195
# Trainable params: 351,189
# Non-trainable params: 6
# _________________________________________________________________

# %%
callbacks = [
    #EarlyStopping(monitor='val_loss', patience=15),
    #TensorBoard(
    #    log_dir='./logs',
    #    histogram_freq=1
    #)
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=100, 
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 304/304 [==============================] - 57s 180ms/step - loss: 152.6536 - reconstruction_loss: 110.8668 - kl_loss: 0.1648 - val_loss: 82.1708 - val_reconstruction_loss: 80.3231 - val_kl_loss: 1.8477
# Epoch 2/100
# 304/304 [==============================] - 21s 68ms/step - loss: 61.7243 - reconstruction_loss: 37.2127 - kl_loss: 10.3941 - val_loss: 29.1573 - val_reconstruction_loss: 17.6213 - val_kl_loss: 11.5360
# Epoch 3/100
# 304/304 [==============================] - 21s 68ms/step - loss: 30.4162 - reconstruction_loss: 18.0137 - kl_loss: 11.3716 - val_loss: 27.6140 - val_reconstruction_loss: 16.2948 - val_kl_loss: 11.3192
# Epoch 4/100
# 304/304 [==============================] - 21s 68ms/step - loss: 27.8973 - reconstruction_loss: 15.8601 - kl_loss: 10.7405 - val_loss: 29.5372 - val_reconstruction_loss: 19.9229 - val_kl_loss: 9.6143
# Epoch 5/100
# 304/304 [==============================] - 21s 68ms/step - loss: 23.9156 - reconstruction_loss: 13.2523 - kl_loss: 10.1833 - val_loss: 23.6605 - val_reconstruction_loss: 14.1040 - val_kl_loss: 9.5565
# Epoch 6/100
# 304/304 [==============================] - 21s 70ms/step - loss: 22.5368 - reconstruction_loss: 12.1799 - kl_loss: 9.7507 - val_loss: 21.1197 - val_reconstruction_loss: 11.3186 - val_kl_loss: 9.8011
# Epoch 7/100
# 304/304 [==============================] - 20s 67ms/step - loss: 21.2288 - reconstruction_loss: 11.3910 - kl_loss: 9.7621 - val_loss: 17.8109 - val_reconstruction_loss: 7.9442 - val_kl_loss: 9.8667
# Epoch 8/100
# 304/304 [==============================] - 21s 68ms/step - loss: 20.5840 - reconstruction_loss: 10.8215 - kl_loss: 9.8161 - val_loss: 19.0878 - val_reconstruction_loss: 9.8050 - val_kl_loss: 9.2828
# Epoch 9/100
# 304/304 [==============================] - 21s 69ms/step - loss: 20.7836 - reconstruction_loss: 10.5041 - kl_loss: 9.8053 - val_loss: 17.9652 - val_reconstruction_loss: 8.5670 - val_kl_loss: 9.3981
# Epoch 10/100
# 304/304 [==============================] - 21s 69ms/step - loss: 20.0649 - reconstruction_loss: 10.3895 - kl_loss: 9.7452 - val_loss: 17.9662 - val_reconstruction_loss: 7.9332 - val_kl_loss: 10.0330
# Epoch 11/100
# 304/304 [==============================] - 21s 69ms/step - loss: 19.2565 - reconstruction_loss: 9.1816 - kl_loss: 9.9494 - val_loss: 20.1191 - val_reconstruction_loss: 10.0529 - val_kl_loss: 10.0662
# Epoch 12/100
# 304/304 [==============================] - 21s 68ms/step - loss: 19.8249 - reconstruction_loss: 9.5487 - kl_loss: 9.9234 - val_loss: 18.1297 - val_reconstruction_loss: 8.4055 - val_kl_loss: 9.7242
# Epoch 13/100
# 304/304 [==============================] - 21s 68ms/step - loss: 18.2318 - reconstruction_loss: 8.4063 - kl_loss: 10.0657 - val_loss: 18.7997 - val_reconstruction_loss: 8.6879 - val_kl_loss: 10.1118
# Epoch 14/100
# 304/304 [==============================] - 21s 69ms/step - loss: 18.4359 - reconstruction_loss: 8.3726 - kl_loss: 10.1148 - val_loss: 17.9830 - val_reconstruction_loss: 8.3019 - val_kl_loss: 9.6810
# Epoch 15/100
# 304/304 [==============================] - 21s 70ms/step - loss: 18.5910 - reconstruction_loss: 8.8695 - kl_loss: 9.9685 - val_loss: 20.5800 - val_reconstruction_loss: 10.7357 - val_kl_loss: 9.8443
# Epoch 16/100
# 304/304 [==============================] - 21s 70ms/step - loss: 18.1417 - reconstruction_loss: 7.6395 - kl_loss: 10.1595 - val_loss: 15.9795 - val_reconstruction_loss: 6.3471 - val_kl_loss: 9.6324
# Epoch 17/100
# 304/304 [==============================] - 21s 70ms/step - loss: 17.5357 - reconstruction_loss: 7.7140 - kl_loss: 10.1749 - val_loss: 16.7208 - val_reconstruction_loss: 6.3651 - val_kl_loss: 10.3557
# Epoch 18/100
# 304/304 [==============================] - 21s 70ms/step - loss: 17.3272 - reconstruction_loss: 7.3792 - kl_loss: 10.2136 - val_loss: 16.0626 - val_reconstruction_loss: 5.8280 - val_kl_loss: 10.2346
# Epoch 19/100
# 304/304 [==============================] - 21s 70ms/step - loss: 17.5234 - reconstruction_loss: 7.7480 - kl_loss: 10.2164 - val_loss: 16.7228 - val_reconstruction_loss: 6.6574 - val_kl_loss: 10.0654
# Epoch 20/100
# 304/304 [==============================] - 21s 70ms/step - loss: 17.0976 - reconstruction_loss: 6.7950 - kl_loss: 10.2676 - val_loss: 17.2926 - val_reconstruction_loss: 7.0937 - val_kl_loss: 10.1989
# Epoch 21/100
# 304/304 [==============================] - 21s 70ms/step - loss: 17.7368 - reconstruction_loss: 7.4205 - kl_loss: 10.2484 - val_loss: 15.7472 - val_reconstruction_loss: 6.3917 - val_kl_loss: 9.3555
# Epoch 22/100
# 304/304 [==============================] - 21s 70ms/step - loss: 17.7868 - reconstruction_loss: 7.2933 - kl_loss: 10.1908 - val_loss: 16.4654 - val_reconstruction_loss: 6.3985 - val_kl_loss: 10.0669
# Epoch 23/100
# 304/304 [==============================] - 21s 70ms/step - loss: 17.0205 - reconstruction_loss: 7.0570 - kl_loss: 10.2689 - val_loss: 15.9411 - val_reconstruction_loss: 6.0945 - val_kl_loss: 9.8466
# Epoch 24/100
# 304/304 [==============================] - 21s 70ms/step - loss: 16.6662 - reconstruction_loss: 6.3306 - kl_loss: 10.3122 - val_loss: 17.5613 - val_reconstruction_loss: 7.1866 - val_kl_loss: 10.3746
# Epoch 25/100
# 304/304 [==============================] - 21s 70ms/step - loss: 16.7431 - reconstruction_loss: 6.7300 - kl_loss: 10.2300 - val_loss: 15.6635 - val_reconstruction_loss: 5.5998 - val_kl_loss: 10.0637
# Epoch 26/100
# 304/304 [==============================] - 21s 70ms/step - loss: 17.2832 - reconstruction_loss: 7.0996 - kl_loss: 10.2514 - val_loss: 16.7419 - val_reconstruction_loss: 6.2510 - val_kl_loss: 10.4909
# Epoch 27/100
# 304/304 [==============================] - 21s 70ms/step - loss: 16.7451 - reconstruction_loss: 6.7760 - kl_loss: 10.2479 - val_loss: 18.3294 - val_reconstruction_loss: 7.7644 - val_kl_loss: 10.5650
# Epoch 28/100
# 304/304 [==============================] - 21s 70ms/step - loss: 16.8634 - reconstruction_loss: 6.3899 - kl_loss: 10.3111 - val_loss: 16.9311 - val_reconstruction_loss: 6.6016 - val_kl_loss: 10.3296
# Epoch 29/100
# 304/304 [==============================] - 21s 70ms/step - loss: 16.8639 - reconstruction_loss: 6.3369 - kl_loss: 10.2766 - val_loss: 15.7540 - val_reconstruction_loss: 5.3310 - val_kl_loss: 10.4230
# Epoch 30/100
# 304/304 [==============================] - 21s 69ms/step - loss: 16.7993 - reconstruction_loss: 6.2968 - kl_loss: 10.3171 - val_loss: 16.7512 - val_reconstruction_loss: 6.1371 - val_kl_loss: 10.6141
# Epoch 31/100
# 304/304 [==============================] - 21s 67ms/step - loss: 16.2609 - reconstruction_loss: 6.2882 - kl_loss: 10.2233 - val_loss: 13.5918 - val_reconstruction_loss: 3.2483 - val_kl_loss: 10.3435
# Epoch 32/100
# 304/304 [==============================] - 21s 68ms/step - loss: 16.2295 - reconstruction_loss: 6.0353 - kl_loss: 10.2937 - val_loss: 15.6420 - val_reconstruction_loss: 5.1585 - val_kl_loss: 10.4835
# Epoch 33/100
# 304/304 [==============================] - 21s 68ms/step - loss: 16.3719 - reconstruction_loss: 5.8259 - kl_loss: 10.2966 - val_loss: 16.3199 - val_reconstruction_loss: 6.0346 - val_kl_loss: 10.2853
# Epoch 34/100
# 304/304 [==============================] - 21s 68ms/step - loss: 16.1964 - reconstruction_loss: 6.1011 - kl_loss: 10.2855 - val_loss: 16.4553 - val_reconstruction_loss: 5.7055 - val_kl_loss: 10.7498
# Epoch 35/100
# 304/304 [==============================] - 21s 68ms/step - loss: 16.0989 - reconstruction_loss: 5.9255 - kl_loss: 10.3571 - val_loss: 16.5164 - val_reconstruction_loss: 6.4446 - val_kl_loss: 10.0719
# Epoch 36/100
# 304/304 [==============================] - 21s 68ms/step - loss: 16.2489 - reconstruction_loss: 5.9723 - kl_loss: 10.2569 - val_loss: 15.0581 - val_reconstruction_loss: 5.1770 - val_kl_loss: 9.8811
# Epoch 37/100
# 304/304 [==============================] - 21s 68ms/step - loss: 16.2778 - reconstruction_loss: 6.1105 - kl_loss: 10.2126 - val_loss: 13.6420 - val_reconstruction_loss: 3.8098 - val_kl_loss: 9.8322
# Epoch 38/100
# 304/304 [==============================] - 21s 68ms/step - loss: 16.1332 - reconstruction_loss: 5.7873 - kl_loss: 10.2496 - val_loss: 15.1844 - val_reconstruction_loss: 4.7483 - val_kl_loss: 10.4361
# Epoch 39/100
# 304/304 [==============================] - 21s 68ms/step - loss: 16.2592 - reconstruction_loss: 5.9106 - kl_loss: 10.1832 - val_loss: 14.6725 - val_reconstruction_loss: 4.4673 - val_kl_loss: 10.2052
# Epoch 40/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.7754 - reconstruction_loss: 5.8098 - kl_loss: 10.2034 - val_loss: 13.7114 - val_reconstruction_loss: 3.5843 - val_kl_loss: 10.1271
# Epoch 41/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.6382 - reconstruction_loss: 5.7750 - kl_loss: 10.2224 - val_loss: 15.1243 - val_reconstruction_loss: 5.0952 - val_kl_loss: 10.0291
# Epoch 42/100
# 304/304 [==============================] - 21s 68ms/step - loss: 16.0352 - reconstruction_loss: 5.6098 - kl_loss: 10.2759 - val_loss: 15.0727 - val_reconstruction_loss: 5.2428 - val_kl_loss: 9.8299
# Epoch 43/100
# 304/304 [==============================] - 21s 68ms/step - loss: 16.1444 - reconstruction_loss: 5.9077 - kl_loss: 10.1847 - val_loss: 16.0642 - val_reconstruction_loss: 5.8972 - val_kl_loss: 10.1670
# Epoch 44/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.6935 - reconstruction_loss: 5.5212 - kl_loss: 10.2320 - val_loss: 15.8659 - val_reconstruction_loss: 5.6549 - val_kl_loss: 10.2110
# Epoch 45/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.5867 - reconstruction_loss: 5.2538 - kl_loss: 10.2823 - val_loss: 15.1834 - val_reconstruction_loss: 4.7646 - val_kl_loss: 10.4187
# Epoch 46/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.6628 - reconstruction_loss: 5.5299 - kl_loss: 10.2394 - val_loss: 17.0509 - val_reconstruction_loss: 6.9743 - val_kl_loss: 10.0766
# Epoch 47/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.8814 - reconstruction_loss: 5.8446 - kl_loss: 10.1089 - val_loss: 14.3473 - val_reconstruction_loss: 4.8432 - val_kl_loss: 9.5041
# Epoch 48/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.2851 - reconstruction_loss: 5.1806 - kl_loss: 10.2217 - val_loss: 16.7457 - val_reconstruction_loss: 6.5809 - val_kl_loss: 10.1648
# Epoch 49/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.5924 - reconstruction_loss: 5.6339 - kl_loss: 10.1782 - val_loss: 16.3968 - val_reconstruction_loss: 6.7861 - val_kl_loss: 9.6106
# Epoch 50/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.7526 - reconstruction_loss: 5.3459 - kl_loss: 10.2023 - val_loss: 14.7917 - val_reconstruction_loss: 4.1947 - val_kl_loss: 10.5970
# Epoch 51/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.2146 - reconstruction_loss: 4.9457 - kl_loss: 10.2517 - val_loss: 14.6068 - val_reconstruction_loss: 4.5791 - val_kl_loss: 10.0277
# Epoch 52/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.2917 - reconstruction_loss: 5.0589 - kl_loss: 10.2617 - val_loss: 15.3280 - val_reconstruction_loss: 5.0051 - val_kl_loss: 10.3229
# Epoch 53/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.2564 - reconstruction_loss: 5.1734 - kl_loss: 10.2730 - val_loss: 15.8617 - val_reconstruction_loss: 6.3881 - val_kl_loss: 9.4736
# Epoch 54/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.6012 - reconstruction_loss: 5.2706 - kl_loss: 10.2759 - val_loss: 13.7433 - val_reconstruction_loss: 3.2911 - val_kl_loss: 10.4522
# Epoch 55/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.7715 - reconstruction_loss: 4.7649 - kl_loss: 10.2841 - val_loss: 13.2737 - val_reconstruction_loss: 3.3872 - val_kl_loss: 9.8866
# Epoch 56/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.1565 - reconstruction_loss: 5.0030 - kl_loss: 10.2664 - val_loss: 13.2103 - val_reconstruction_loss: 3.3154 - val_kl_loss: 9.8950
# Epoch 57/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.6405 - reconstruction_loss: 5.0756 - kl_loss: 10.2213 - val_loss: 15.0452 - val_reconstruction_loss: 4.9094 - val_kl_loss: 10.1358
# Epoch 58/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.5508 - reconstruction_loss: 5.1818 - kl_loss: 10.2272 - val_loss: 15.9616 - val_reconstruction_loss: 5.7863 - val_kl_loss: 10.1753
# Epoch 59/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.1993 - reconstruction_loss: 4.9867 - kl_loss: 10.2436 - val_loss: 14.1735 - val_reconstruction_loss: 3.8948 - val_kl_loss: 10.2787
# Epoch 60/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.2525 - reconstruction_loss: 5.0698 - kl_loss: 10.2263 - val_loss: 13.5219 - val_reconstruction_loss: 3.5786 - val_kl_loss: 9.9432
# Epoch 61/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.8528 - reconstruction_loss: 4.5825 - kl_loss: 10.2975 - val_loss: 15.0402 - val_reconstruction_loss: 5.0820 - val_kl_loss: 9.9581
# Epoch 62/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.9745 - reconstruction_loss: 4.8338 - kl_loss: 10.3505 - val_loss: 13.8719 - val_reconstruction_loss: 3.6386 - val_kl_loss: 10.2333
# Epoch 63/100
# 304/304 [==============================] - 21s 68ms/step - loss: 15.0357 - reconstruction_loss: 4.6154 - kl_loss: 10.2793 - val_loss: 13.8525 - val_reconstruction_loss: 3.5722 - val_kl_loss: 10.2803
# Epoch 64/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.4907 - reconstruction_loss: 4.4580 - kl_loss: 10.2727 - val_loss: 14.7207 - val_reconstruction_loss: 4.3487 - val_kl_loss: 10.3721
# Epoch 65/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.6550 - reconstruction_loss: 4.3111 - kl_loss: 10.3739 - val_loss: 13.6035 - val_reconstruction_loss: 3.2015 - val_kl_loss: 10.4020
# Epoch 66/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.7629 - reconstruction_loss: 4.3213 - kl_loss: 10.3654 - val_loss: 12.5031 - val_reconstruction_loss: 2.4836 - val_kl_loss: 10.0196
# Epoch 67/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.5235 - reconstruction_loss: 4.2093 - kl_loss: 10.3850 - val_loss: 12.1680 - val_reconstruction_loss: 1.8405 - val_kl_loss: 10.3274
# Epoch 68/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.5036 - reconstruction_loss: 4.1316 - kl_loss: 10.3099 - val_loss: 13.7566 - val_reconstruction_loss: 3.5475 - val_kl_loss: 10.2090
# Epoch 69/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.2294 - reconstruction_loss: 3.9384 - kl_loss: 10.3029 - val_loss: 12.6656 - val_reconstruction_loss: 2.8378 - val_kl_loss: 9.8278
# Epoch 70/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.3341 - reconstruction_loss: 3.9175 - kl_loss: 10.3862 - val_loss: 11.5145 - val_reconstruction_loss: 1.8717 - val_kl_loss: 9.6428
# Epoch 71/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.1559 - reconstruction_loss: 4.0774 - kl_loss: 10.3456 - val_loss: 15.4227 - val_reconstruction_loss: 4.5383 - val_kl_loss: 10.8844
# Epoch 72/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.3272 - reconstruction_loss: 3.8519 - kl_loss: 10.3684 - val_loss: 12.7804 - val_reconstruction_loss: 2.5742 - val_kl_loss: 10.2061
# Epoch 73/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.1923 - reconstruction_loss: 3.9571 - kl_loss: 10.3755 - val_loss: 12.4500 - val_reconstruction_loss: 1.9284 - val_kl_loss: 10.5216
# Epoch 74/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.9944 - reconstruction_loss: 3.8004 - kl_loss: 10.3508 - val_loss: 13.1806 - val_reconstruction_loss: 2.9901 - val_kl_loss: 10.1906
# Epoch 75/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.6579 - reconstruction_loss: 3.6749 - kl_loss: 10.3111 - val_loss: 13.6233 - val_reconstruction_loss: 3.8015 - val_kl_loss: 9.8218
# Epoch 76/100
# 304/304 [==============================] - 21s 68ms/step - loss: 14.3199 - reconstruction_loss: 3.7971 - kl_loss: 10.3391 - val_loss: 13.4942 - val_reconstruction_loss: 3.5230 - val_kl_loss: 9.9712
# Epoch 77/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.7301 - reconstruction_loss: 3.4617 - kl_loss: 10.3065 - val_loss: 11.7494 - val_reconstruction_loss: 2.1214 - val_kl_loss: 9.6280
# Epoch 78/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.8857 - reconstruction_loss: 3.6370 - kl_loss: 10.2915 - val_loss: 12.3286 - val_reconstruction_loss: 2.3134 - val_kl_loss: 10.0151
# Epoch 79/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.9104 - reconstruction_loss: 3.6108 - kl_loss: 10.2830 - val_loss: 10.9840 - val_reconstruction_loss: 1.0753 - val_kl_loss: 9.9087
# Epoch 80/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.5006 - reconstruction_loss: 3.4424 - kl_loss: 10.2517 - val_loss: 12.1310 - val_reconstruction_loss: 2.3447 - val_kl_loss: 9.7864
# Epoch 81/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.8821 - reconstruction_loss: 3.6784 - kl_loss: 10.2575 - val_loss: 17.4066 - val_reconstruction_loss: 7.5340 - val_kl_loss: 9.8726
# Epoch 82/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.7630 - reconstruction_loss: 3.5572 - kl_loss: 10.2304 - val_loss: 13.4436 - val_reconstruction_loss: 3.0156 - val_kl_loss: 10.4280
# Epoch 83/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.6452 - reconstruction_loss: 3.6182 - kl_loss: 10.2340 - val_loss: 11.7445 - val_reconstruction_loss: 1.7300 - val_kl_loss: 10.0145
# Epoch 84/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.4740 - reconstruction_loss: 3.4611 - kl_loss: 10.2233 - val_loss: 12.1247 - val_reconstruction_loss: 1.6976 - val_kl_loss: 10.4271
# Epoch 85/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.6945 - reconstruction_loss: 3.6507 - kl_loss: 10.2385 - val_loss: 13.4736 - val_reconstruction_loss: 3.2179 - val_kl_loss: 10.2557
# Epoch 86/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.5215 - reconstruction_loss: 3.3599 - kl_loss: 10.2348 - val_loss: 14.0934 - val_reconstruction_loss: 3.7339 - val_kl_loss: 10.3594
# Epoch 87/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.8794 - reconstruction_loss: 3.4687 - kl_loss: 10.2511 - val_loss: 12.2511 - val_reconstruction_loss: 2.6494 - val_kl_loss: 9.6017
# Epoch 88/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.7083 - reconstruction_loss: 3.5939 - kl_loss: 10.2562 - val_loss: 14.1641 - val_reconstruction_loss: 3.8341 - val_kl_loss: 10.3301
# Epoch 89/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.4300 - reconstruction_loss: 3.3615 - kl_loss: 10.2459 - val_loss: 11.8848 - val_reconstruction_loss: 1.6792 - val_kl_loss: 10.2056
# Epoch 90/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.8747 - reconstruction_loss: 3.6071 - kl_loss: 10.2479 - val_loss: 13.5503 - val_reconstruction_loss: 2.8165 - val_kl_loss: 10.7338
# Epoch 91/100
# 304/304 [==============================] - 21s 68ms/step - loss: 13.9203 - reconstruction_loss: 3.7152 - kl_loss: 10.2723 - val_loss: 11.6550 - val_reconstruction_loss: 1.8973 - val_kl_loss: 9.7577
# Epoch 92/100
# 304/304 [==============================] - 21s 69ms/step - loss: 13.5931 - reconstruction_loss: 3.4356 - kl_loss: 10.1734 - val_loss: 16.6732 - val_reconstruction_loss: 6.6715 - val_kl_loss: 10.0016
# Epoch 93/100
# 304/304 [==============================] - 21s 69ms/step - loss: 13.7383 - reconstruction_loss: 3.4064 - kl_loss: 10.1774 - val_loss: 12.4656 - val_reconstruction_loss: 2.2345 - val_kl_loss: 10.2311
# Epoch 94/100
# 304/304 [==============================] - 21s 69ms/step - loss: 13.5063 - reconstruction_loss: 3.1437 - kl_loss: 10.1943 - val_loss: 14.1807 - val_reconstruction_loss: 4.2876 - val_kl_loss: 9.8931
# Epoch 95/100
# 304/304 [==============================] - 21s 69ms/step - loss: 13.2937 - reconstruction_loss: 3.3759 - kl_loss: 10.1992 - val_loss: 12.9859 - val_reconstruction_loss: 2.9447 - val_kl_loss: 10.0411
# Epoch 96/100
# 304/304 [==============================] - 21s 69ms/step - loss: 13.8773 - reconstruction_loss: 3.7504 - kl_loss: 10.1823 - val_loss: 11.3271 - val_reconstruction_loss: 1.5944 - val_kl_loss: 9.7327
# Epoch 97/100
# 304/304 [==============================] - 21s 69ms/step - loss: 13.0700 - reconstruction_loss: 3.1668 - kl_loss: 10.2235 - val_loss: 13.7765 - val_reconstruction_loss: 3.8308 - val_kl_loss: 9.9458
# Epoch 98/100
# 304/304 [==============================] - 21s 70ms/step - loss: 13.5509 - reconstruction_loss: 3.2492 - kl_loss: 10.1873 - val_loss: 14.1781 - val_reconstruction_loss: 4.3804 - val_kl_loss: 9.7977
# Epoch 99/100
# 304/304 [==============================] - 21s 69ms/step - loss: 13.1032 - reconstruction_loss: 3.2347 - kl_loss: 10.1977 - val_loss: 11.4666 - val_reconstruction_loss: 1.2754 - val_kl_loss: 10.1912
# Epoch 100/100
# 304/304 [==============================] - 21s 70ms/step - loss: 13.7192 - reconstruction_loss: 3.2140 - kl_loss: 10.2056 - val_loss: 11.7999 - val_reconstruction_loss: 1.8967 - val_kl_loss: 9.9032

# %%
rec_loss = history.history['reconstruction_loss']

epochs = range(1, len(val_rec_loss) + 1)    

plt.figure(figsize=(8,6), dpi=80)
plt.plot(epochs, val_rec_loss, 'r', label='Val Reconstruction loss')
plt.plot(epochs, rec_loss, 'b', label='Train Reconstruction loss')
plt.title('Reconstruction loss')
plt.ylabel('Loss')
plt.xlabel("Epochs")
plt.gca().set_ylim([0,15])
#plt.gca().set_ylim([0, 20])
plt.legend()

# %%
import os
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

files = os.listdir("./images_paddleless_big/")
rand_img = random.randint(0, len(files) -10)

for i in range(n):
    #print(files[rand_img+i])
    img = img_to_array(load_img(f"images_paddleless_big/{files[rand_img+i]}", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 300.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [0] * 10
            # missing =  4.5645156e+00,  1.5707643e+01,    
            z_sample = np.array([[xi, yi] + rest])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)

# %%
vae.model.save("models/vae_big_paddleless")
# Out:
# INFO:tensorflow:Assets written to: models/vae_big_paddleless/assets
