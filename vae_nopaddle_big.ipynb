# %% [markdown]
# ## Variational Autoencoder Big

# %%
from keras.utils.vis_utils import plot_model
from keras_visualizer import visualizer
from keras.callbacks import EarlyStopping, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from autoencoders.VAE import VAE as VAE

DATASET_SIZE = 25084
INPUT_SHAPE = (40, 30, 1)

# %%
import tensorflow as tf

devices = tf.config.list_physical_devices('GPU')

if len(devices) < 1:
    raise Exception("Cannot initialize GPU")

print("GPU configured correctly")
# Out:
# GPU configured correctly

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3,
    horizontal_flip=True,
    vertical_flip=True
)
# Allow horizontal flip and vertical flip as a mirror image in both axes of a game is a valid game state

train_datagen = datagen.flow_from_directory(
    'images_paddleless_big/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='training'
)

val_datagen = datagen.flow_from_directory(
    'images_paddleless_big/',
    target_size=(INPUT_SHAPE[0], INPUT_SHAPE[1]),
    color_mode='grayscale',
    class_mode='input',
    shuffle=True,
    subset='validation'
)
# Out:
# Found 9706 images belonging to 1 classes.
# Found 4159 images belonging to 1 classes.

# %%
vae = VAE(
    layers=5,
    latent_size=12,
    kernel_size=3,
    filters=8,
    beta=1,
    input_shape=INPUT_SHAPE,
    name="VAE"
)
vae.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_encoder (InputLayer)      [(None, 40, 30, 1)]  0
# __________________________________________________________________________________________________
# conv1_enc (Conv2D)              (None, 40, 30, 8)    80          input_encoder[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 20, 15, 8)    0           conv1_enc[0][0]
# __________________________________________________________________________________________________
# conv2_enc (Conv2D)              (None, 20, 15, 16)   1168        maxpool1[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 10, 8, 16)    0           conv2_enc[0][0]
# __________________________________________________________________________________________________
# conv3_enc (Conv2D)              (None, 10, 8, 32)    4640        maxpool2[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 5, 4, 32)     0           conv3_enc[0][0]
# __________________________________________________________________________________________________
# conv4_enc (Conv2D)              (None, 5, 4, 64)     18496       maxpool3[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 3, 2, 64)     0           conv4_enc[0][0]
# __________________________________________________________________________________________________
# conv5_enc (Conv2D)              (None, 3, 2, 128)    73856       maxpool4[0][0]
# __________________________________________________________________________________________________
# maxpool5 (MaxPooling2D)         (None, 2, 1, 128)    0           conv5_enc[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           maxpool5[0][0]
# __________________________________________________________________________________________________
# bottleneck (Dense)              (None, 12)           3084        flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 12)           156         bottleneck[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 12)           156         bottleneck[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 12)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 101,636
# Trainable params: 101,636
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_decoder (InputLayer)   [(None, 12)]              0
# _________________________________________________________________
# decoding (Dense)             (None, 256)               3328
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 1, 128)         0
# _________________________________________________________________
# conv5_dec (Conv2D)           (None, 2, 1, 128)         147584
# _________________________________________________________________
# upsamp5 (UpSampling2D)       (None, 4, 2, 128)         0
# _________________________________________________________________
# conv4_dec (Conv2D)           (None, 4, 2, 64)          73792
# _________________________________________________________________
# upsamp4 (UpSampling2D)       (None, 8, 4, 64)          0
# _________________________________________________________________
# conv3_dec (Conv2D)           (None, 8, 4, 32)          18464
# _________________________________________________________________
# upsamp3 (UpSampling2D)       (None, 16, 8, 32)         0
# _________________________________________________________________
# conv2_dec (Conv2D)           (None, 16, 8, 16)         4624
# _________________________________________________________________
# upsamp2 (UpSampling2D)       (None, 32, 16, 16)        0
# _________________________________________________________________
# conv1_dec (Conv2D)           (None, 32, 16, 8)         1160
# _________________________________________________________________
# upsamp1 (UpSampling2D)       (None, 64, 32, 8)         0
# _________________________________________________________________
# output (Conv2D)              (None, 40, 30, 1)         601
# =================================================================
# Total params: 249,553
# Trainable params: 249,553
# Non-trainable params: 0
# _________________________________________________________________
# Model: "VAE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder (Functional)         [(None, 12), (None, 12),  101636
# _________________________________________________________________
# Decoder (Functional)         (None, 40, 30, 1)         249553
# =================================================================
# Total params: 351,195
# Trainable params: 351,189
# Non-trainable params: 6
# _________________________________________________________________

# %%
callbacks = [
    #EarlyStopping(monitor='val_loss', patience=15),
    #TensorBoard(
    #    log_dir='./logs',
    #    histogram_freq=1
    #)
]

history = vae.train(
    train_datagen, 
    val_datagen, 
    epochs=100, 
    callbacks=callbacks
)
# Out:
# 304/304 [==============================] - 3s 10ms/step - loss: 27.0230 - reconstruction_loss: 14.7217 - kl_loss: 11.8968 - val_loss: 26.0460 - val_reconstruction_loss: 14.3695 - val_kl_loss: 11.6765
# Epoch 7/100
# 304/304 [==============================] - 3s 10ms/step - loss: 25.2656 - reconstruction_loss: 13.6588 - kl_loss: 11.3310 - val_loss: 23.4068 - val_reconstruction_loss: 12.7528 - val_kl_loss: 10.6540
# Epoch 8/100
# 304/304 [==============================] - 3s 10ms/step - loss: 23.4311 - reconstruction_loss: 12.2497 - kl_loss: 10.5508 - val_loss: 21.4964 - val_reconstruction_loss: 11.3001 - val_kl_loss: 10.1963
# Epoch 9/100
# 304/304 [==============================] - 3s 10ms/step - loss: 21.0252 - reconstruction_loss: 10.7264 - kl_loss: 9.9643 - val_loss: 23.8840 - val_reconstruction_loss: 14.3911 - val_kl_loss: 9.4930
# Epoch 10/100
# 304/304 [==============================] - 3s 10ms/step - loss: 20.6651 - reconstruction_loss: 10.6256 - kl_loss: 9.8521 - val_loss: 17.3971 - val_reconstruction_loss: 7.2507 - val_kl_loss: 10.1464
# Epoch 11/100
# 304/304 [==============================] - 3s 10ms/step - loss: 19.3836 - reconstruction_loss: 9.5800 - kl_loss: 9.9690 - val_loss: 18.8292 - val_reconstruction_loss: 9.0021 - val_kl_loss: 9.8272
# Epoch 12/100
# 304/304 [==============================] - 3s 10ms/step - loss: 19.4722 - reconstruction_loss: 9.4210 - kl_loss: 9.9387 - val_loss: 17.2820 - val_reconstruction_loss: 7.6592 - val_kl_loss: 9.6229
# Epoch 13/100
# 304/304 [==============================] - 3s 10ms/step - loss: 18.5715 - reconstruction_loss: 8.6450 - kl_loss: 10.0792 - val_loss: 20.1287 - val_reconstruction_loss: 10.0334 - val_kl_loss: 10.0954
# Epoch 14/100
# 304/304 [==============================] - 3s 10ms/step - loss: 19.9443 - reconstruction_loss: 9.1419 - kl_loss: 9.9470 - val_loss: 24.7486 - val_reconstruction_loss: 14.9156 - val_kl_loss: 9.8330
# Epoch 15/100
# 304/304 [==============================] - 3s 10ms/step - loss: 19.0282 - reconstruction_loss: 8.4135 - kl_loss: 10.0956 - val_loss: 19.3399 - val_reconstruction_loss: 9.6758 - val_kl_loss: 9.6641
# Epoch 16/100
# 304/304 [==============================] - 3s 10ms/step - loss: 18.6532 - reconstruction_loss: 8.1374 - kl_loss: 10.0796 - val_loss: 15.1031 - val_reconstruction_loss: 5.0374 - val_kl_loss: 10.0658
# Epoch 17/100
# 304/304 [==============================] - 3s 10ms/step - loss: 18.1364 - reconstruction_loss: 8.2146 - kl_loss: 10.0900 - val_loss: 17.4044 - val_reconstruction_loss: 7.5505 - val_kl_loss: 9.8539
# Epoch 18/100
# 304/304 [==============================] - 3s 10ms/step - loss: 18.4384 - reconstruction_loss: 7.7273 - kl_loss: 10.1300 - val_loss: 18.1346 - val_reconstruction_loss: 8.3354 - val_kl_loss: 9.7992
# Epoch 19/100
# 304/304 [==============================] - 3s 10ms/step - loss: 17.6315 - reconstruction_loss: 7.3286 - kl_loss: 10.1496 - val_loss: 17.5310 - val_reconstruction_loss: 7.2897 - val_kl_loss: 10.2413
# Epoch 20/100
# 304/304 [==============================] - 3s 10ms/step - loss: 17.7366 - reconstruction_loss: 7.2488 - kl_loss: 10.2167 - val_loss: 16.0652 - val_reconstruction_loss: 6.2330 - val_kl_loss: 9.8322
# Epoch 21/100
# 304/304 [==============================] - 3s 10ms/step - loss: 17.2730 - reconstruction_loss: 7.1333 - kl_loss: 10.1737 - val_loss: 17.7535 - val_reconstruction_loss: 7.6517 - val_kl_loss: 10.1018
# Epoch 22/100
# 304/304 [==============================] - 3s 10ms/step - loss: 17.4663 - reconstruction_loss: 7.1756 - kl_loss: 10.1930 - val_loss: 17.5330 - val_reconstruction_loss: 7.2874 - val_kl_loss: 10.2456
# Epoch 23/100
# 304/304 [==============================] - 3s 10ms/step - loss: 17.2153 - reconstruction_loss: 7.3147 - kl_loss: 10.1844 - val_loss: 14.9194 - val_reconstruction_loss: 4.9919 - val_kl_loss: 9.9275
# Epoch 24/100
# 304/304 [==============================] - 3s 10ms/step - loss: 17.1496 - reconstruction_loss: 7.1890 - kl_loss: 10.1543 - val_loss: 15.7308 - val_reconstruction_loss: 5.5941 - val_kl_loss: 10.1367
# Epoch 25/100
# 304/304 [==============================] - 3s 11ms/step - loss: 17.5058 - reconstruction_loss: 6.8658 - kl_loss: 10.2321 - val_loss: 16.0934 - val_reconstruction_loss: 5.9684 - val_kl_loss: 10.1250
# Epoch 26/100
# 304/304 [==============================] - 3s 10ms/step - loss: 17.0127 - reconstruction_loss: 6.8619 - kl_loss: 10.2129 - val_loss: 18.2474 - val_reconstruction_loss: 7.8428 - val_kl_loss: 10.4045
# Epoch 27/100
# 304/304 [==============================] - 3s 10ms/step - loss: 17.0988 - reconstruction_loss: 6.7116 - kl_loss: 10.1941 - val_loss: 15.6108 - val_reconstruction_loss: 5.6168 - val_kl_loss: 9.9939
# Epoch 28/100
# 304/304 [==============================] - 3s 10ms/step - loss: 17.2824 - reconstruction_loss: 6.8877 - kl_loss: 10.1680 - val_loss: 16.7972 - val_reconstruction_loss: 6.4633 - val_kl_loss: 10.3340
# Epoch 29/100
# 304/304 [==============================] - 3s 10ms/step - loss: 17.5665 - reconstruction_loss: 7.4211 - kl_loss: 10.1409 - val_loss: 15.9482 - val_reconstruction_loss: 6.2496 - val_kl_loss: 9.6986
# Epoch 30/100
# 304/304 [==============================] - 3s 11ms/step - loss: 16.2717 - reconstruction_loss: 6.1723 - kl_loss: 10.1842 - val_loss: 16.1733 - val_reconstruction_loss: 6.2678 - val_kl_loss: 9.9055
# Epoch 31/100
# 304/304 [==============================] - 3s 10ms/step - loss: 16.4431 - reconstruction_loss: 6.0985 - kl_loss: 10.3006 - val_loss: 15.7967 - val_reconstruction_loss: 5.5975 - val_kl_loss: 10.1992
# Epoch 32/100
# 304/304 [==============================] - 3s 10ms/step - loss: 16.3086 - reconstruction_loss: 6.5166 - kl_loss: 10.2479 - val_loss: 14.2027 - val_reconstruction_loss: 4.1220 - val_kl_loss: 10.0806
# Epoch 33/100
# 304/304 [==============================] - 3s 10ms/step - loss: 16.8333 - reconstruction_loss: 6.4458 - kl_loss: 10.1722 - val_loss: 15.1791 - val_reconstruction_loss: 5.0950 - val_kl_loss: 10.0841
# Epoch 34/100
# 304/304 [==============================] - 3s 10ms/step - loss: 16.6200 - reconstruction_loss: 6.4177 - kl_loss: 10.2052 - val_loss: 17.0846 - val_reconstruction_loss: 6.9075 - val_kl_loss: 10.1770
# Epoch 35/100
# 304/304 [==============================] - 3s 10ms/step - loss: 16.5502 - reconstruction_loss: 6.2511 - kl_loss: 10.1947 - val_loss: 15.0044 - val_reconstruction_loss: 5.0396 - val_kl_loss: 9.9648
# Epoch 36/100
# 304/304 [==============================] - 3s 10ms/step - loss: 16.1415 - reconstruction_loss: 5.9060 - kl_loss: 10.2464 - val_loss: 18.5942 - val_reconstruction_loss: 8.5038 - val_kl_loss: 10.0904
# Epoch 37/100
# 304/304 [==============================] - 3s 10ms/step - loss: 16.2243 - reconstruction_loss: 6.1636 - kl_loss: 10.1948 - val_loss: 15.9909 - val_reconstruction_loss: 5.9062 - val_kl_loss: 10.0847
# Epoch 38/100
# 304/304 [==============================] - 3s 10ms/step - loss: 16.0179 - reconstruction_loss: 5.7979 - kl_loss: 10.2410 - val_loss: 16.7000 - val_reconstruction_loss: 6.2530 - val_kl_loss: 10.4470
# Epoch 39/100
# 304/304 [==============================] - 3s 11ms/step - loss: 16.2639 - reconstruction_loss: 5.9006 - kl_loss: 10.2024 - val_loss: 14.0913 - val_reconstruction_loss: 4.0595 - val_kl_loss: 10.0317
# Epoch 40/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.9758 - reconstruction_loss: 5.7520 - kl_loss: 10.2372 - val_loss: 14.3428 - val_reconstruction_loss: 4.1470 - val_kl_loss: 10.1958
# Epoch 41/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.8437 - reconstruction_loss: 5.7159 - kl_loss: 10.2216 - val_loss: 17.8665 - val_reconstruction_loss: 7.8108 - val_kl_loss: 10.0557
# Epoch 42/100
# 304/304 [==============================] - 3s 10ms/step - loss: 16.1861 - reconstruction_loss: 5.6486 - kl_loss: 10.2218 - val_loss: 19.2072 - val_reconstruction_loss: 9.0432 - val_kl_loss: 10.1640
# Epoch 43/100
# 304/304 [==============================] - 3s 10ms/step - loss: 16.6252 - reconstruction_loss: 6.0135 - kl_loss: 10.2211 - val_loss: 12.9276 - val_reconstruction_loss: 2.9864 - val_kl_loss: 9.9412
# Epoch 44/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.7898 - reconstruction_loss: 5.8826 - kl_loss: 10.1643 - val_loss: 14.3356 - val_reconstruction_loss: 4.2776 - val_kl_loss: 10.0580
# Epoch 45/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.4632 - reconstruction_loss: 5.4397 - kl_loss: 10.2200 - val_loss: 15.0740 - val_reconstruction_loss: 5.0795 - val_kl_loss: 9.9945
# Epoch 46/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.9027 - reconstruction_loss: 5.6405 - kl_loss: 10.2042 - val_loss: 17.4644 - val_reconstruction_loss: 7.2020 - val_kl_loss: 10.2624
# Epoch 47/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.6912 - reconstruction_loss: 5.5598 - kl_loss: 10.2183 - val_loss: 16.1015 - val_reconstruction_loss: 5.8290 - val_kl_loss: 10.2724
# Epoch 48/100
# 304/304 [==============================] - 3s 11ms/step - loss: 16.4633 - reconstruction_loss: 6.0720 - kl_loss: 10.1626 - val_loss: 15.4233 - val_reconstruction_loss: 5.4065 - val_kl_loss: 10.0169
# Epoch 49/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.6478 - reconstruction_loss: 5.5484 - kl_loss: 10.2059 - val_loss: 13.9581 - val_reconstruction_loss: 4.0406 - val_kl_loss: 9.9175
# Epoch 50/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.4325 - reconstruction_loss: 5.4542 - kl_loss: 10.1637 - val_loss: 15.0184 - val_reconstruction_loss: 4.4878 - val_kl_loss: 10.5306
# Epoch 51/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.6654 - reconstruction_loss: 5.1289 - kl_loss: 10.2335 - val_loss: 13.6767 - val_reconstruction_loss: 3.0997 - val_kl_loss: 10.5770
# Epoch 52/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.5009 - reconstruction_loss: 5.2764 - kl_loss: 10.2291 - val_loss: 12.2378 - val_reconstruction_loss: 1.9828 - val_kl_loss: 10.2550
# Epoch 53/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.3075 - reconstruction_loss: 5.6072 - kl_loss: 10.1741 - val_loss: 15.9591 - val_reconstruction_loss: 5.5369 - val_kl_loss: 10.4221
# Epoch 54/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.2006 - reconstruction_loss: 5.0014 - kl_loss: 10.1505 - val_loss: 15.2383 - val_reconstruction_loss: 5.1556 - val_kl_loss: 10.0826
# Epoch 55/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.7468 - reconstruction_loss: 5.4402 - kl_loss: 10.1793 - val_loss: 13.8411 - val_reconstruction_loss: 3.7354 - val_kl_loss: 10.1057
# Epoch 56/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.5081 - reconstruction_loss: 5.4246 - kl_loss: 10.1245 - val_loss: 12.7284 - val_reconstruction_loss: 2.6098 - val_kl_loss: 10.1186
# Epoch 57/100
# 304/304 [==============================] - 4s 12ms/step - loss: 15.2050 - reconstruction_loss: 5.2486 - kl_loss: 10.2150 - val_loss: 16.1963 - val_reconstruction_loss: 6.4638 - val_kl_loss: 9.7325
# Epoch 58/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.7198 - reconstruction_loss: 5.2737 - kl_loss: 10.2018 - val_loss: 15.8761 - val_reconstruction_loss: 5.2993 - val_kl_loss: 10.5768
# Epoch 59/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.7332 - reconstruction_loss: 5.5066 - kl_loss: 10.1631 - val_loss: 14.8595 - val_reconstruction_loss: 4.7817 - val_kl_loss: 10.0778
# Epoch 60/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.9401 - reconstruction_loss: 5.6778 - kl_loss: 10.1510 - val_loss: 14.2055 - val_reconstruction_loss: 4.1094 - val_kl_loss: 10.0961
# Epoch 61/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.9442 - reconstruction_loss: 4.9591 - kl_loss: 10.2202 - val_loss: 12.9122 - val_reconstruction_loss: 3.1978 - val_kl_loss: 9.7144
# Epoch 62/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.8421 - reconstruction_loss: 4.9210 - kl_loss: 10.1845 - val_loss: 14.8155 - val_reconstruction_loss: 4.9551 - val_kl_loss: 9.8605
# Epoch 63/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.0973 - reconstruction_loss: 5.0229 - kl_loss: 10.1876 - val_loss: 15.6042 - val_reconstruction_loss: 5.4001 - val_kl_loss: 10.2040
# Epoch 64/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.4094 - reconstruction_loss: 5.4272 - kl_loss: 10.1593 - val_loss: 15.0680 - val_reconstruction_loss: 5.3381 - val_kl_loss: 9.7299
# Epoch 65/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.1341 - reconstruction_loss: 4.9752 - kl_loss: 10.1627 - val_loss: 14.6993 - val_reconstruction_loss: 4.4823 - val_kl_loss: 10.2170
# Epoch 66/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.4937 - reconstruction_loss: 5.2919 - kl_loss: 10.2004 - val_loss: 18.2254 - val_reconstruction_loss: 8.2641 - val_kl_loss: 9.9613
# Epoch 67/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.7805 - reconstruction_loss: 4.6600 - kl_loss: 10.1904 - val_loss: 14.5166 - val_reconstruction_loss: 4.7490 - val_kl_loss: 9.7675
# Epoch 68/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.1568 - reconstruction_loss: 4.9540 - kl_loss: 10.1345 - val_loss: 16.4782 - val_reconstruction_loss: 6.3096 - val_kl_loss: 10.1686
# Epoch 69/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.6333 - reconstruction_loss: 5.0665 - kl_loss: 10.1971 - val_loss: 15.9622 - val_reconstruction_loss: 5.6807 - val_kl_loss: 10.2815
# Epoch 70/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.9953 - reconstruction_loss: 4.9042 - kl_loss: 10.1625 - val_loss: 13.1031 - val_reconstruction_loss: 2.9918 - val_kl_loss: 10.1113
# Epoch 71/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.0069 - reconstruction_loss: 5.0836 - kl_loss: 10.1569 - val_loss: 16.9757 - val_reconstruction_loss: 6.4727 - val_kl_loss: 10.5030
# Epoch 72/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.2507 - reconstruction_loss: 4.9778 - kl_loss: 10.1744 - val_loss: 15.9776 - val_reconstruction_loss: 5.2788 - val_kl_loss: 10.6987
# Epoch 73/100
# 304/304 [==============================] - 3s 10ms/step - loss: 15.1832 - reconstruction_loss: 5.1635 - kl_loss: 10.1475 - val_loss: 14.4155 - val_reconstruction_loss: 4.6858 - val_kl_loss: 9.7297
# Epoch 74/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.9880 - reconstruction_loss: 4.9209 - kl_loss: 10.1490 - val_loss: 11.8203 - val_reconstruction_loss: 2.0766 - val_kl_loss: 9.7437
# Epoch 75/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.0598 - reconstruction_loss: 4.8910 - kl_loss: 10.1255 - val_loss: 14.1860 - val_reconstruction_loss: 3.8995 - val_kl_loss: 10.2866
# Epoch 76/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.8578 - reconstruction_loss: 4.9057 - kl_loss: 10.1859 - val_loss: 14.1066 - val_reconstruction_loss: 4.1669 - val_kl_loss: 9.9396
# Epoch 77/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.9189 - reconstruction_loss: 4.8134 - kl_loss: 10.1520 - val_loss: 13.0384 - val_reconstruction_loss: 3.1075 - val_kl_loss: 9.9309
# Epoch 78/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.8564 - reconstruction_loss: 4.6077 - kl_loss: 10.1629 - val_loss: 15.1450 - val_reconstruction_loss: 5.2048 - val_kl_loss: 9.9402
# Epoch 79/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.8466 - reconstruction_loss: 4.7169 - kl_loss: 10.1369 - val_loss: 13.4759 - val_reconstruction_loss: 3.4962 - val_kl_loss: 9.9797
# Epoch 80/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.9185 - reconstruction_loss: 4.7520 - kl_loss: 10.1438 - val_loss: 17.5403 - val_reconstruction_loss: 7.6148 - val_kl_loss: 9.9255
# Epoch 81/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.7699 - reconstruction_loss: 4.5599 - kl_loss: 10.1532 - val_loss: 14.3861 - val_reconstruction_loss: 4.1374 - val_kl_loss: 10.2487
# Epoch 82/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.7423 - reconstruction_loss: 4.6954 - kl_loss: 10.1088 - val_loss: 13.5236 - val_reconstruction_loss: 3.5001 - val_kl_loss: 10.0235
# Epoch 83/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.2480 - reconstruction_loss: 4.2516 - kl_loss: 10.1892 - val_loss: 14.9100 - val_reconstruction_loss: 4.8797 - val_kl_loss: 10.0302
# Epoch 84/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.6909 - reconstruction_loss: 4.5018 - kl_loss: 10.2043 - val_loss: 12.1644 - val_reconstruction_loss: 2.5740 - val_kl_loss: 9.5904
# Epoch 85/100
# 304/304 [==============================] - 3s 11ms/step - loss: 15.0583 - reconstruction_loss: 4.8822 - kl_loss: 10.1153 - val_loss: 13.0764 - val_reconstruction_loss: 3.0439 - val_kl_loss: 10.0325
# Epoch 86/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.4062 - reconstruction_loss: 4.2722 - kl_loss: 10.1858 - val_loss: 16.1360 - val_reconstruction_loss: 6.1394 - val_kl_loss: 9.9966
# Epoch 87/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.4898 - reconstruction_loss: 4.5167 - kl_loss: 10.1315 - val_loss: 12.1198 - val_reconstruction_loss: 2.4312 - val_kl_loss: 9.6886
# Epoch 88/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.7512 - reconstruction_loss: 4.7404 - kl_loss: 10.1535 - val_loss: 13.0475 - val_reconstruction_loss: 3.4354 - val_kl_loss: 9.6120
# Epoch 89/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.8727 - reconstruction_loss: 4.7882 - kl_loss: 10.0996 - val_loss: 13.3331 - val_reconstruction_loss: 3.2316 - val_kl_loss: 10.1016
# Epoch 90/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.8787 - reconstruction_loss: 4.7702 - kl_loss: 10.0805 - val_loss: 14.3201 - val_reconstruction_loss: 4.8571 - val_kl_loss: 9.4630
# Epoch 91/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.5719 - reconstruction_loss: 4.3516 - kl_loss: 10.1404 - val_loss: 13.2282 - val_reconstruction_loss: 2.9052 - val_kl_loss: 10.3230
# Epoch 92/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.4637 - reconstruction_loss: 4.2648 - kl_loss: 10.1791 - val_loss: 14.1031 - val_reconstruction_loss: 3.3286 - val_kl_loss: 10.7746
# Epoch 93/100
# 304/304 [==============================] - 3s 10ms/step - loss: 14.4932 - reconstruction_loss: 4.3446 - kl_loss: 10.1782 - val_loss: 13.2299 - val_reconstruction_loss: 3.1917 - val_kl_loss: 10.0382
# Epoch 94/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.8397 - reconstruction_loss: 4.5239 - kl_loss: 10.1567 - val_loss: 13.4855 - val_reconstruction_loss: 3.4731 - val_kl_loss: 10.0124
# Epoch 95/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.4603 - reconstruction_loss: 4.2915 - kl_loss: 10.1890 - val_loss: 12.6186 - val_reconstruction_loss: 2.4401 - val_kl_loss: 10.1785
# Epoch 96/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.9605 - reconstruction_loss: 4.8137 - kl_loss: 10.0963 - val_loss: 12.3176 - val_reconstruction_loss: 2.3864 - val_kl_loss: 9.9311
# Epoch 97/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.2483 - reconstruction_loss: 4.2922 - kl_loss: 10.1329 - val_loss: 12.3915 - val_reconstruction_loss: 2.1739 - val_kl_loss: 10.2176
# Epoch 98/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.2014 - reconstruction_loss: 4.4074 - kl_loss: 10.0948 - val_loss: 14.1638 - val_reconstruction_loss: 4.2966 - val_kl_loss: 9.8672
# Epoch 99/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.1835 - reconstruction_loss: 4.3255 - kl_loss: 10.1481 - val_loss: 14.3772 - val_reconstruction_loss: 4.5017 - val_kl_loss: 9.8756
# Epoch 100/100
# 304/304 [==============================] - 3s 11ms/step - loss: 14.4788 - reconstruction_loss: 4.4148 - kl_loss: 10.0727 - val_loss: 14.2264 - val_reconstruction_loss: 3.6839 - val_kl_loss: 10.5424

# %%
val_rec_loss = history.history['val_reconstruction_loss']
rec_loss = history.history['reconstruction_loss']

epochs = range(1, len(val_rec_loss) + 1)    

plt.plot(epochs, val_rec_loss, 'b', label='Val Reconstruction loss')
plt.plot(epochs, rec_loss, 'bo', label='Reconstruction loss')
plt.title('Reconstruction and KL loss')
#plt.gca().set_ylim([0, 20])
plt.legend()

# %%
import os
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import random

n = 10
images = np.empty((n, *INPUT_SHAPE))

files = os.listdir("./images_paddleless_big/")
rand_img = random.randint(0, len(files) -10)

for i in range(n):
    #print(files[rand_img+i])
    img = img_to_array(load_img(f"images_paddleless_big/{files[rand_img+i]}", color_mode='grayscale'))
    images[i] = img

decoded_imgs = vae.predict(images)
latent = vae.encoder.predict(images)

#print(latent[:][2])

decoded_imgs = vae.decoder.predict(latent[:][2])

plt.figure(figsize=(20, 4))

for i in range(1, n+1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(images[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i-1].reshape(INPUT_SHAPE[0], INPUT_SHAPE[1]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import random

def plot_latent_space(vae, n=15, figsize=25):
    # display a n*n 2D manifold of digits
    x_input_size = INPUT_SHAPE[0]
    y_input_size = INPUT_SHAPE[1]
    scale = 300.0
    figure = np.zeros((x_input_size * n + n - 1, y_input_size * n + n - 1))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            
            rest = [0] * 10
            # missing =  4.5645156e+00,  1.5707643e+01,    
            z_sample = np.array([[xi, yi] + rest])
            #z_sample = np.array([[random.randint(-scale, scale) for i in range(16)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(x_input_size, y_input_size)
            figure[
                i * x_input_size + i: (i + 1) * x_input_size + i,
                j * y_input_size + j: (j + 1) * y_input_size + j,
            ] = digit

            if i != len(grid_x) - 1:
                figure[
                    (i + 1) * x_input_size + i,
                    j * y_input_size + j: (j + 1) * y_input_size + j,
                ] = np.array([1] * y_input_size)
            if j != len(grid_y) - 1:
                figure[
                    i * x_input_size + i: (i + 1) * x_input_size + i,
                    (j + 1) * y_input_size + j,
                ] = np.array([1] * x_input_size)

    plt.figure(figsize=(figsize, figsize))
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)

# %%
vae.model.save("models/vae_big_paddleless")
# Out:
# INFO:tensorflow:Assets written to: models/vae_big_paddleless/assets
